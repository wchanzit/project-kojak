# %%
import numpy as np
import pandas as pd
import json

import pickle

import os

import nltk
import gensim
from gensim import corpora, models, similarities

# %% [markdown]
# ### Load the Kramer DataFrame

# %%
# Load prompts
with open('kramer_responses.pkl', 'rb') as file:
    df_kramer_01 = pickle.load(file)

# %% [markdown]
# ### Further Processing

# %%
# tokenize, encode, pad

# %%
# The loaded data
df_kramer_01.head()
# Out:
#      ep_num  scene_num  line_num char_prompt  \
# 137       1          6        30      GEORGE
# 437       2          9         6       JERRY
# 440       2          9         9       MORTY
# 446       2          9        15       JERRY
# 470       2          9        39       HELEN
#
#                                       prompt char_response  \
# 137                 did you need something .        KRAMER
# 437  you cant look in there , were playing !        KRAMER
# 440                                 kramer !        KRAMER
# 446                    dad , shes cheating !        KRAMER
# 470                                     32 .        KRAMER
#
#                                    response
# 137  do you handle any of that commercial .
# 437                                    hi .
# 440                             hey morty !
# 446                                   quo ?
# 470  no , you dont have to challenge that .

# %%
df_kramer_01.shape
# Out:
# (6239, 7)

# %%
mask = df_kramer_01.response.apply(lambda x: len(nltk.word_tokenize(x)) <= 27)
df_kramer_01[mask].shape
# Out:
# (6208, 7)

# %%
df_kramer_01[~mask]
# Out:
#        ep_num  scene_num  line_num char_prompt  \
# 7159       28          4        31      ELAINE
# 7601       30          2         1      GEORGE
# 8311       32         12        14       JERRY
# 10663      41          4        30      HELENA
# 11739      44         16        19      NEWMAN
# 12886      48          2        52       JERRY
# 15148      56          6        16       JERRY
# 16562      61         16         3       JERRY
# 16731      62          9        25      GEORGE
# 19331      71          4        50      ELAINE
# 21015      76         11         9        JANE
# 21294      77         12         1      GEORGE
# 23564      84         12         5      GEORGE
# 24337      87         10        19       JERRY
# 26637      95          5        35      ELAINE
# 30262     109          9         1       PUDDY
# 30283     109         11         4       JERRY
# 33927     121          1       233   MRS. ROSS
# 34213     122         20        14       JERRY
# ...

# %%
# %%time

# Tokenize the data
prompts_tokenized = [nltk.word_tokenize(line) for line in df_kramer_01.prompt]
responses_tokenized = [nltk.word_tokenize(line) for line in df_kramer_01.response]
# Out:
# CPU times: user 1.85 s, sys: 47.4 ms, total: 1.89 s
# Wall time: 2.3 s

# %%
max([len(line) for line in prompts_tokenized])
# Out:
# 27

# %%
max([len(line) for line in responses_tokenized])
# Out:
# 51

# %%
# Encode the data
sentend=np.ones((300L,),dtype=np.float32) 

vec_x=[]
for sent in tok_x:
    sentvec = [model[w] for w in sent if w in model.vocab]
    vec_x.append(sentvec)
    
vec_y=[]
for sent in tok_y:
    sentvec = [model[w] for w in sent if w in model.vocab]
    vec_y.append(sentvec)

# %%
    
    

    
    
for tok_sent in vec_x:
    tok_sent[14:]=[]
    tok_sent.append(sentend)
    

for tok_sent in vec_x:
    if len(tok_sent)<15:
        for i in range(15-len(tok_sent)):
            tok_sent.append(sentend)    
            
for tok_sent in vec_y:
    tok_sent[14:]=[]
    tok_sent.append(sentend)
    

for tok_sent in vec_y:
    if len(tok_sent)<15:
        for i in range(15-len(tok_sent)):
            tok_sent.append(sentend)             
            
            
with open('conversation.pickle','w') as f:
    pickle.dump([vec_x,vec_y],f)
