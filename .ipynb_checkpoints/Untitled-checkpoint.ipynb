# %%
import pandas as pd
import numpy as np
import json

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
! pwd
# Out:
# /Users/warren/Data_Science/Metis/github/project-kojak

# %%
# %%time
with open('scrape_seinfeld/all_eps.json') as json_data:
    d = json.load(json_data)

# %%
# %%time
#colnames = []

df1 = pd.DataFrame(d)#, columns = colnames)
# Out:
# CPU times: user 14.9 s, sys: 2.49 s, total: 17.4 s
# Wall time: 18.1 s

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Columns: 140288 entries, 100_0 to 9_99
# dtypes: object(140288)
# memory usage: 188.4+ MB

# %%
df1.shape
# Out:
# (176, 140288)

# %%
df1.head().T
# Out:
#           0    1    2    3    4
# 100_0   NaN  NaN  NaN  NaN  NaN
# 100_1   NaN  NaN  NaN  NaN  NaN
# 100_10  NaN  NaN  NaN  NaN  NaN
# 100_11  NaN  NaN  NaN  NaN  NaN
# 100_12  NaN  NaN  NaN  NaN  NaN
# 100_13  NaN  NaN  NaN  NaN  NaN
# 100_14  NaN  NaN  NaN  NaN  NaN
# 100_15  NaN  NaN  NaN  NaN  NaN
# 100_16  NaN  NaN  NaN  NaN  NaN
# 100_17  NaN  NaN  NaN  NaN  NaN
# 100_18  NaN  NaN  NaN  NaN  NaN
# 100_19  NaN  NaN  NaN  NaN  NaN
# 100_2   NaN  NaN  NaN  NaN  NaN
# 100_20  NaN  NaN  NaN  NaN  NaN
# 100_21  NaN  NaN  NaN  NaN  NaN
# 100_22  NaN  NaN  NaN  NaN  NaN
# 100_23  NaN  NaN  NaN  NaN  NaN
# 100_24  NaN  NaN  NaN  NaN  NaN
# 100_25  NaN  NaN  NaN  NaN  NaN
# 100_26  NaN  NaN  NaN  NaN  NaN
# 100_27  NaN  NaN  NaN  NaN  NaN
# 100_28  NaN  NaN  NaN  NaN  NaN
# 100_29  NaN  NaN  NaN  NaN  NaN
# 100_3   NaN  NaN  NaN  NaN  NaN
# 100_30  NaN  NaN  NaN  NaN  NaN
# 100_31  NaN  NaN  NaN  NaN  NaN
# 100_32  NaN  NaN  NaN  NaN  NaN
# 100_33  NaN  NaN  NaN  NaN  NaN
# ...

# %%
# %%time
with open('scrape_seinfeld/ep60test.json') as json_data:
    ep60 = json.load(json_data)
# Out:
# CPU times: user 2.15 ms, sys: 2.23 ms, total: 4.38 ms
# Wall time: 4.45 ms

# %%
# %%time
#colnames = []

df_ep60 = pd.DataFrame(ep60)#, columns = colnames)
# Out:
# CPU times: user 81.1 ms, sys: 12.8 ms, total: 93.9 ms
# Wall time: 111 ms

# %%
pd.DataFrame.from_dict(ep60, orient = 'index')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-da2667a9abf7> in <module>()
# ----> 1 pd.DataFrame.from_dict(ep60, orient = 'index')
#
# /Users/warren/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype)
#     843             if len(data) > 0:
#     844                 # TODO speed up Series case
# --> 845                 if isinstance(list(data.values())[0], (Series, dict)):
#     846                     data = _from_nested_dict(data)
#     847                 else:
#
# AttributeError: 'list' object has no attribute 'values'

# %%
ep60
# Out:
# [{'0': 'Episode 60 - The Junior Mint',
#   '1': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tpc: 421, season 4, episode 20',
#   '10': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tRegulars:',
#   '100': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tKRAMER: Definitely.',
#   '101': '\n\t\t\t\t\t\t\t',
#   '102': "\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJERRY: So we're still going to the health club to play racquetball right?",
#   '103': '\n\t\t\t\t\t\t\t',
#   '104': "\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tKRAMER: Yeah, yeah, whenever you're ready.",
#   '105': '\n\t\t\t\t\t\t\t',
#   '106': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJERRY: O.K., soon as Elaine gets here.',
#   '107': '\n\t\t\t\t\t\t\t',
#   '108': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tKRAMER: Yep.',
#   '109': '\n\t\t\t\t\t\t\t',
#   '11': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJerry Seinfeld ........................ Jerry Seinfeld',
#   '110': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t[Kramer exits]',
#   '111': '\n\t\t\t\t\t\t\t',
#   '112': '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJERRY: What, you rented "Home Alone"?',
# ...

# %%
df_ep60.shape
# Out:
# (1, 971)

# %%
df_ep60.head().T
# Out:
#                                                      0
# 0                         Episode 60 - The Junior Mint
# 1    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tpc: 421, season ...
# 10             \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tRegulars:
# 100  \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tKRAMER: Definitely.
# 101                                   \n\t\t\t\t\t\t\t
# 102  \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJERRY: So we're ...
# 103                                   \n\t\t\t\t\t\t\t
# 104  \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tKRAMER: Yeah, ye...
# 105                                   \n\t\t\t\t\t\t\t
# 106  \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJERRY: O.K., soo...
# 107                                   \n\t\t\t\t\t\t\t
# 108         \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tKRAMER: Yep.
# 109                                   \n\t\t\t\t\t\t\t
# 11   \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJerry Seinfeld ....
# 110       \n\t\t\t\t\t\t\t\n\t\t\t\t\t\t[Kramer exits]
# 111                                   \n\t\t\t\t\t\t\t
# ...

# %%
# %%time
with open('scrape_seinfeld/ep60test2.json') as json_data:
    ep60_2 = json.load(json_data)
# Out:
# CPU times: user 1.97 ms, sys: 2.64 ms, total: 4.61 ms
# Wall time: 3.94 ms

# %%
# %%time
#colnames = []

df_ep60_2 = pd.DataFrame(ep60_2[0])#, columns = colnames)
# Out:
# CPU times: user 1.16 ms, sys: 1.97 ms, total: 3.14 ms
# Wall time: 3.1 ms

# %%
df_ep60_2
# Out:
#                                                   line line_index
# 0                         Episode 60 - The Junior Mint       60_0
# 1    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tpc: 421, season ...       60_1
# 2    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tBroadcast date: ...       60_2
# 3                                     \n\t\t\t\t\t\t\t       60_3
# 4    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tWritten by  Andy...       60_4
# 5    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tDirected by Tom ...       60_5
# 6                                     \n\t\t\t\t\t\t\t       60_6
# 7    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\t----------------...       60_7
# 8                                     \n\t\t\t\t\t\t\t       60_8
# 9               \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tThe Cast       60_9
# 10             \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tRegulars:      60_10
# 11   \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJerry Seinfeld ....      60_11
# 12   \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJason Alexander ...      60_12
# ...

# %%
pd.DataFrame.from_dict(ep60_2[0])
# Out:
#                                                   line line_index
# 0                         Episode 60 - The Junior Mint       60_0
# 1    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tpc: 421, season ...       60_1
# 2    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tBroadcast date: ...       60_2
# 3                                     \n\t\t\t\t\t\t\t       60_3
# 4    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tWritten by  Andy...       60_4
# 5    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tDirected by Tom ...       60_5
# 6                                     \n\t\t\t\t\t\t\t       60_6
# 7    \n\t\t\t\t\t\t\t\n\t\t\t\t\t\t----------------...       60_7
# 8                                     \n\t\t\t\t\t\t\t       60_8
# 9               \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tThe Cast       60_9
# 10             \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tRegulars:      60_10
# 11   \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJerry Seinfeld ....      60_11
# 12   \n\t\t\t\t\t\t\t\n\t\t\t\t\t\tJason Alexander ...      60_12
# ...

# %%
# %%time
with open('scrape_seinfeld/all_eps_2.json') as json_data:
    jfile = json.load(json_data)
# Out:
# CPU times: user 10.7 s, sys: 4.34 s, total: 15.1 s
# Wall time: 17.7 s

# %%
# %%time
#colnames = []

df1 = pd.DataFrame(jfile[0])
# Out:
# CPU times: user 1.33 ms, sys: 1.2 ms, total: 2.52 ms
# Wall time: 3.9 ms

# %%
df1.shape
# Out:
# (564, 2)

# %%
df1.iloc[100:110]
# Out:
#                                                   line line_index
# 100  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tJE...      1_100
# 101                             \n\t\t\t\t\t\t\t\t\t\t      1_101
# 102  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tGE...      1_102
# 103                             \n\t\t\t\t\t\t\t\t\t\t      1_103
# 104  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tJE...      1_104
# 105                             \n\t\t\t\t\t\t\t\t\t\t      1_105
# 106  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tGE...      1_106
# 107                             \n\t\t\t\t\t\t\t\t\t\t      1_107
# 108  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tJE...      1_108
# 109                             \n\t\t\t\t\t\t\t\t\t\t      1_109
