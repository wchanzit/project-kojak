# %%
import pandas as pd
import numpy as np
import json

import re

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from pprint import pprint

# %% [markdown]
# ### Create DataFrame - Line Counts

# %%
# %%time
with open('scrape_seinfeld/line_count.json') as json_data:
    json_lc = json.load(json_data)
# Out:
# CPU times: user 6.91 ms, sys: 1.49 ms, total: 8.4 ms
# Wall time: 7.69 ms

# %%
# Investigate json_lc
print(type(json_lc))
print(len(json_lc))
# Out:
# <class 'list'>
# 176

# %%
# Create DataFrame of line counts "df_lc"
# Only take final element of json_lc because spider yielded cumulative results when ran
df_lc = pd.DataFrame.from_dict(json_lc[len(json_lc)-1], orient = 'index').reset_index()

df_lc.columns = ['ep_num', 'line_count']
df_lc['ep_num'] = df_lc.ep_num.astype('int')

# %%
# There are about 140K total lines (pre-cleaning)
df_lc.line_count.sum()
# Out:
# 140288

# %% [markdown]
# ### Create DataFrame - Scripts from All Episodes

# %%
# %%time
with open('scrape_seinfeld/all_eps_3.json') as json_data:
    json_scripts = json.load(json_data)
# Out:
# CPU times: user 169 ms, sys: 37 ms, total: 206 ms
# Wall time: 313 ms

# %%
# Investigate json_scripts
print(type(json_scripts))
print(len(json_scripts))
# Out:
# <class 'list'>
# 176

# %%
# Check that the line counts in json_scripts match those in df_lc
for i in range(len(json_scripts)):
    ep_num = int(re.findall('\d+', json_scripts[i]['line'][0])[0])
    num_lines = len(json_scripts[i]['line'])
    num_check = df_lc[df_lc.ep_num == ep_num].line_count.iloc[0]
    
    if (num_lines != num_check):
        print('ep_num: ', ep_num, ' ', num_lines, ' ', num_check)

# %%
# Calling the DataFrame "df1" because it will undrgo some currently unknown number of cleaning operations and re-saves
df1 = pd.DataFrame(json_scripts[0])

for i in range(1, len(json_scripts)):
    df1 = pd.concat([df1, pd.DataFrame(json_scripts[i])])

# %%
df1.shape
# Out:
# (141031, 2)

# %%
# Not sure why this mismatch exists. Investigate after creation of MVP
141031 - 140288
# Out:
# 743

# %%
df1.head()
# Out:
#                                                 line line_index
# 0                    Episode 1 - Good News, Bad News        1_0
# 1  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tpc...        1_1
# 2  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tBr...        1_2
# 3  \n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t(T...        1_3
# 4                             \n\t\t\t\t\t\t\t\t\t\t        1_4

# %% [markdown]
# ### Clean Seinfeld DataFrame

# %%
# Remove '\n' and '\t' characters from the lines
df1['line'] = df1.line.str.replace('\\n','')
df1['line'] = df1.line.str.replace('\\t','')

# %%
# Remove all rows that are not either lines or text denoting a new scene
# Upon inspecting the data, I found that the first 11 episodes have text beginning with 'INT.' to denote a new scene,
# and the rest of the episodes contain text enclosed in square brackets

cond_line = df1.line.str.contains(':')
cond_scene1 = df1.line.str.startswith('INT.')
cond_scene2 = df1.line.str.startswith('[')

# %%
# Apply conditions defined in above cell
mask = (cond_line | cond_scene1 | cond_scene2)
df2 = df1[mask]

# %%
df2.iloc[:5]
# Out:
#                                     line line_index
# 1   pc: 101, season 1, episode 1 (Pilot)        1_1
# 2           Broadcast date: July 5, 1989        1_2
# 11                             Regulars:       1_11
# 16                          Guest Stars:       1_16
# 24              INT. COMEDY CLUB  NIGHT       1_24

# %%
# Looking at the rows returned above, additional conditions are to be imposed on the data:
# Row shouldn't contain both "season" and "episode"
# Row shouldn't contain "Broadcast date:"
# Row shouldn't end with a colon
# An alternate strategy would be to create a whitelist of character names that appear before colons in lines
# and use that whitelist to filter the data (while also including scene breaks)

cond_sn_ep = ~(df2.line.str.contains("season") & df2.line.str.contains("episode"))
cond_bdcast = ~df2.line.str.contains("Broadcast")
cond_colon = df2.line.map(lambda x: x[-1] != ":")

# %%
# Apply conditions defined in above cell
mask = (cond_sn_ep & cond_bdcast & cond_colon)
df3 = df2[mask]

# %%
df3.head()
# Out:
#                                                  line line_index
# 24                           INT. COMEDY CLUB  NIGHT       1_24
# 28  JERRY: Do you know what this is all about? Do ...       1_28
# 32                     INT. PETES LUNCHEONETTE  DAY       1_32
# 36  JERRY: (pointing at Georges shirt) See, to me...       1_36
# 38                          GEORGE: Are you through?        1_38

# %%
df3.tail()
# Out:
#                                                   line line_index
# 813  JERRY: Now thats not fair! So where did you m...      2_813
# 815              ELAINE: I staked out his health club.      2_815
# 817  JERRY: Uh huh. When youre on a stakeout, do y...      2_817
# 823                           INT. COMEDY CLUB  NIGHT      2_823
# 827  JERRY: Yknow I think that even if youve had ...      2_827

# %%
# Before the scene number is assigned to each line, ep_num and line_num are split and converted to integer
# These two new columns functionally replace the col 'line_index'
df4 = (df3
       .assign(ep_num = [int(x[0]) for x in df3.line_index.str.split("_")],
               line_num_orig = [int(x[1]) for x in df3.line_index.str.split("_")])
       .drop('line_index', axis = 1)
       .sort_values(['ep_num', 'line_num_orig'])
      )
df4.head()
# Out:
#                                                  line  ep_num  line_num_orig
# 24                           INT. COMEDY CLUB  NIGHT       1             24
# 28  JERRY: Do you know what this is all about? Do ...       1             28
# 32                     INT. PETES LUNCHEONETTE  DAY       1             32
# 36  JERRY: (pointing at Georges shirt) See, to me...       1             36
# 38                          GEORGE: Are you through?        1             38

# %%
# %%time

# To make this more pythonic, use reduce()?
# FIX TO RESET NUM WHEN EPISODE CHANGES!
new_scene = []
scene_num = []
num = 0
last_episode = 0

for ind, val in df4.iterrows():
    new_bool = (val.line.find("INT.") != -1) | (val.line.find("[") == 0)
    new_scene.append(new_bool)
    
    num += int(new_bool)
    
    if val.ep_num > last_episode:
        num = 1

    scene_num.append(num)
    
    last_episode = val.ep_num
# Out:
# CPU times: user 7.67 s, sys: 61.5 ms, total: 7.73 s
# Wall time: 8.13 s

# %%
# Just checking...
print(len(new_scene))
print(len(scene_num))
df4.shape
# Out:
# 57575
# 57575
# (57575, 3)

# %%
df5 = df4.assign(scene_num = scene_num)
df5.head(100)
# Out:
#                                                   line  ep_num  line_num_orig  \
# 24                            INT. COMEDY CLUB  NIGHT       1             24
# 28   JERRY: Do you know what this is all about? Do ...       1             28
# 32                      INT. PETES LUNCHEONETTE  DAY       1             32
# 36   JERRY: (pointing at Georges shirt) See, to me...       1             36
# 38                           GEORGE: Are you through?        1             38
# 40       JERRY: You do of course try on, when you buy?       1             40
# 42   GEORGE: Yes, it was purple, I liked it, I don...       1             42
# 44                        JERRY: Oh, you dont recall?       1             44
# 46   GEORGE: (on an imaginary microphone) Uh, no, n...       1             46
# 48   JERRY: Well, senator, Id just like to know, w...       1             48
# 52                CLAIRE: Mr. Seinfeld. Mr. Costanza.        1             52
# 56   GEORGE: Are, are you sure this is decaf? Where...       1             56
# 58   CLAIRE: Its missing, I have to do it in my he...       1             58
# 60   JERRY: Can you relax, its a cup of coffee. Cl...       1             60
# 62   CLAIRE: Trust me George. No one has any intere...       1             62
# 66   GEORGE: How come youre not doin the second s...       1             66
# 68   JERRY: Well, theres this uh, woman might be c...       1             68
# 70   GEORGE: Wait a second, wait a second, what com...       1             70
# 72   JERRY: I told you about Laura, the girl I met ...       1             72
# 74                             GEORGE: No, you didnt!       1             74
# 76   JERRY: I thought I told you about it, yes, she...       1             76
# 78                                         GEORGE: Ha.       1             78
# 80   JERRY: (looks in the creamer) Theres no milk ...       1             80
# 82   GEORGE: Wait wait wait, what is she... (takes ...       1             82
# 84   JERRY: Oh, shes really great. I mean, shes g...       1             84
# 86   GEORGE: (smiling) So, you know, what, what hap...       1             86
# 88   JERRY: Oh, nothing happened, you know, but is ...       1             88
# 90         GEORGE: Oh, nothing happened, but it was...       1             90
# 92                                        JERRY: Yeah.       1             92
# 94                              GEORGE: This is great!       1             94
# ..                                                 ...     ...            ...
# 190  GEORGE: I cant believe- (falls on his knees) ...       1            190
# 192         JERRY: Yeah, but how could you be so sure?       1            192
# 194  GEORGE: Cause its signals, Jerry, its signa...       1            194
# 196                                         JERRY: No.       1            196
# 198  GEORGE: She calls you today and she doesnt ma...       1            198
# 200                                       JERRY: Yeah.       1            200
# 202  GEORGE: What is that? Its ridiculous! You don...       1            202
# 204                         JERRY: Maybe youre right.       1            204
# 206      GEORGE: Maybe Im right? Of course Im right.       1            206
# 208  JERRY: This is insane. You know, I dont even ...       1            208
# 212  GEORGE: I know, I know. Listen, your stuff has...       1            212
# 214  JERRY: No no no, dont interrupt the cycle. Th...       1            214
# 216                   GEORGE: Youre gonna overdry it.       1            216
# 218                     JERRY: You, you cant overdry.       1            218
# 220                                   GEORGE: Why not?       1            220
# 222  JERRY: Same as you cant overwet. You see, onc...       1            222
# 224  GEORGE: (to the other laundry patrons) Any que...       1            224
# 226  JERRY: How could she not tell me where she was...       1            226
# 230               GEORGE: Look at that. Theyre done!        1            230
# 234                           INT. COMEDY CLUB  NIGHT       1            234
# 238  JERRY: Laundry day is the only exciting day in...       1            238
# 242                             INT. JERRYS APARTMENT       1            242
# 246  JERRY: (answering, quickly) If you know what h...       1            246
# 250                         JERRY: (to the door) Yeah?       1            250
# 254                               KESSLER: Are you up?       1            254
# 256  JERRY: (to Kessler) Yeah. (to the phone) Yeah,...       1            256
# 260      KESSLER: Boy, the Mets blew it tonight, huh?        1            260
# 262  JERRY: (upset) Ohhhh, what are you doing? Kess...       1            262
# 264  KESSLER: Hey, Im sorry, I- you know, I, I tho...       1            264
# 266  JERRY: Meat? I dont, I dont know, go... hunt...       1            266
#
#      scene_num
# 24           1
# 28           1
# 32           2
# 36           2
# 38           2
# 40           2
# 42           2
# 44           2
# 46           2
# 48           2
# 52           2
# 56           2
# 58           2
# 60           2
# 62           2
# 66           2
# 68           2
# 70           2
# 72           2
# 74           2
# 76           2
# 78           2
# 80           2
# 82           2
# 84           2
# 86           2
# 88           2
# 90           2
# 92           2
# 94           2
# ..         ...
# 190          3
# 192          3
# 194          3
# 196          3
# 198          3
# 200          3
# 202          3
# 204          3
# 206          3
# 208          3
# 212          3
# 214          3
# 216          3
# 218          3
# 220          3
# 222          3
# 224          3
# 226          3
# 230          3
# 234          4
# 238          4
# 242          5
# 246          5
# 250          5
# 254          5
# 256          5
# 260          5
# 262          5
# 264          5
# 266          5
#
# [100 rows x 4 columns]

# %%
# Define a function determine_line that returns true if and only if the line begins with a letter and it also
# does not begin with "INT."
# This will be used to filter out "lines" that set a new scene or describe what is happening
# (The first 11 episodes use "INT." instead of "[" to denote a new scene)
def determine_line(x):
    a = bool(re.match('^[A-Za-z]', x))
    b = a and not bool(re.match('^INT.', x))
    
    return b
             
real_line = list(map(determine_line, df5.line))         

print(len(real_line))
print(real_line[:5])
# Out:
# 57575
# [False, True, False, True, True]

# %%
# Now let's apply the filter created in the cell above
df6 = df5[real_line]
df6.head()
# Out:
#                                                  line  ep_num  line_num_orig  \
# 28  JERRY: Do you know what this is all about? Do ...       1             28
# 36  JERRY: (pointing at Georges shirt) See, to me...       1             36
# 38                          GEORGE: Are you through?        1             38
# 40      JERRY: You do of course try on, when you buy?       1             40
# 42  GEORGE: Yes, it was purple, I liked it, I don...       1             42
#
#     scene_num
# 28          1
# 36          2
# 38          2
# 40          2
# 42          2

# %%
# Now let's add a new line_num column
line_num = df6.assign(ones = 1).groupby(by=['ep_num', 'scene_num']).ones.cumsum()
df7 = (df6
       .assign(line_num = line_num)
       .rename(index=str, columns={"line": "line_old"}) #set-up for next step
       )
df7.head()
# Out:
#                                              line_old  ep_num  line_num_orig  \
# 28  JERRY: Do you know what this is all about? Do ...       1             28
# 36  JERRY: (pointing at Georges shirt) See, to me...       1             36
# 38                          GEORGE: Are you through?        1             38
# 40      JERRY: You do of course try on, when you buy?       1             40
# 42  GEORGE: Yes, it was purple, I liked it, I don...       1             42
#
#     scene_num  line_num
# 28          1         1
# 36          2         1
# 38          2         2
# 40          2         3
# 42          2         4

# %%
# Move the character to it's own column
character = df7.line_old.apply(lambda x: x[:x.find(':')])
line = df7.line_old.apply(lambda x: x[x.find(':')+1:].strip())

df8 = (df7
      .assign(character = character,
              line = line)
      .drop('line_old', axis = 1)
      .drop('line_num_orig', axis = 1))
df8.head()
# Out:
#     ep_num  scene_num  line_num character  \
# 28       1          1         1     JERRY
# 36       1          2         1     JERRY
# 38       1          2         2    GEORGE
# 40       1          2         3     JERRY
# 42       1          2         4    GEORGE
#
#                                                  line
# 28  Do you know what this is all about? Do you kno...
# 36  (pointing at Georges shirt) See, to me, that ...
# 38                                   Are you through?
# 40             You do of course try on, when you buy?
# 42  Yes, it was purple, I liked it, I dont actual...

# %%
# To do: take out () and text therein from character (in addition to line) (only drewback is converting ALL (except [CHAR]) to ALL),
# replace '\x91' and other '\x's' (92)
# could also filter that CHAR == CHAR.to_upper() - well, some ELAINE (and JERRY) lines would be filtered out without furth proc
# 
# A couple of actual lines still made it into the CHAR list - just filter them out?
char_list = df8.character.sort_values().unique()
print(len(char_list))
list(char_list)
# Out:
# 1533
# ['AARON',
#  'AARON & HELEN',
#  'ABBY',
#  'ADA',
#  'ADAM',
#  'ADE',
#  'AENT',
#  'AGENCY REP',
#  'AGENT',
#  'AL',
#  'AL ROKER',
#  'ALAN',
#  'ALEC',
#  'ALEX',
#  'ALEX TREBEK',
#  'ALICIA',
#  'ALISON',
#  'ALL',
#  'ALL (EXCEPT MORTY)',
#  'ALL (chanting)',
#  'ALL (singing)',
#  'ALL (singing, competing)',
#  'ALL FOUR MEN',
#  'ALL THREE',
#  'ALLBRIGHT (O.C.)',
#  'ALLISON',
#  'ALLSION',
#  'ALTON',
#  'AMANDA',
#  'AMY',
#  'ANGELA',
#  'ANGRY MAN',
#  'ANNA',
#  'ANNOUNCEMENT',
#  'ANNOUNCER',
#  'ANNOUNCER #1',
#  'ANNOUNCER #2',
#  'ANNOUNCER ON P.A. SYSTEM',
#  'ANNOUNCER ON TV',
#  'ANSWERING MACHINE',
#  'ANTONIO',
#  'APPLICANT',
#  'ARNIE',
#  'ARONSON',
#  'ARTIE',
#  'ASSISTANT',
#  'ASSISTANT DRESSER',
#  'ATTENDANT',
#  'ATTENDANT #1',
#  'ATTENDANT #2',
#  'AUCTIONEER',
#  'AUDIENCE',
#  'AUDREY',
#  'AUNT MAY',
#  'AVA',
#  'Announcer',
#  'Another man',
#  'BABS',
#  'BABU',
#  "BABU'S BROTHER",
#  "BABU'S FRIEND",
#  'BAILIFF',
#  'BANIA',
#  'BANK EMPLOYEE',
#  'BARBARA',
#  "BARNEY'S SALES ASSOCIATE",
#  'BARRY',
#  'BARTENDER',
#  'BECK',
#  'BECKY',
#  'BEN',
#  'BENES',
#  'BETH',
#  'BETSY',
#  'BETSY (sweetly)',
#  'BETSY (to Aunt May)',
#  'BETTE',
#  'BIKER',
#  'BILL',
#  'BILLY',
#  'BLAINE',
#  'BLIND MAN',
#  'BLIND VIOLIN PLAYER',
#  'BOB',
#  'BOBBY',
#  'BOMB COP',
#  'BONNIE',
#  'BOOKIE',
#  'BOOKMAN',
#  'BOOKMAN (emerging)',
#  'BOSS',
#  "BOSS' WIFE",
#  'BOTH',
#  'BOUNCER',
#  'BOY',
#  'BOYFRIEND',
#  'BRADY',
#  'BRETT',
#  'BRIDGET',
#  'BRODY',
#  'BRUCE',
#  'BRUCE (holding a phone)',
#  'BRUCE (laughing)',
#  'BRYANT',
#  'BUBBLE BOY',
#  'BUCKLES',
#  'BUDDY',
#  'BUILDING A',
#  'BUILDING B',
#  'BUILDING C',
#  'BUSINESS MAN',
#  'BUSINESSMAN',
#  'BUXOM WOMAN',
#  'BUZZER',
#  'BYSTANDER #1',
#  'BYSTANDER #2',
#  'Babu Bhatt',
#  'Banker',
#  'Beginnings',
#  'Boysenberry',
#  'Bruce (laughing)',
#  'C.K.',
#  'CAB DRIVER',
#  'CABBIE',
#  'CABBY',
#  'CALVIN KLEIN',
#  'CANDICE BERGEN',
#  'CAPTAIN',
#  'CAR SALESMAN',
#  'CAR THIEF',
#  'CAR WASHER',
#  'CARL',
#  'CARL (hands Jerry an invoice)',
#  'CARL (off-camera)',
#  'CAROL',
#  'CAROL (shows Elaine and the girls pictures of Adam)',
#  'CARRERAS',
#  'CARRIE',
#  'CASHIER',
#  'CASHIER (Ruthie Cohen)',
#  'CASTING DIRECTOR',
#  'CASTRO',
#  'CEDRIC',
#  'CELIA',
#  'CHAIRMAN',
#  'CHARLES',
#  'CHARLIE',
#  'CHARMAINE',
#  'CHAUFFEUR',
#  'CHELSEA',
#  'CHERYL',
#  'CHILES',
#  'CHIROPRACTOR',
#  'CHOATE',
#  'CHRISTIE',
#  'CINDY',
#  'CLAIE',
#  'CLAIRE',
#  'CLARE',
#  'CLAYTON',
#  'CLEANING WOMAN',
#  'CLERK',
#  'CLERK (checking the computer)',
#  'CLERK (to Kramer)',
#  'CLERK 2',
#  'CLERK\x92S VOICE (off camera)',
#  'CLICKY',
#  'CLOTWORTHY',
#  'CLUB ANNOUNCER',
#  'CLYDE',
#  'CO-WORKER',
#  'CO-WORKER #1',
#  'CO-WORKER #2',
#  'COCO',
#  'COMPUTER VOICE',
#  'CONNIE',
#  'CONRAD',
#  'CONTEST WINNER',
#  'CONTEST WINNER (to Elaine)',
#  'COP',
#  'COP #1',
#  'COP #2',
#  'COP 2',
#  'COPS',
#  'CORBIN BERNSEN',
#  'CORINNE',
#  'COUNTER WOMAN',
#  'COUNTERPERSON',
#  'COWORKER',
#  'CRAIG',
#  'CRESPI',
#  'CREW LEADER',
#  'CROWD',
#  'CUSTOMER',
#  'CYNTHIA',
#  'Check #1246, dated Dec. 15 \x9196, Made out to',
#  'Claims to Fame',
#  'DAN',
#  'DANA',
#  'DANA (unenthusiastic)',
#  'DANIELLE',
#  'DANNY TARTABULL',
#  'DAPHNE',
#  'DARREN',
#  'DARRYL',
#  'DAVID',
#  'DAVOLA',
#  'DAVOLA (O.C.)',
#  'DEAN JONES',
#  'DEBBY',
#  'DEENA',
#  'DEENSFREI',
#  'DELIVERY BOY',
#  'DELIVERY GUY',
#  'DELIVERY MAN',
#  'DENIM VEST',
#  'DENISE',
#  'DENNIS',
#  'DENTIST',
#  'DEPUTY',
#  'DETECTIVE',
#  'DETECTIVE #1 (to Kurt)',
#  'DETECTIVE #2',
#  'DETECTIVE #2 (to Kurt)',
#  'DETECTIVE (V.O.)',
#  'DEVOLA',
#  'DIANE',
#  'DICK',
#  'DIRECTOR',
#  'DISPATCHER',
#  'DJ ON RADIO',
#  'DOCTER',
#  'DOCTOR',
#  'DOCTOR (O.C.)',
#  'DOG OWNER',
#  'DOLL',
#  'DOLORES',
#  'DONALD',
#  'DONNA',
#  'DONNA ',
#  'DOORMAN',
#  'DOORMAN 2',
#  'DORIS',
#  'DR. ALLENWOOD',
#  'DR. BAKERSOLL',
#  'DR. COOPERMAN',
#  'DR. DEMBROW',
#  'DR. RESTON',
#  'DR. WEXLER',
#  'DRIVER',
#  'DRY CLEANE',
#  'DRY CLEANER',
#  'DUGAN',
#  'DUNCAN',
#  'DUNCAN & JERRY',
#  'DUSTIN',
#  'DUSTIN - Locker room Attendant #2',
#  'DWAYNE',
#  'Dedication',
#  'Driver',
#  'Dugan',
#  'Dx',
#  'EALINE',
#  'EARL',
#  'ECHO',
#  'ED',
#  'EDDIE',
#  'EDDIT',
#  'EGO',
#  'ELAIEN',
#  'ELAINE',
#  'ELAINE ',
#  'ELAINE & GEORGE',
#  'ELAINE & JERRY',
#  'ELAINE & PUDDY',
#  'ELAINE & RAY',
#  'ELAINE (Gives him the money)',
#  'ELAINE (O.C.)',
#  'ELAINE (V.O.)',
#  'ELAINE (absolutely disgusted)',
#  'ELAINE (amused)',
#  'ELAINE (angrily)',
#  'ELAINE (beaming)',
#  'ELAINE (deaf)',
#  'ELAINE (enunciating clearly so George gets the point)',
#  'ELAINE (examining the socks)',
#  'ELAINE (excited)',
#  'ELAINE (fed up)',
#  'ELAINE (flirtatiously)',
#  'ELAINE (getting up to leave)',
#  'ELAINE (grabs the papers from Jerry)',
#  'ELAINE (gushing)',
#  'ELAINE (happily)',
#  'ELAINE (humoring her)',
#  'ELAINE (imitating Toby)',
#  'ELAINE (in a dreadful tone)',
#  'ELAINE (in a southern accent)',
#  'ELAINE (irritated, imitates Gail)',
#  'ELAINE (laughing)',
#  'ELAINE (laughs)',
#  'ELAINE (leaning forward)',
#  'ELAINE (looking in the fridge)',
#  'ELAINE (looks at Jerry and smears lipstick across her face)',
#  'ELAINE (modest)',
#  'ELAINE (mouths the words)',
#  'ELAINE (nodding)',
#  'ELAINE (nudges George with her elbow)',
#  'ELAINE (offended)',
#  'ELAINE (on the witness stand)',
#  "ELAINE (pulling up Pitt's socks)",
#  "ELAINE (put off by Toby's exuberance)",
#  'ELAINE (putting on lipstick)',
#  'ELAINE (puzzled)',
#  'ELAINE (signing)',
#  'ELAINE (singing)',
#  'ELAINE (sitting down)',
#  'ELAINE (smiling)',
#  'ELAINE (smug)',
#  'ELAINE (standing in the doorway)',
#  'ELAINE (standing up)',
#  'ELAINE (stands up)',
#  'ELAINE (stretches)',
#  'ELAINE (surprised)',
#  'ELAINE (thinking to herself)',
#  'ELAINE (thinking)',
#  'ELAINE (through her teeth)',
#  'ELAINE (through teeth)',
#  'ELAINE (throws the script at Jerry)',
#  'ELAINE (to Carl)',
#  'ELAINE (to Carl, flirtatiously)',
#  'ELAINE (to George)',
#  'ELAINE (to Jerry)',
#  'ELAINE (to Jerry, imitating Carol)',
#  'ELAINE (to Kramer)',
#  'ELAINE (to Poppie)',
#  'ELAINE (to Russell)',
#  'ELAINE (to a woman at the fight)',
#  "ELAINE (tries to snatch food off a waiter's tray)",
#  'ELAINE (turning on George)',
#  'ELAINE (uninterested)',
#  'ELAINE (warns)',
#  'ELAINE (wearily)',
#  'ELAINE (whispering)',
#  'ELAINE (with little hope)',
#  'ELAINE (yelling)',
#  'ELAINE AND JERRY',
#  'ELAINE AND PUDDY',
#  'ELAINE and KRAMER',
#  "ELAINE'S VOICE",
#  "ELAINE's brain",
#  'ELAINE/DAVOLA',
#  'ELAINE/JERRY',
#  'ELAINE/WENDY',
#  'ELANE',
#  'ELDRIDGE',
#  'ELECTRICIAN',
#  'ELIANE',
#  'ELLEN',
#  'EMILY',
#  'EMPLOYEE',
#  'ENZO',
#  'ERIC',
#  'ESTELLE',
#  'ESTELLE (crying)',
#  'ESTELLE (smiling)',
#  'ETHAN',
#  'EULOGIST',
#  'EVA',
#  'EVELYN',
#  'EVERYBODY',
#  'EVERYONE',
#  'EXECUTIVE 1',
#  'EXECUTIVE 2',
#  'ElainELAINE',
#  'Elaine',
#  'Elaine (answering)',
#  'Elaine (hanging up)',
#  "Elaine (thinking it's Dan)",
#  'Elaine + JERRY',
#  'Elaine thinking',
#  'Elaine, becoming board',
#  'Ex',
#  'FAN',
#  'FAN #1',
#  'FARKUS',
#  'FARMER',
#  'FATHER',
#  'FATHER CURTIS',
#  'FATHER HERNANDEZ',
#  'FATHER JESSUP',
#  'FATHER-PRIEST',
#  'FATHER-PRIEST 2',
#  'FDR',
#  'FELDMAN',
#  'FEMALE CUSTOMER',
#  'FEMALE WORKER',
#  'FIREMAN',
#  'FLIGHT ATTENDANT',
#  'FLORIST',
#  'FOREMAN',
#  'FOWLER',
#  'FRANK',
#  'FRANK (from the answering machine)',
#  'FRANK (yelling)',
#  'FRANKIE',
#  'FRED',
#  'FRED (a little frightened and backing away towards the door)',
#  'FRED SAVAGE',
#  'FRIEND',
#  'FRIEND 1',
#  'FULTON',
#  'FURNITURE GUY',
#  'Frank (picking up his shoes)',
#  'Frank Costanza',
#  'Frank and ESTELLE',
#  'GAIL',
#  'GAIL (hands a plate to another chef)',
#  'GAIL (impressed)',
#  'GAIL (to Elaine)',
#  'GAIL (to Jerry)',
#  'GARDNER',
#  'GARY',
#  'GAS STATION ATTENDANT',
#  'GAURD',
#  'GAVIN',
#  'GENE',
#  'GENNICE',
#  'GEOGE',
#  'GEORGE',
#  'GEORGE ',
#  'GEORGE & ELAINE',
#  'GEORGE & JERRY',
#  'GEORGE & KRAMER',
#  'GEORGE (Counting on his fingers)',
#  'GEORGE (O.C.)',
#  'GEORGE (O.S.)',
#  'GEORGE (V.O.)',
#  'GEORGE (angrily)',
#  'GEORGE (apologetic)',
#  'GEORGE (attempting to make a move)',
#  'GEORGE (beaming)',
#  'GEORGE (boasting)',
#  'GEORGE (chuckles)',
#  "GEORGE (clears his throat, annoyed that the movie's being interrupted)",
#  'GEORGE (close to tears)',
#  'GEORGE (comes out of the bathroom brushing his teeth)',
#  'GEORGE (defensive)',
#  'GEORGE (disappointed)',
#  "GEORGE (examining Kurt's head with a lamp)",
#  'GEORGE (from backstage)',
#  'GEORGE (from the bathroom)',
#  'GEORGE (giddy)',
#  'GEORGE (grabs the M&M away from Jerry)',
#  'GEORGE (holds up one finger)',
#  'GEORGE (immediately, to Elaine)',
#  'GEORGE (irritated)',
#  'GEORGE (laughing)',
#  'GEORGE (lazily swinging the garbage bag around)',
#  'GEORGE (loading up his plate with sandwiches)',
#  "GEORGE (looking at Kramer's arm)",
#  'GEORGE (looking over)',
#  'GEORGE (looks at his watch)',
#  'GEORGE (meekly)',
#  'GEORGE (mocking Jerry)',
#  'GEORGE (nervously)',
#  "GEORGE (notices Russell's lunch)",
#  "GEORGE (noticing Jerry's suitcase)",
#  'GEORGE (nudges Elaine with his elbow)',
#  'GEORGE (on a pay phone)',
#  'GEORGE (on intercom)',
#  'GEORGE (overjoyed to find out)',
#  'GEORGE (pulls over)',
#  'GEORGE (sadly)',
#  'GEORGE (shakes huge keyring)',
#  'GEORGE (singing)',
#  'GEORGE (sniffling)',
#  'GEORGE (solemnly)',
#  'GEORGE (suddenly interested)',
#  'GEORGE (thinking)',
#  'GEORGE (to Elaine)',
#  'GEORGE (to Elaine, in a somber tone)',
#  'GEORGE (to Jerry)',
#  'GEORGE (to Kramer)',
#  'GEORGE (to Lupe)',
#  'GEORGE (to clerk)',
#  'GEORGE (to guy)',
#  'GEORGE (to himself)',
#  'GEORGE (to the EMTs)',
#  'GEORGE (tosses the condom aside)',
#  'GEORGE (unimpressed)',
#  'GEORGE (voice is hoarse from screaming)',
#  'GEORGE (whistles to guy on phone)',
#  'GEORGE (writing on a notepad)',
#  'GEORGE (yelling at her)',
#  'GEORGE AND JERRY',
#  'GEORGE WENDT',
#  'GEORGE WENDT (checking his watch, obviously uncomfortable)',
#  "GEORGE'S VOICE",
#  'GEORGE, ELAINE, KRAMER, JERRY, & STAN',
#  'GEORGE/JERRY/ELAINE/WENDY',
#  'GEORGE/SUSAN',
#  'GEPETTO',
#  'GERMAN WOMAN',
#  'GEROGE',
#  'GIGGIO',
#  'GILLIAN',
#  'GINA',
#  'GINO',
#  'GIRL',
#  'GIRL (NOT WINONA)',
#  'GIRLFRIEND',
#  'GIULIANI',
#  'GLADYS',
#  'GLENDA',
#  'GLENN',
#  'GOERGE',
#  'GRANDPA (to Anna)',
#  'GREENY',
#  'GREG',
#  'GREG (hands the bottle back)',
#  'GREG (looks at his watch)',
#  'GREG (to Elaine)',
#  'GROSSBARD',
#  'GROUP',
#  'GUAD',
#  'GUARD',
#  'GUESTS, JERRY & ELAINE',
#  'GUILLERMO',
#  'GUY',
#  'GUY ON PHONE',
#  'GWEN',
#  'GX',
#  'Genderson',
#  'Guy1',
#  'HAARWOOD',
#  'HAFFLER',
#  'HAIRDRESSER',
#  'HAL',
#  'HALLIE',
#  'HANKE',
#  'HAROLD',
#  'HEAD',
#  'HEAD (O.C.)',
#  'HEALTH INSPECTOR',
#  'HELEN',
#  'HELEN & AARON',
#  'HELEN & MORTY',
#  'HELEN (V.O)',
#  'HELEN (in Florida with Morty)',
#  'HELEN (to Jerry)',
#  'HELENA',
#  'HENRY',
#  'HERB',
#  'HEYMAN',
#  'HIGH PITCHED VOICE',
#  'HILDE',
#  'HIPPIE #1',
#  'HIPPIE #2',
#  'HOLE DIGGER',
#  'HOLE DIGGER #2',
#  'HOLLY',
#  'HOMELESS MAN',
#  'HOMELESS MAN 2',
#  'HOOKER',
#  'HORST',
#  'HOSPITAL VOICEOVER',
#  'HOSTESS',
#  'HOT DOG VENDOR',
#  'HOTEL CLERK',
#  'HOUSEKEEPER',
#  'HOYT',
#  'HUSBAND',
#  'Huckleberry',
#  'Hx',
#  'I always feel bad for the silver medal winner in the Olympics. How do you live with that the rest of your life? People are gonna keep asking',
#  "I always get confused in the movie theater by the, by the plot. It's embarrassing. It's an embarrassment to have to admit, but I'm the one that you see in the parking lot after the movie talking with his friends, going",
#  'I am not gay. I am, however, thin, single and neat. Sometimes when someone is thin, single and neat people assume they are gay because that is a stereotype. They normally don\'t think of gay people as fat, sloppy and married. Although I\'m sure there are, I don\'t want to perpetuate the stereotype. I\'m sure they are the minority though within the gay community. They\'re probably discriminated against because of that, people say to them "Y\'know Joe, I enjoy being gay with you but I think think it\'s about time, y\'know that you got in shape, tucked the shirt in and lost the wife". But if people are even going to assume that people that are neat are gay, maybe instead of doin\' this',
#  'I think the thing I admire most about the Chinese is that they\'re hanging in there with the chopsticks. Because, if you think about it, you know, they\'ve seen the fork... by now. I\'m sure they\'ve seen the spoon, they\'re going, "Yeah, yeah, they\'re OK... We\'re going to stay with the sticks." I mean, I don\'t know how they\'ve missed it',
#  'IAN',
#  'ICE CREAM VENDER #1',
#  'ICE CREAM VENDER #2',
#  'ILENE',
#  'ISAAC',
#  'ISABEL',
#  'IZZY',
#  'IZZY & IZZY JR.',
#  'IZZY IZZY SR.. (O.C.)',
#  'IZZY JR.',
#  'IZZY SR.',
#  'IZZY/IZZY JR/IZZY IZZY SR.',
#  'Inside Kew Gardens Reprinted from an article in the October 1982 issue of Metropolis Magazine. http',
#  'J. PETERMAN',
#  'JACK',
#  'JACKIE',
#  'JACKIE ',
#  'JACKIE (impressed)',
#  'JACKIE (speaking to the intercom)',
#  'JACKIE (to Kramer and Stan)',
#  'JAKE',
#  'JAMES',
#  'JANE',
#  'JANET',
#  'JANICE',
#  'JAY',
#  'JAY LENO',
#  'JEAN-PAUL',
#  'JEANINE',
#  'JEANNIE',
#  'JEFF',
#  'JENNA',
#  'JENNA (O.C.)',
#  'JENNY',
#  'JERR',
#  'JERRY',
#  'JERRY ',
#  'JERRY & COP',
#  'JERRY & ELAINE',
#  'JERRY & GEORGE',
#  'JERRY & George',
#  'JERRY & JEANNIE',
#  'JERRY & KRAMER',
#  'JERRY & TIA',
#  'JERRY (O.C.)',
#  'JERRY (V.O)',
#  'JERRY (V.O.)',
#  'JERRY (angrily)',
#  'JERRY (answering phone)',
#  'JERRY (applauding)',
#  "JERRY (attempting to carry on despite Toby's interruptions)",
#  'JERRY (catches Elaine)',
#  "JERRY (clearly creeped out by having to shake Poppie's hand)",
#  "JERRY (comes out of the bedroom with Poppie's money)",
#  'JERRY (copying down the number)',
#  'JERRY (copying it down and grinning)',
#  'JERRY (dialing)',
#  'JERRY (doubtfully)',
#  'JERRY (exasperated)',
#  'JERRY (excited)',
#  'JERRY (frantic)',
#  'JERRY (from his bedroom hallway, alluding to the fact that she should get the drink herself)',
#  'JERRY (from inside the bathroom)',
#  'JERRY (from outside the door)',
#  'JERRY (getting out of bed)',
#  'JERRY (giving in)',
#  'JERRY (hesitant)',
#  'JERRY (holds up the syrup bottle)',
#  'JERRY (hoping Leo will pick up on the scam)',
#  'JERRY (indifferent)',
#  'JERRY (interrupts)',
#  'JERRY (irritated)',
#  "JERRY (leaving a message on Elaine's machine)",
#  'JERRY (looking at the puddle with Kramer)',
#  'JERRY (looking in a drawer)',
#  'JERRY (looking through some papers on the desk)',
#  'JERRY (looks at his watch)',
#  'JERRY (low voice)',
#  'JERRY (making fun)',
#  'JERRY (mesmerized)',
#  'JERRY (mimics smoking an "after sex cigarette")',
#  'JERRY (nonplussed)',
#  'JERRY (not happy)',
#  'JERRY (noticing something across the coffee shop)',
#  'JERRY (offers a hot dog to Miss Rhode Island)',
#  'JERRY (opens the envelope)',
#  'JERRY (patiently while watching tv)',
#  'JERRY (picks up a yellow M&M toy from the model)',
#  'JERRY (picks up the phone)',
#  'JERRY (pointing at the trophy)',
#  'JERRY (points at the Power Ranger)',
#  'JERRY (points)',
#  'JERRY (proudly)',
#  'JERRY (rolls his eyes)',
#  'JERRY (sarcastic)',
#  'JERRY (sarcastically)',
#  'JERRY (sees a white couch by the wall)',
#  'JERRY (shrugs)',
#  'JERRY (shudders)',
#  'JERRY (shuts the car door)',
#  'JERRY (signing)',
#  'JERRY (sits down)',
#  'JERRY (slams the drawer)',
#  'JERRY (slowly)',
#  'JERRY (smiling)',
#  'JERRY (standing)',
#  'JERRY (still trying to remember)',
#  'JERRY (takes out his wallet)',
#  'JERRY (thinks)',
#  'JERRY (to Elaine)',
#  'JERRY (to Farfel)',
#  'JERRY (to George)',
#  'JERRY (to George, hugs Kramer happily)',
#  'JERRY (to Karen)',
#  'JERRY (to Kevin)',
#  'JERRY (to Kramer)',
#  'JERRY (to Lena)',
#  'JERRY (to Meryl)',
#  "JERRY (to Meryl, who's making a racket in the kitchen looking for the can opener)",
#  'JERRY (to Pam)',
#  'JERRY (to waitress)',
#  'JERRY (toasts with his orange juice)',
#  'JERRY (turning to leave)',
#  'JERRY (under his breath, to a man at the party)',
#  'JERRY (using Elaine as an example)',
#  "JERRY (wipes Kramer's brow)",
#  'JERRY (yelling from his room)',
#  'JERRY AND ELAINE',
#  'JERRY AND ELAINE (together)',
#  'JERRY AND GEORGE',
#  'JERRY AND JOEL',
#  'JERRY AND KRAMER',
#  'JERRY AND NEWMAN',
#  'JERRY and ELAINE',
#  'JERRY and ELAINE, together',
#  'JERRY and GEORGE',
#  'JERRY and KRAMER',
#  'JERRY and NEWMAN',
#  'JERRY&ELAINE',
#  "JERRY'S ANSWERING MACHINE",
#  "JERRY'S BRAIN",
#  "JERRY'S MACHINE",
#  "JERRY'S PENIS",
#  "JERRY'S brain",
#  "JERRY's brain",
#  'JERRY(MIND)',
#  'JERRY, GEORGE & ELAINE',
#  'JERRY, GEORGE & KRAMER',
#  'JERRY, GEORGE, & KRAMER',
#  'JERRY, GEORGE, ELAINE',
#  'JERRY, KRAMER & NEWMAN',
#  'JERRY, MORTY AND HELEN',
#  'JERRY\x92S MESSAGE',
#  'JERRY\x92S OUTGOING MESSAGE',
#  'JERY',
#  'JESSIE',
#  'JETER',
#  'JIM',
#  'JIMMY',
#  'JOAN',
#  'JOANNE',
#  'JODI',
#  'JOE',
#  'JOE (passes George a bowl)',
#  'JOE DEVOLA',
#  'JOE DIVOLA',
#  "JOE'S WIFE",
#  'JOEL',
#  'JOEY',
#  'JOHN',
#  'JOHN (V.O.)',
#  'JOHN TYLER',
#  'JOHNNY',
#  'JOY MAYO',
#  'JOYCE',
#  'JUDGE',
#  'JUDGE (banging his gavel)',
#  'JUDY',
#  'JULIANNA',
#  'JULIANNA (releasing her child)',
#  'JULIANNA (visibly uncomfortable)',
#  'JULIE',
#  'JULIO',
#  'James',
#  'Jerry and GEORGE',
#  "Jerry's stand-up",
#  'KAREN',
#  'KARL',
#  'KATE',
#  'KATHY LEE',
#  'KATIE',
#  'KATY',
#  'KATYA',
#  'KEITH',
#  'KELLY',
#  'KEN',
#  'KEN (O.C.)',
#  'KERI',
#  'KERNIS',
#  'KESSLER',
#  'KEVIN',
#  'KID',
#  'KID #2',
#  'KIDS & KRAMER',
#  'KIM',
#  'KIMBROUGH',
#  'KLEIN',
#  'KOREN (O.C.)',
#  'KRAMER',
#  'KRAMER ',
#  'KRAMER & GEORGE',
#  'KRAMER & JERRY',
#  'KRAMER & JOEY',
#  'KRAMER & MICKEY',
#  'KRAMER (O.C.)',
#  'KRAMER (a la Ratso Rizzo in Midnight Cowboy)',
#  'KRAMER (angrily, to Jerry)',
#  'KRAMER (approvingly)',
#  'KRAMER (breaking into tears)',
#  'KRAMER (comes back inside with his finger pointed at Jerry)',
#  'KRAMER (excited)',
#  'KRAMER (frantic)',
#  'KRAMER (from bathroom)',
#  'KRAMER (from hallway)',
#  'KRAMER (from his doorway)',
#  'KRAMER (getting up)',
#  'KRAMER (goes out on the terrace to look, and slips in the water)',
#  'KRAMER (happily)',
#  'KRAMER (holds up his hand)',
#  'KRAMER (impressed)',
#  "KRAMER (in a chef's hat and apron)",
#  'KRAMER (in a perfectly normal tone of voice)',
#  'KRAMER (in disgust)',
#  'KRAMER (in hallway)',
#  'KRAMER (into phone)',
#  'KRAMER (lunging for Little Jerry)',
#  'KRAMER (mouths the words)',
#  'KRAMER (moves over and sits next to George)',
#  'KRAMER (moving back to the othe side of the booth)',
#  'KRAMER (nervously)',
#  'KRAMER (nods)',
#  'KRAMER (panting)',
#  'KRAMER (picking up the wrapper)',
#  "KRAMER (points at Elaine's feet)",
#  "KRAMER (points at Jerry like he's found him out)",
#  'KRAMER (points to his head)',
#  'KRAMER (puts the dough on the counter)',
#  'KRAMER (realizing)',
#  'KRAMER (scanning a menu)',
#  "KRAMER (shouting over the cycle's engine)",
#  'KRAMER (shows Jerry his outfit)',
#  'KRAMER (shows Jerry his winnings)',
#  'KRAMER (singing)',
#  'KRAMER (sternly)',
#  'KRAMER (stuffing tissue up his nose)',
#  'KRAMER (talks rapidly in an attempt to keep up with Newman)',
#  'KRAMER (to Elaine)',
#  'KRAMER (to Jerry)',
#  'KRAMER (to Karen)',
#  'KRAMER (to Poppie)',
#  'KRAMER (to organizer at desk)',
#  'KRAMER (wipes chocolate off his face)',
#  'KRAMER + JERRY',
#  'KRAMER and JERRY (together)',
#  'KRAMER/NEWMAN',
#  'KRAMER/Turkey',
#  'KRISTIN',
#  'KRMAER',
#  'KRUGER',
#  'KURT',
#  'KURT (from the bedroom)',
#  'KURT (laughs)',
#  'KURT (to Elaine)',
#  'LAB TECHNICIAN',
#  'LADY',
#  'LADY 1',
#  'LADY 2',
#  'LAMAR',
#  'LANDIS',
#  "LANDIS'S INTERCOM",
#  'LANDLORD',
#  'LANETTE',
#  'LARRY',
#  'LASER GUY',
#  'LAURA',
#  'LAURA & JERRY',
#  'LEADER',
#  "LEAPIN' LARRY",
#  'LELAND',
#  'LENA',
#  "LENA (smells Jerry's arm)",
#  'LENA (to waiter)',
#  'LEO',
#  'LEO (O.C.)',
#  'LESLIE',
#  'LETTERMAN',
#  'LEVITAN',
#  'LEW',
#  'LIBRARIAN',
#  'LINDSAY',
#  'LIPPMAN',
#  'LISA',
#  'LISI',
#  'LIZ',
#  'LLOYD',
#  'LOIS',
#  'LORETTA',
#  'LORRAINE',
#  'LORRAINE (shaking her hand)',
#  'LOTUS',
#  'LOU',
#  'LOUISE',
#  'LOW-TALKER',
#  'LT. COLEMAN',
#  'LT. MARTEL',
#  'LUBECK',
#  'LUPE',
#  'LYLE',
#  'MABEL',
#  'MACHINE',
#  'MACHINE (KRAMER)',
#  'MACKENZIE',
#  'MAESTRO',
#  'MAESTRO AND ELAINE (Simultaneously)',
#  'MAHJONG LADY',
#  'MAID',
#  'MAILMAN',
#  "MAITRE D'",
#  'MALCOLM',
#  'MALE WORKER',
#  'MAN',
#  'MAN #',
#  'MAN #1',
#  'MAN #1 ',
#  'MAN #2',
#  'MAN #2 ',
#  'MAN #3',
#  'MAN #4',
#  'MAN 1',
#  'MAN 2',
#  'MAN 3',
#  'MAN 4',
#  'MAN AT THE COUNTER',
#  'MAN BEHIND THE DOOR',
#  'MAN IN AUDIENCE',
#  'MAN IN CAR',
#  'MAN IN NEIGHBORING BED',
#  'MAN IN SHOWER',
#  'MAN IN THE CROWD',
#  'MAN ON RAFT',
#  'MAN ON THE STREET',
#  'MAN#1',
#  'MAN#2',
#  'MAN#3',
#  'MAN1',
#  'MAN2',
#  'MAN3',
#  'MAN4',
#  'MANAGER',
#  'MANDEL',
#  'MANNY',
#  'MANYA',
#  'MANYA ',
#  'MAR',
#  'MARCELINO',
#  'MARCELINO (impressed)',
#  'MARCELINO (leaving)',
#  'MARCELINO (tosses the gum on the counter)',
#  'MARCELLINO',
#  'MARCY',
#  'MARGARET',
#  'MARIAN',
#  'MARIAN (turning, surprised)',
#  'MARIE',
#  'MARIE (describing Holly Go-Lightly in "Breakfast At Tiffany\'s")',
#  'MARIO',
#  'MARION',
#  'MARISA',
#  'MARK',
#  'MARLA',
#  'MARLENE',
#  'MARRY',
#  'MARTIN',
#  'MARTY',
#  'MARTY (looking at the locket)',
#  'MARTY (to Jerry)',
#  'MARTY (to Meryl)',
#  'MARY',
#  'MARY ANNE',
#  'MARYEDITH',
#  'MATTHEW',
#  'MAURA',
#  'MAXWELL',
#  'MCADAM',
#  'MECHANIC',
#  'MEL',
#  'MELANIE',
#  'MELISSA',
#  'MEMBER 1',
#  'MEMBER 2',
#  'MERYL',
#  "MERYL (feels Jerry's material)",
#  'MERYL (getting up)',
#  'MERYL (looking for the can opener)',
#  'MERYL (looking in the drawer)',
#  'MERYL (not finding the opener)',
#  "MERYL (throws Paula's clothes at Jerry)",
#  'MICHAEL',
#  'MICKEY',
#  'MIKE',
#  'MILOS',
#  'MINKLER',
#  'MIRANDA',
#  'MISHA',
#  'MISS RHODE ISLAND',
#  'MODEL #1',
#  'MODEL #2',
#  'MODEL #3',
#  'MODEL #4',
#  'MOHEL',
#  'MOLLIKA',
#  'MOLLY',
#  ...]

# %%
# Define a function get_paren_depth to ensure that the paren removal function will work properly
def get_paren_depth(string):
    depth = 0
    for s in string:
        if s == '(':
            depth += 1
        if s == ')':
            depth -= 1
        if depth > 1:
            return 1
        if depth < 0:
            return -1
    
    return depth

# Testing the func
test_cases = ['a (but really b)', '', 'no paren', 'yes (but no (well maybe) ...owl!) yeah!', ' oy ) vey (oops)']
[get_paren_depth(case) for case in test_cases]
# Out:
# [0, 0, 0, 1, -1]

# %%
# Look's good!
paren_test_char = [get_paren_depth(char) for char in char_list]
print(max(paren_test_char))
print(min(paren_test_char))
# Out:
# 0
# 0

# %%
# Okay, now let's define the paren_removal function
def paren_removal(string):
    beg = string.find('(')
    
    if beg != -1:
        end = string.find(')')
        s_new = string[:beg] + string[end + 1:]
        s_new = s_new.replace('  ', ' ').strip()
        return s_new
    else:
        return string

# This function was defined for cleaining the lines after the above version was used to clean the characters
# It took a while when used on a full dataframe, so it will be avoided for now
def paren_removal_rec(string):
    beg = string.find('(')
    
    if beg != -1:
        end = string.find(')')
        s_new = string[:beg] + string[end + 1:]
        s_new = s_new.replace('  ', ' ').strip()
        return paren_removal_rec(s_new)
    else:
        return string    
# Test the function
test_cases = ['blah(blah)BLAH', 'blah (blah)BLAH', 'blah(blah) BLAH', 'blah (blah) BLAH', 'blah BLAH',
              'blah BLAH (wut)', '(blah) (blah) blah BLAH']
pprint([paren_removal(case) for case in test_cases])
pprint([paren_removal_rec(case) for case in test_cases])
# Out:
# ['blahBLAH',
#  'blah BLAH',
#  'blah BLAH',
#  'blah BLAH',
#  'blah BLAH',
#  'blah BLAH',
#  '(blah) blah BLAH']
# ['blahBLAH',
#  'blah BLAH',
#  'blah BLAH',
#  'blah BLAH',
#  'blah BLAH',
#  'blah BLAH',
#  'blah BLAH']

# %%
char_list_2 = [paren_removal(char) for char in char_list]
print(len(char_list_2))
list(zip(char_list, char_list_2))
# Out:
# 1533
# [('AARON', 'AARON'),
#  ('AARON & HELEN', 'AARON & HELEN'),
#  ('ABBY', 'ABBY'),
#  ('ADA', 'ADA'),
#  ('ADAM', 'ADAM'),
#  ('ADE', 'ADE'),
#  ('AENT', 'AENT'),
#  ('AGENCY REP', 'AGENCY REP'),
#  ('AGENT', 'AGENT'),
#  ('AL', 'AL'),
#  ('AL ROKER', 'AL ROKER'),
#  ('ALAN', 'ALAN'),
#  ('ALEC', 'ALEC'),
#  ('ALEX', 'ALEX'),
#  ('ALEX TREBEK', 'ALEX TREBEK'),
#  ('ALICIA', 'ALICIA'),
#  ('ALISON', 'ALISON'),
#  ('ALL', 'ALL'),
#  ('ALL (EXCEPT MORTY)', 'ALL'),
#  ('ALL (chanting)', 'ALL'),
#  ('ALL (singing)', 'ALL'),
#  ('ALL (singing, competing)', 'ALL'),
#  ('ALL FOUR MEN', 'ALL FOUR MEN'),
#  ('ALL THREE', 'ALL THREE'),
#  ('ALLBRIGHT (O.C.)', 'ALLBRIGHT'),
#  ('ALLISON', 'ALLISON'),
#  ('ALLSION', 'ALLSION'),
#  ('ALTON', 'ALTON'),
#  ('AMANDA', 'AMANDA'),
#  ('AMY', 'AMY'),
#  ('ANGELA', 'ANGELA'),
#  ('ANGRY MAN', 'ANGRY MAN'),
#  ('ANNA', 'ANNA'),
#  ('ANNOUNCEMENT', 'ANNOUNCEMENT'),
#  ('ANNOUNCER', 'ANNOUNCER'),
#  ('ANNOUNCER #1', 'ANNOUNCER #1'),
#  ('ANNOUNCER #2', 'ANNOUNCER #2'),
#  ('ANNOUNCER ON P.A. SYSTEM', 'ANNOUNCER ON P.A. SYSTEM'),
#  ('ANNOUNCER ON TV', 'ANNOUNCER ON TV'),
#  ('ANSWERING MACHINE', 'ANSWERING MACHINE'),
#  ('ANTONIO', 'ANTONIO'),
#  ('APPLICANT', 'APPLICANT'),
#  ('ARNIE', 'ARNIE'),
#  ('ARONSON', 'ARONSON'),
#  ('ARTIE', 'ARTIE'),
#  ('ASSISTANT', 'ASSISTANT'),
#  ('ASSISTANT DRESSER', 'ASSISTANT DRESSER'),
#  ('ATTENDANT', 'ATTENDANT'),
#  ('ATTENDANT #1', 'ATTENDANT #1'),
#  ('ATTENDANT #2', 'ATTENDANT #2'),
#  ('AUCTIONEER', 'AUCTIONEER'),
#  ('AUDIENCE', 'AUDIENCE'),
#  ('AUDREY', 'AUDREY'),
#  ('AUNT MAY', 'AUNT MAY'),
#  ('AVA', 'AVA'),
#  ('Announcer', 'Announcer'),
#  ('Another man', 'Another man'),
#  ('BABS', 'BABS'),
#  ('BABU', 'BABU'),
#  ("BABU'S BROTHER", "BABU'S BROTHER"),
#  ("BABU'S FRIEND", "BABU'S FRIEND"),
#  ('BAILIFF', 'BAILIFF'),
#  ('BANIA', 'BANIA'),
#  ('BANK EMPLOYEE', 'BANK EMPLOYEE'),
#  ('BARBARA', 'BARBARA'),
#  ("BARNEY'S SALES ASSOCIATE", "BARNEY'S SALES ASSOCIATE"),
#  ('BARRY', 'BARRY'),
#  ('BARTENDER', 'BARTENDER'),
#  ('BECK', 'BECK'),
#  ('BECKY', 'BECKY'),
#  ('BEN', 'BEN'),
#  ('BENES', 'BENES'),
#  ('BETH', 'BETH'),
#  ('BETSY', 'BETSY'),
#  ('BETSY (sweetly)', 'BETSY'),
#  ('BETSY (to Aunt May)', 'BETSY'),
#  ('BETTE', 'BETTE'),
#  ('BIKER', 'BIKER'),
#  ('BILL', 'BILL'),
#  ('BILLY', 'BILLY'),
#  ('BLAINE', 'BLAINE'),
#  ('BLIND MAN', 'BLIND MAN'),
#  ('BLIND VIOLIN PLAYER', 'BLIND VIOLIN PLAYER'),
#  ('BOB', 'BOB'),
#  ('BOBBY', 'BOBBY'),
#  ('BOMB COP', 'BOMB COP'),
#  ('BONNIE', 'BONNIE'),
#  ('BOOKIE', 'BOOKIE'),
#  ('BOOKMAN', 'BOOKMAN'),
#  ('BOOKMAN (emerging)', 'BOOKMAN'),
#  ('BOSS', 'BOSS'),
#  ("BOSS' WIFE", "BOSS' WIFE"),
#  ('BOTH', 'BOTH'),
#  ('BOUNCER', 'BOUNCER'),
#  ('BOY', 'BOY'),
#  ('BOYFRIEND', 'BOYFRIEND'),
#  ('BRADY', 'BRADY'),
#  ('BRETT', 'BRETT'),
#  ('BRIDGET', 'BRIDGET'),
#  ('BRODY', 'BRODY'),
#  ('BRUCE', 'BRUCE'),
#  ('BRUCE (holding a phone)', 'BRUCE'),
#  ('BRUCE (laughing)', 'BRUCE'),
#  ('BRYANT', 'BRYANT'),
#  ('BUBBLE BOY', 'BUBBLE BOY'),
#  ('BUCKLES', 'BUCKLES'),
#  ('BUDDY', 'BUDDY'),
#  ('BUILDING A', 'BUILDING A'),
#  ('BUILDING B', 'BUILDING B'),
#  ('BUILDING C', 'BUILDING C'),
#  ('BUSINESS MAN', 'BUSINESS MAN'),
#  ('BUSINESSMAN', 'BUSINESSMAN'),
#  ('BUXOM WOMAN', 'BUXOM WOMAN'),
#  ('BUZZER', 'BUZZER'),
#  ('BYSTANDER #1', 'BYSTANDER #1'),
#  ('BYSTANDER #2', 'BYSTANDER #2'),
#  ('Babu Bhatt', 'Babu Bhatt'),
#  ('Banker', 'Banker'),
#  ('Beginnings', 'Beginnings'),
#  ('Boysenberry', 'Boysenberry'),
#  ('Bruce (laughing)', 'Bruce'),
#  ('C.K.', 'C.K.'),
#  ('CAB DRIVER', 'CAB DRIVER'),
#  ('CABBIE', 'CABBIE'),
#  ('CABBY', 'CABBY'),
#  ('CALVIN KLEIN', 'CALVIN KLEIN'),
#  ('CANDICE BERGEN', 'CANDICE BERGEN'),
#  ('CAPTAIN', 'CAPTAIN'),
#  ('CAR SALESMAN', 'CAR SALESMAN'),
#  ('CAR THIEF', 'CAR THIEF'),
#  ('CAR WASHER', 'CAR WASHER'),
#  ('CARL', 'CARL'),
#  ('CARL (hands Jerry an invoice)', 'CARL'),
#  ('CARL (off-camera)', 'CARL'),
#  ('CAROL', 'CAROL'),
#  ('CAROL (shows Elaine and the girls pictures of Adam)', 'CAROL'),
#  ('CARRERAS', 'CARRERAS'),
#  ('CARRIE', 'CARRIE'),
#  ('CASHIER', 'CASHIER'),
#  ('CASHIER (Ruthie Cohen)', 'CASHIER'),
#  ('CASTING DIRECTOR', 'CASTING DIRECTOR'),
#  ('CASTRO', 'CASTRO'),
#  ('CEDRIC', 'CEDRIC'),
#  ('CELIA', 'CELIA'),
#  ('CHAIRMAN', 'CHAIRMAN'),
#  ('CHARLES', 'CHARLES'),
#  ('CHARLIE', 'CHARLIE'),
#  ('CHARMAINE', 'CHARMAINE'),
#  ('CHAUFFEUR', 'CHAUFFEUR'),
#  ('CHELSEA', 'CHELSEA'),
#  ('CHERYL', 'CHERYL'),
#  ('CHILES', 'CHILES'),
#  ('CHIROPRACTOR', 'CHIROPRACTOR'),
#  ('CHOATE', 'CHOATE'),
#  ('CHRISTIE', 'CHRISTIE'),
#  ('CINDY', 'CINDY'),
#  ('CLAIE', 'CLAIE'),
#  ('CLAIRE', 'CLAIRE'),
#  ('CLARE', 'CLARE'),
#  ('CLAYTON', 'CLAYTON'),
#  ('CLEANING WOMAN', 'CLEANING WOMAN'),
#  ('CLERK', 'CLERK'),
#  ('CLERK (checking the computer)', 'CLERK'),
#  ('CLERK (to Kramer)', 'CLERK'),
#  ('CLERK 2', 'CLERK 2'),
#  ('CLERK\x92S VOICE (off camera)', 'CLERK\x92S VOICE'),
#  ('CLICKY', 'CLICKY'),
#  ('CLOTWORTHY', 'CLOTWORTHY'),
#  ('CLUB ANNOUNCER', 'CLUB ANNOUNCER'),
#  ('CLYDE', 'CLYDE'),
#  ('CO-WORKER', 'CO-WORKER'),
#  ('CO-WORKER #1', 'CO-WORKER #1'),
#  ('CO-WORKER #2', 'CO-WORKER #2'),
#  ('COCO', 'COCO'),
#  ('COMPUTER VOICE', 'COMPUTER VOICE'),
#  ('CONNIE', 'CONNIE'),
#  ('CONRAD', 'CONRAD'),
#  ('CONTEST WINNER', 'CONTEST WINNER'),
#  ('CONTEST WINNER (to Elaine)', 'CONTEST WINNER'),
#  ('COP', 'COP'),
#  ('COP #1', 'COP #1'),
#  ('COP #2', 'COP #2'),
#  ('COP 2', 'COP 2'),
#  ('COPS', 'COPS'),
#  ('CORBIN BERNSEN', 'CORBIN BERNSEN'),
#  ('CORINNE', 'CORINNE'),
#  ('COUNTER WOMAN', 'COUNTER WOMAN'),
#  ('COUNTERPERSON', 'COUNTERPERSON'),
#  ('COWORKER', 'COWORKER'),
#  ('CRAIG', 'CRAIG'),
#  ('CRESPI', 'CRESPI'),
#  ('CREW LEADER', 'CREW LEADER'),
#  ('CROWD', 'CROWD'),
#  ('CUSTOMER', 'CUSTOMER'),
#  ('CYNTHIA', 'CYNTHIA'),
#  ('Check #1246, dated Dec. 15 \x9196, Made out to',
#   'Check #1246, dated Dec. 15 \x9196, Made out to'),
#  ('Claims to Fame', 'Claims to Fame'),
#  ('DAN', 'DAN'),
#  ('DANA', 'DANA'),
#  ('DANA (unenthusiastic)', 'DANA'),
#  ('DANIELLE', 'DANIELLE'),
#  ('DANNY TARTABULL', 'DANNY TARTABULL'),
#  ('DAPHNE', 'DAPHNE'),
#  ('DARREN', 'DARREN'),
#  ('DARRYL', 'DARRYL'),
#  ('DAVID', 'DAVID'),
#  ('DAVOLA', 'DAVOLA'),
#  ('DAVOLA (O.C.)', 'DAVOLA'),
#  ('DEAN JONES', 'DEAN JONES'),
#  ('DEBBY', 'DEBBY'),
#  ('DEENA', 'DEENA'),
#  ('DEENSFREI', 'DEENSFREI'),
#  ('DELIVERY BOY', 'DELIVERY BOY'),
#  ('DELIVERY GUY', 'DELIVERY GUY'),
#  ('DELIVERY MAN', 'DELIVERY MAN'),
#  ('DENIM VEST', 'DENIM VEST'),
#  ('DENISE', 'DENISE'),
#  ('DENNIS', 'DENNIS'),
#  ('DENTIST', 'DENTIST'),
#  ('DEPUTY', 'DEPUTY'),
#  ('DETECTIVE', 'DETECTIVE'),
#  ('DETECTIVE #1 (to Kurt)', 'DETECTIVE #1'),
#  ('DETECTIVE #2', 'DETECTIVE #2'),
#  ('DETECTIVE #2 (to Kurt)', 'DETECTIVE #2'),
#  ('DETECTIVE (V.O.)', 'DETECTIVE'),
#  ('DEVOLA', 'DEVOLA'),
#  ('DIANE', 'DIANE'),
#  ('DICK', 'DICK'),
#  ('DIRECTOR', 'DIRECTOR'),
#  ('DISPATCHER', 'DISPATCHER'),
#  ('DJ ON RADIO', 'DJ ON RADIO'),
#  ('DOCTER', 'DOCTER'),
#  ('DOCTOR', 'DOCTOR'),
#  ('DOCTOR (O.C.)', 'DOCTOR'),
#  ('DOG OWNER', 'DOG OWNER'),
#  ('DOLL', 'DOLL'),
#  ('DOLORES', 'DOLORES'),
#  ('DONALD', 'DONALD'),
#  ('DONNA', 'DONNA'),
#  ('DONNA ', 'DONNA '),
#  ('DOORMAN', 'DOORMAN'),
#  ('DOORMAN 2', 'DOORMAN 2'),
#  ('DORIS', 'DORIS'),
#  ('DR. ALLENWOOD', 'DR. ALLENWOOD'),
#  ('DR. BAKERSOLL', 'DR. BAKERSOLL'),
#  ('DR. COOPERMAN', 'DR. COOPERMAN'),
#  ('DR. DEMBROW', 'DR. DEMBROW'),
#  ('DR. RESTON', 'DR. RESTON'),
#  ('DR. WEXLER', 'DR. WEXLER'),
#  ('DRIVER', 'DRIVER'),
#  ('DRY CLEANE', 'DRY CLEANE'),
#  ('DRY CLEANER', 'DRY CLEANER'),
#  ('DUGAN', 'DUGAN'),
#  ('DUNCAN', 'DUNCAN'),
#  ('DUNCAN & JERRY', 'DUNCAN & JERRY'),
#  ('DUSTIN', 'DUSTIN'),
#  ('DUSTIN - Locker room Attendant #2', 'DUSTIN - Locker room Attendant #2'),
#  ('DWAYNE', 'DWAYNE'),
#  ('Dedication', 'Dedication'),
#  ('Driver', 'Driver'),
#  ('Dugan', 'Dugan'),
#  ('Dx', 'Dx'),
#  ('EALINE', 'EALINE'),
#  ('EARL', 'EARL'),
#  ('ECHO', 'ECHO'),
#  ('ED', 'ED'),
#  ('EDDIE', 'EDDIE'),
#  ('EDDIT', 'EDDIT'),
#  ('EGO', 'EGO'),
#  ('ELAIEN', 'ELAIEN'),
#  ('ELAINE', 'ELAINE'),
#  ('ELAINE ', 'ELAINE '),
#  ('ELAINE & GEORGE', 'ELAINE & GEORGE'),
#  ('ELAINE & JERRY', 'ELAINE & JERRY'),
#  ('ELAINE & PUDDY', 'ELAINE & PUDDY'),
#  ('ELAINE & RAY', 'ELAINE & RAY'),
#  ('ELAINE (Gives him the money)', 'ELAINE'),
#  ('ELAINE (O.C.)', 'ELAINE'),
#  ('ELAINE (V.O.)', 'ELAINE'),
#  ('ELAINE (absolutely disgusted)', 'ELAINE'),
#  ('ELAINE (amused)', 'ELAINE'),
#  ('ELAINE (angrily)', 'ELAINE'),
#  ('ELAINE (beaming)', 'ELAINE'),
#  ('ELAINE (deaf)', 'ELAINE'),
#  ('ELAINE (enunciating clearly so George gets the point)', 'ELAINE'),
#  ('ELAINE (examining the socks)', 'ELAINE'),
#  ('ELAINE (excited)', 'ELAINE'),
#  ('ELAINE (fed up)', 'ELAINE'),
#  ('ELAINE (flirtatiously)', 'ELAINE'),
#  ('ELAINE (getting up to leave)', 'ELAINE'),
#  ('ELAINE (grabs the papers from Jerry)', 'ELAINE'),
#  ('ELAINE (gushing)', 'ELAINE'),
#  ('ELAINE (happily)', 'ELAINE'),
#  ('ELAINE (humoring her)', 'ELAINE'),
#  ('ELAINE (imitating Toby)', 'ELAINE'),
#  ('ELAINE (in a dreadful tone)', 'ELAINE'),
#  ('ELAINE (in a southern accent)', 'ELAINE'),
#  ('ELAINE (irritated, imitates Gail)', 'ELAINE'),
#  ('ELAINE (laughing)', 'ELAINE'),
#  ('ELAINE (laughs)', 'ELAINE'),
#  ('ELAINE (leaning forward)', 'ELAINE'),
#  ('ELAINE (looking in the fridge)', 'ELAINE'),
#  ('ELAINE (looks at Jerry and smears lipstick across her face)', 'ELAINE'),
#  ('ELAINE (modest)', 'ELAINE'),
#  ('ELAINE (mouths the words)', 'ELAINE'),
#  ('ELAINE (nodding)', 'ELAINE'),
#  ('ELAINE (nudges George with her elbow)', 'ELAINE'),
#  ('ELAINE (offended)', 'ELAINE'),
#  ('ELAINE (on the witness stand)', 'ELAINE'),
#  ("ELAINE (pulling up Pitt's socks)", 'ELAINE'),
#  ("ELAINE (put off by Toby's exuberance)", 'ELAINE'),
#  ('ELAINE (putting on lipstick)', 'ELAINE'),
#  ('ELAINE (puzzled)', 'ELAINE'),
#  ('ELAINE (signing)', 'ELAINE'),
#  ('ELAINE (singing)', 'ELAINE'),
#  ('ELAINE (sitting down)', 'ELAINE'),
#  ('ELAINE (smiling)', 'ELAINE'),
#  ('ELAINE (smug)', 'ELAINE'),
#  ('ELAINE (standing in the doorway)', 'ELAINE'),
#  ('ELAINE (standing up)', 'ELAINE'),
#  ('ELAINE (stands up)', 'ELAINE'),
#  ('ELAINE (stretches)', 'ELAINE'),
#  ('ELAINE (surprised)', 'ELAINE'),
#  ('ELAINE (thinking to herself)', 'ELAINE'),
#  ('ELAINE (thinking)', 'ELAINE'),
#  ('ELAINE (through her teeth)', 'ELAINE'),
#  ('ELAINE (through teeth)', 'ELAINE'),
#  ('ELAINE (throws the script at Jerry)', 'ELAINE'),
#  ('ELAINE (to Carl)', 'ELAINE'),
#  ('ELAINE (to Carl, flirtatiously)', 'ELAINE'),
#  ('ELAINE (to George)', 'ELAINE'),
#  ('ELAINE (to Jerry)', 'ELAINE'),
#  ('ELAINE (to Jerry, imitating Carol)', 'ELAINE'),
#  ('ELAINE (to Kramer)', 'ELAINE'),
#  ('ELAINE (to Poppie)', 'ELAINE'),
#  ('ELAINE (to Russell)', 'ELAINE'),
#  ('ELAINE (to a woman at the fight)', 'ELAINE'),
#  ("ELAINE (tries to snatch food off a waiter's tray)", 'ELAINE'),
#  ('ELAINE (turning on George)', 'ELAINE'),
#  ('ELAINE (uninterested)', 'ELAINE'),
#  ('ELAINE (warns)', 'ELAINE'),
#  ('ELAINE (wearily)', 'ELAINE'),
#  ('ELAINE (whispering)', 'ELAINE'),
#  ('ELAINE (with little hope)', 'ELAINE'),
#  ('ELAINE (yelling)', 'ELAINE'),
#  ('ELAINE AND JERRY', 'ELAINE AND JERRY'),
#  ('ELAINE AND PUDDY', 'ELAINE AND PUDDY'),
#  ('ELAINE and KRAMER', 'ELAINE and KRAMER'),
#  ("ELAINE'S VOICE", "ELAINE'S VOICE"),
#  ("ELAINE's brain", "ELAINE's brain"),
#  ('ELAINE/DAVOLA', 'ELAINE/DAVOLA'),
#  ('ELAINE/JERRY', 'ELAINE/JERRY'),
#  ('ELAINE/WENDY', 'ELAINE/WENDY'),
#  ('ELANE', 'ELANE'),
#  ('ELDRIDGE', 'ELDRIDGE'),
#  ('ELECTRICIAN', 'ELECTRICIAN'),
#  ('ELIANE', 'ELIANE'),
#  ('ELLEN', 'ELLEN'),
#  ('EMILY', 'EMILY'),
#  ('EMPLOYEE', 'EMPLOYEE'),
#  ('ENZO', 'ENZO'),
#  ('ERIC', 'ERIC'),
#  ('ESTELLE', 'ESTELLE'),
#  ('ESTELLE (crying)', 'ESTELLE'),
#  ('ESTELLE (smiling)', 'ESTELLE'),
#  ('ETHAN', 'ETHAN'),
#  ('EULOGIST', 'EULOGIST'),
#  ('EVA', 'EVA'),
#  ('EVELYN', 'EVELYN'),
#  ('EVERYBODY', 'EVERYBODY'),
#  ('EVERYONE', 'EVERYONE'),
#  ('EXECUTIVE 1', 'EXECUTIVE 1'),
#  ('EXECUTIVE 2', 'EXECUTIVE 2'),
#  ('ElainELAINE', 'ElainELAINE'),
#  ('Elaine', 'Elaine'),
#  ('Elaine (answering)', 'Elaine'),
#  ('Elaine (hanging up)', 'Elaine'),
#  ("Elaine (thinking it's Dan)", 'Elaine'),
#  ('Elaine + JERRY', 'Elaine + JERRY'),
#  ('Elaine thinking', 'Elaine thinking'),
#  ('Elaine, becoming board', 'Elaine, becoming board'),
#  ('Ex', 'Ex'),
#  ('FAN', 'FAN'),
#  ('FAN #1', 'FAN #1'),
#  ('FARKUS', 'FARKUS'),
#  ('FARMER', 'FARMER'),
#  ('FATHER', 'FATHER'),
#  ('FATHER CURTIS', 'FATHER CURTIS'),
#  ('FATHER HERNANDEZ', 'FATHER HERNANDEZ'),
#  ('FATHER JESSUP', 'FATHER JESSUP'),
#  ('FATHER-PRIEST', 'FATHER-PRIEST'),
#  ('FATHER-PRIEST 2', 'FATHER-PRIEST 2'),
#  ('FDR', 'FDR'),
#  ('FELDMAN', 'FELDMAN'),
#  ('FEMALE CUSTOMER', 'FEMALE CUSTOMER'),
#  ('FEMALE WORKER', 'FEMALE WORKER'),
#  ('FIREMAN', 'FIREMAN'),
#  ('FLIGHT ATTENDANT', 'FLIGHT ATTENDANT'),
#  ('FLORIST', 'FLORIST'),
#  ('FOREMAN', 'FOREMAN'),
#  ('FOWLER', 'FOWLER'),
#  ('FRANK', 'FRANK'),
#  ('FRANK (from the answering machine)', 'FRANK'),
#  ('FRANK (yelling)', 'FRANK'),
#  ('FRANKIE', 'FRANKIE'),
#  ('FRED', 'FRED'),
#  ('FRED (a little frightened and backing away towards the door)', 'FRED'),
#  ('FRED SAVAGE', 'FRED SAVAGE'),
#  ('FRIEND', 'FRIEND'),
#  ('FRIEND 1', 'FRIEND 1'),
#  ('FULTON', 'FULTON'),
#  ('FURNITURE GUY', 'FURNITURE GUY'),
#  ('Frank (picking up his shoes)', 'Frank'),
#  ('Frank Costanza', 'Frank Costanza'),
#  ('Frank and ESTELLE', 'Frank and ESTELLE'),
#  ('GAIL', 'GAIL'),
#  ('GAIL (hands a plate to another chef)', 'GAIL'),
#  ('GAIL (impressed)', 'GAIL'),
#  ('GAIL (to Elaine)', 'GAIL'),
#  ('GAIL (to Jerry)', 'GAIL'),
#  ('GARDNER', 'GARDNER'),
#  ('GARY', 'GARY'),
#  ('GAS STATION ATTENDANT', 'GAS STATION ATTENDANT'),
#  ('GAURD', 'GAURD'),
#  ('GAVIN', 'GAVIN'),
#  ('GENE', 'GENE'),
#  ('GENNICE', 'GENNICE'),
#  ('GEOGE', 'GEOGE'),
#  ('GEORGE', 'GEORGE'),
#  ('GEORGE ', 'GEORGE '),
#  ('GEORGE & ELAINE', 'GEORGE & ELAINE'),
#  ('GEORGE & JERRY', 'GEORGE & JERRY'),
#  ('GEORGE & KRAMER', 'GEORGE & KRAMER'),
#  ('GEORGE (Counting on his fingers)', 'GEORGE'),
#  ('GEORGE (O.C.)', 'GEORGE'),
#  ('GEORGE (O.S.)', 'GEORGE'),
#  ('GEORGE (V.O.)', 'GEORGE'),
#  ('GEORGE (angrily)', 'GEORGE'),
#  ('GEORGE (apologetic)', 'GEORGE'),
#  ('GEORGE (attempting to make a move)', 'GEORGE'),
#  ('GEORGE (beaming)', 'GEORGE'),
#  ('GEORGE (boasting)', 'GEORGE'),
#  ('GEORGE (chuckles)', 'GEORGE'),
#  ("GEORGE (clears his throat, annoyed that the movie's being interrupted)",
#   'GEORGE'),
#  ('GEORGE (close to tears)', 'GEORGE'),
#  ('GEORGE (comes out of the bathroom brushing his teeth)', 'GEORGE'),
#  ('GEORGE (defensive)', 'GEORGE'),
#  ('GEORGE (disappointed)', 'GEORGE'),
#  ("GEORGE (examining Kurt's head with a lamp)", 'GEORGE'),
#  ('GEORGE (from backstage)', 'GEORGE'),
#  ('GEORGE (from the bathroom)', 'GEORGE'),
#  ('GEORGE (giddy)', 'GEORGE'),
#  ('GEORGE (grabs the M&M away from Jerry)', 'GEORGE'),
#  ('GEORGE (holds up one finger)', 'GEORGE'),
#  ('GEORGE (immediately, to Elaine)', 'GEORGE'),
#  ('GEORGE (irritated)', 'GEORGE'),
#  ('GEORGE (laughing)', 'GEORGE'),
#  ('GEORGE (lazily swinging the garbage bag around)', 'GEORGE'),
#  ('GEORGE (loading up his plate with sandwiches)', 'GEORGE'),
#  ("GEORGE (looking at Kramer's arm)", 'GEORGE'),
#  ('GEORGE (looking over)', 'GEORGE'),
#  ('GEORGE (looks at his watch)', 'GEORGE'),
#  ('GEORGE (meekly)', 'GEORGE'),
#  ('GEORGE (mocking Jerry)', 'GEORGE'),
#  ('GEORGE (nervously)', 'GEORGE'),
#  ("GEORGE (notices Russell's lunch)", 'GEORGE'),
#  ("GEORGE (noticing Jerry's suitcase)", 'GEORGE'),
#  ('GEORGE (nudges Elaine with his elbow)', 'GEORGE'),
#  ('GEORGE (on a pay phone)', 'GEORGE'),
#  ('GEORGE (on intercom)', 'GEORGE'),
#  ('GEORGE (overjoyed to find out)', 'GEORGE'),
#  ('GEORGE (pulls over)', 'GEORGE'),
#  ('GEORGE (sadly)', 'GEORGE'),
#  ('GEORGE (shakes huge keyring)', 'GEORGE'),
#  ('GEORGE (singing)', 'GEORGE'),
#  ('GEORGE (sniffling)', 'GEORGE'),
#  ('GEORGE (solemnly)', 'GEORGE'),
#  ('GEORGE (suddenly interested)', 'GEORGE'),
#  ('GEORGE (thinking)', 'GEORGE'),
#  ('GEORGE (to Elaine)', 'GEORGE'),
#  ('GEORGE (to Elaine, in a somber tone)', 'GEORGE'),
#  ('GEORGE (to Jerry)', 'GEORGE'),
#  ('GEORGE (to Kramer)', 'GEORGE'),
#  ('GEORGE (to Lupe)', 'GEORGE'),
#  ('GEORGE (to clerk)', 'GEORGE'),
#  ('GEORGE (to guy)', 'GEORGE'),
#  ('GEORGE (to himself)', 'GEORGE'),
#  ('GEORGE (to the EMTs)', 'GEORGE'),
#  ('GEORGE (tosses the condom aside)', 'GEORGE'),
#  ('GEORGE (unimpressed)', 'GEORGE'),
#  ('GEORGE (voice is hoarse from screaming)', 'GEORGE'),
#  ('GEORGE (whistles to guy on phone)', 'GEORGE'),
#  ('GEORGE (writing on a notepad)', 'GEORGE'),
#  ('GEORGE (yelling at her)', 'GEORGE'),
#  ('GEORGE AND JERRY', 'GEORGE AND JERRY'),
#  ('GEORGE WENDT', 'GEORGE WENDT'),
#  ('GEORGE WENDT (checking his watch, obviously uncomfortable)',
#   'GEORGE WENDT'),
#  ("GEORGE'S VOICE", "GEORGE'S VOICE"),
#  ('GEORGE, ELAINE, KRAMER, JERRY, & STAN',
#   'GEORGE, ELAINE, KRAMER, JERRY, & STAN'),
#  ('GEORGE/JERRY/ELAINE/WENDY', 'GEORGE/JERRY/ELAINE/WENDY'),
#  ('GEORGE/SUSAN', 'GEORGE/SUSAN'),
#  ('GEPETTO', 'GEPETTO'),
#  ('GERMAN WOMAN', 'GERMAN WOMAN'),
#  ('GEROGE', 'GEROGE'),
#  ('GIGGIO', 'GIGGIO'),
#  ('GILLIAN', 'GILLIAN'),
#  ('GINA', 'GINA'),
#  ('GINO', 'GINO'),
#  ('GIRL', 'GIRL'),
#  ('GIRL (NOT WINONA)', 'GIRL'),
#  ('GIRLFRIEND', 'GIRLFRIEND'),
#  ('GIULIANI', 'GIULIANI'),
#  ('GLADYS', 'GLADYS'),
#  ('GLENDA', 'GLENDA'),
#  ('GLENN', 'GLENN'),
#  ('GOERGE', 'GOERGE'),
#  ('GRANDPA (to Anna)', 'GRANDPA'),
#  ('GREENY', 'GREENY'),
#  ('GREG', 'GREG'),
#  ('GREG (hands the bottle back)', 'GREG'),
#  ('GREG (looks at his watch)', 'GREG'),
#  ('GREG (to Elaine)', 'GREG'),
#  ('GROSSBARD', 'GROSSBARD'),
#  ('GROUP', 'GROUP'),
#  ('GUAD', 'GUAD'),
#  ('GUARD', 'GUARD'),
#  ('GUESTS, JERRY & ELAINE', 'GUESTS, JERRY & ELAINE'),
#  ('GUILLERMO', 'GUILLERMO'),
#  ('GUY', 'GUY'),
#  ('GUY ON PHONE', 'GUY ON PHONE'),
#  ('GWEN', 'GWEN'),
#  ('GX', 'GX'),
#  ('Genderson', 'Genderson'),
#  ('Guy1', 'Guy1'),
#  ('HAARWOOD', 'HAARWOOD'),
#  ('HAFFLER', 'HAFFLER'),
#  ('HAIRDRESSER', 'HAIRDRESSER'),
#  ('HAL', 'HAL'),
#  ('HALLIE', 'HALLIE'),
#  ('HANKE', 'HANKE'),
#  ('HAROLD', 'HAROLD'),
#  ('HEAD', 'HEAD'),
#  ('HEAD (O.C.)', 'HEAD'),
#  ('HEALTH INSPECTOR', 'HEALTH INSPECTOR'),
#  ('HELEN', 'HELEN'),
#  ('HELEN & AARON', 'HELEN & AARON'),
#  ('HELEN & MORTY', 'HELEN & MORTY'),
#  ('HELEN (V.O)', 'HELEN'),
#  ('HELEN (in Florida with Morty)', 'HELEN'),
#  ('HELEN (to Jerry)', 'HELEN'),
#  ('HELENA', 'HELENA'),
#  ('HENRY', 'HENRY'),
#  ('HERB', 'HERB'),
#  ('HEYMAN', 'HEYMAN'),
#  ('HIGH PITCHED VOICE', 'HIGH PITCHED VOICE'),
#  ('HILDE', 'HILDE'),
#  ('HIPPIE #1', 'HIPPIE #1'),
#  ('HIPPIE #2', 'HIPPIE #2'),
#  ('HOLE DIGGER', 'HOLE DIGGER'),
#  ('HOLE DIGGER #2', 'HOLE DIGGER #2'),
#  ('HOLLY', 'HOLLY'),
#  ('HOMELESS MAN', 'HOMELESS MAN'),
#  ('HOMELESS MAN 2', 'HOMELESS MAN 2'),
#  ('HOOKER', 'HOOKER'),
#  ('HORST', 'HORST'),
#  ('HOSPITAL VOICEOVER', 'HOSPITAL VOICEOVER'),
#  ('HOSTESS', 'HOSTESS'),
#  ('HOT DOG VENDOR', 'HOT DOG VENDOR'),
#  ('HOTEL CLERK', 'HOTEL CLERK'),
#  ('HOUSEKEEPER', 'HOUSEKEEPER'),
#  ('HOYT', 'HOYT'),
#  ('HUSBAND', 'HUSBAND'),
#  ('Huckleberry', 'Huckleberry'),
#  ('Hx', 'Hx'),
#  ('I always feel bad for the silver medal winner in the Olympics. How do you live with that the rest of your life? People are gonna keep asking',
#   'I always feel bad for the silver medal winner in the Olympics. How do you live with that the rest of your life? People are gonna keep asking'),
#  ("I always get confused in the movie theater by the, by the plot. It's embarrassing. It's an embarrassment to have to admit, but I'm the one that you see in the parking lot after the movie talking with his friends, going",
#   "I always get confused in the movie theater by the, by the plot. It's embarrassing. It's an embarrassment to have to admit, but I'm the one that you see in the parking lot after the movie talking with his friends, going"),
#  ('I am not gay. I am, however, thin, single and neat. Sometimes when someone is thin, single and neat people assume they are gay because that is a stereotype. They normally don\'t think of gay people as fat, sloppy and married. Although I\'m sure there are, I don\'t want to perpetuate the stereotype. I\'m sure they are the minority though within the gay community. They\'re probably discriminated against because of that, people say to them "Y\'know Joe, I enjoy being gay with you but I think think it\'s about time, y\'know that you got in shape, tucked the shirt in and lost the wife". But if people are even going to assume that people that are neat are gay, maybe instead of doin\' this',
#   'I am not gay. I am, however, thin, single and neat. Sometimes when someone is thin, single and neat people assume they are gay because that is a stereotype. They normally don\'t think of gay people as fat, sloppy and married. Although I\'m sure there are, I don\'t want to perpetuate the stereotype. I\'m sure they are the minority though within the gay community. They\'re probably discriminated against because of that, people say to them "Y\'know Joe, I enjoy being gay with you but I think think it\'s about time, y\'know that you got in shape, tucked the shirt in and lost the wife". But if people are even going to assume that people that are neat are gay, maybe instead of doin\' this'),
#  ('I think the thing I admire most about the Chinese is that they\'re hanging in there with the chopsticks. Because, if you think about it, you know, they\'ve seen the fork... by now. I\'m sure they\'ve seen the spoon, they\'re going, "Yeah, yeah, they\'re OK... We\'re going to stay with the sticks." I mean, I don\'t know how they\'ve missed it',
#   'I think the thing I admire most about the Chinese is that they\'re hanging in there with the chopsticks. Because, if you think about it, you know, they\'ve seen the fork... by now. I\'m sure they\'ve seen the spoon, they\'re going, "Yeah, yeah, they\'re OK... We\'re going to stay with the sticks." I mean, I don\'t know how they\'ve missed it'),
#  ('IAN', 'IAN'),
#  ('ICE CREAM VENDER #1', 'ICE CREAM VENDER #1'),
#  ('ICE CREAM VENDER #2', 'ICE CREAM VENDER #2'),
#  ('ILENE', 'ILENE'),
#  ('ISAAC', 'ISAAC'),
#  ('ISABEL', 'ISABEL'),
#  ('IZZY', 'IZZY'),
#  ('IZZY & IZZY JR.', 'IZZY & IZZY JR.'),
#  ('IZZY IZZY SR.. (O.C.)', 'IZZY IZZY SR..'),
#  ('IZZY JR.', 'IZZY JR.'),
#  ('IZZY SR.', 'IZZY SR.'),
#  ('IZZY/IZZY JR/IZZY IZZY SR.', 'IZZY/IZZY JR/IZZY IZZY SR.'),
#  ('Inside Kew Gardens Reprinted from an article in the October 1982 issue of Metropolis Magazine. http',
#   'Inside Kew Gardens Reprinted from an article in the October 1982 issue of Metropolis Magazine. http'),
#  ('J. PETERMAN', 'J. PETERMAN'),
#  ('JACK', 'JACK'),
#  ('JACKIE', 'JACKIE'),
#  ('JACKIE ', 'JACKIE '),
#  ('JACKIE (impressed)', 'JACKIE'),
#  ('JACKIE (speaking to the intercom)', 'JACKIE'),
#  ('JACKIE (to Kramer and Stan)', 'JACKIE'),
#  ('JAKE', 'JAKE'),
#  ('JAMES', 'JAMES'),
#  ('JANE', 'JANE'),
#  ('JANET', 'JANET'),
#  ('JANICE', 'JANICE'),
#  ('JAY', 'JAY'),
#  ('JAY LENO', 'JAY LENO'),
#  ('JEAN-PAUL', 'JEAN-PAUL'),
#  ('JEANINE', 'JEANINE'),
#  ('JEANNIE', 'JEANNIE'),
#  ('JEFF', 'JEFF'),
#  ('JENNA', 'JENNA'),
#  ('JENNA (O.C.)', 'JENNA'),
#  ('JENNY', 'JENNY'),
#  ('JERR', 'JERR'),
#  ('JERRY', 'JERRY'),
#  ('JERRY ', 'JERRY '),
#  ('JERRY & COP', 'JERRY & COP'),
#  ('JERRY & ELAINE', 'JERRY & ELAINE'),
#  ('JERRY & GEORGE', 'JERRY & GEORGE'),
#  ('JERRY & George', 'JERRY & George'),
#  ('JERRY & JEANNIE', 'JERRY & JEANNIE'),
#  ('JERRY & KRAMER', 'JERRY & KRAMER'),
#  ('JERRY & TIA', 'JERRY & TIA'),
#  ('JERRY (O.C.)', 'JERRY'),
#  ('JERRY (V.O)', 'JERRY'),
#  ('JERRY (V.O.)', 'JERRY'),
#  ('JERRY (angrily)', 'JERRY'),
#  ('JERRY (answering phone)', 'JERRY'),
#  ('JERRY (applauding)', 'JERRY'),
#  ("JERRY (attempting to carry on despite Toby's interruptions)", 'JERRY'),
#  ('JERRY (catches Elaine)', 'JERRY'),
#  ("JERRY (clearly creeped out by having to shake Poppie's hand)", 'JERRY'),
#  ("JERRY (comes out of the bedroom with Poppie's money)", 'JERRY'),
#  ('JERRY (copying down the number)', 'JERRY'),
#  ('JERRY (copying it down and grinning)', 'JERRY'),
#  ('JERRY (dialing)', 'JERRY'),
#  ('JERRY (doubtfully)', 'JERRY'),
#  ('JERRY (exasperated)', 'JERRY'),
#  ('JERRY (excited)', 'JERRY'),
#  ('JERRY (frantic)', 'JERRY'),
#  ('JERRY (from his bedroom hallway, alluding to the fact that she should get the drink herself)',
#   'JERRY'),
#  ('JERRY (from inside the bathroom)', 'JERRY'),
#  ('JERRY (from outside the door)', 'JERRY'),
#  ('JERRY (getting out of bed)', 'JERRY'),
#  ('JERRY (giving in)', 'JERRY'),
#  ('JERRY (hesitant)', 'JERRY'),
#  ('JERRY (holds up the syrup bottle)', 'JERRY'),
#  ('JERRY (hoping Leo will pick up on the scam)', 'JERRY'),
#  ('JERRY (indifferent)', 'JERRY'),
#  ('JERRY (interrupts)', 'JERRY'),
#  ('JERRY (irritated)', 'JERRY'),
#  ("JERRY (leaving a message on Elaine's machine)", 'JERRY'),
#  ('JERRY (looking at the puddle with Kramer)', 'JERRY'),
#  ('JERRY (looking in a drawer)', 'JERRY'),
#  ('JERRY (looking through some papers on the desk)', 'JERRY'),
#  ('JERRY (looks at his watch)', 'JERRY'),
#  ('JERRY (low voice)', 'JERRY'),
#  ('JERRY (making fun)', 'JERRY'),
#  ('JERRY (mesmerized)', 'JERRY'),
#  ('JERRY (mimics smoking an "after sex cigarette")', 'JERRY'),
#  ('JERRY (nonplussed)', 'JERRY'),
#  ('JERRY (not happy)', 'JERRY'),
#  ('JERRY (noticing something across the coffee shop)', 'JERRY'),
#  ('JERRY (offers a hot dog to Miss Rhode Island)', 'JERRY'),
#  ('JERRY (opens the envelope)', 'JERRY'),
#  ('JERRY (patiently while watching tv)', 'JERRY'),
#  ('JERRY (picks up a yellow M&M toy from the model)', 'JERRY'),
#  ('JERRY (picks up the phone)', 'JERRY'),
#  ('JERRY (pointing at the trophy)', 'JERRY'),
#  ('JERRY (points at the Power Ranger)', 'JERRY'),
#  ('JERRY (points)', 'JERRY'),
#  ('JERRY (proudly)', 'JERRY'),
#  ('JERRY (rolls his eyes)', 'JERRY'),
#  ('JERRY (sarcastic)', 'JERRY'),
#  ('JERRY (sarcastically)', 'JERRY'),
#  ('JERRY (sees a white couch by the wall)', 'JERRY'),
#  ('JERRY (shrugs)', 'JERRY'),
#  ('JERRY (shudders)', 'JERRY'),
#  ('JERRY (shuts the car door)', 'JERRY'),
#  ('JERRY (signing)', 'JERRY'),
#  ('JERRY (sits down)', 'JERRY'),
#  ('JERRY (slams the drawer)', 'JERRY'),
#  ('JERRY (slowly)', 'JERRY'),
#  ('JERRY (smiling)', 'JERRY'),
#  ('JERRY (standing)', 'JERRY'),
#  ('JERRY (still trying to remember)', 'JERRY'),
#  ('JERRY (takes out his wallet)', 'JERRY'),
#  ('JERRY (thinks)', 'JERRY'),
#  ('JERRY (to Elaine)', 'JERRY'),
#  ('JERRY (to Farfel)', 'JERRY'),
#  ('JERRY (to George)', 'JERRY'),
#  ('JERRY (to George, hugs Kramer happily)', 'JERRY'),
#  ('JERRY (to Karen)', 'JERRY'),
#  ('JERRY (to Kevin)', 'JERRY'),
#  ('JERRY (to Kramer)', 'JERRY'),
#  ('JERRY (to Lena)', 'JERRY'),
#  ('JERRY (to Meryl)', 'JERRY'),
#  ("JERRY (to Meryl, who's making a racket in the kitchen looking for the can opener)",
#   'JERRY'),
#  ('JERRY (to Pam)', 'JERRY'),
#  ('JERRY (to waitress)', 'JERRY'),
#  ('JERRY (toasts with his orange juice)', 'JERRY'),
#  ('JERRY (turning to leave)', 'JERRY'),
#  ('JERRY (under his breath, to a man at the party)', 'JERRY'),
#  ('JERRY (using Elaine as an example)', 'JERRY'),
#  ("JERRY (wipes Kramer's brow)", 'JERRY'),
#  ('JERRY (yelling from his room)', 'JERRY'),
#  ('JERRY AND ELAINE', 'JERRY AND ELAINE'),
#  ('JERRY AND ELAINE (together)', 'JERRY AND ELAINE'),
#  ('JERRY AND GEORGE', 'JERRY AND GEORGE'),
#  ('JERRY AND JOEL', 'JERRY AND JOEL'),
#  ('JERRY AND KRAMER', 'JERRY AND KRAMER'),
#  ('JERRY AND NEWMAN', 'JERRY AND NEWMAN'),
#  ('JERRY and ELAINE', 'JERRY and ELAINE'),
#  ('JERRY and ELAINE, together', 'JERRY and ELAINE, together'),
#  ('JERRY and GEORGE', 'JERRY and GEORGE'),
#  ('JERRY and KRAMER', 'JERRY and KRAMER'),
#  ('JERRY and NEWMAN', 'JERRY and NEWMAN'),
#  ('JERRY&ELAINE', 'JERRY&ELAINE'),
#  ("JERRY'S ANSWERING MACHINE", "JERRY'S ANSWERING MACHINE"),
#  ("JERRY'S BRAIN", "JERRY'S BRAIN"),
#  ("JERRY'S MACHINE", "JERRY'S MACHINE"),
#  ("JERRY'S PENIS", "JERRY'S PENIS"),
#  ("JERRY'S brain", "JERRY'S brain"),
#  ("JERRY's brain", "JERRY's brain"),
#  ('JERRY(MIND)', 'JERRY'),
#  ('JERRY, GEORGE & ELAINE', 'JERRY, GEORGE & ELAINE'),
#  ('JERRY, GEORGE & KRAMER', 'JERRY, GEORGE & KRAMER'),
#  ('JERRY, GEORGE, & KRAMER', 'JERRY, GEORGE, & KRAMER'),
#  ('JERRY, GEORGE, ELAINE', 'JERRY, GEORGE, ELAINE'),
#  ('JERRY, KRAMER & NEWMAN', 'JERRY, KRAMER & NEWMAN'),
#  ('JERRY, MORTY AND HELEN', 'JERRY, MORTY AND HELEN'),
#  ('JERRY\x92S MESSAGE', 'JERRY\x92S MESSAGE'),
#  ('JERRY\x92S OUTGOING MESSAGE', 'JERRY\x92S OUTGOING MESSAGE'),
#  ('JERY', 'JERY'),
#  ('JESSIE', 'JESSIE'),
#  ('JETER', 'JETER'),
#  ('JIM', 'JIM'),
#  ('JIMMY', 'JIMMY'),
#  ('JOAN', 'JOAN'),
#  ('JOANNE', 'JOANNE'),
#  ('JODI', 'JODI'),
#  ('JOE', 'JOE'),
#  ('JOE (passes George a bowl)', 'JOE'),
#  ('JOE DEVOLA', 'JOE DEVOLA'),
#  ('JOE DIVOLA', 'JOE DIVOLA'),
#  ("JOE'S WIFE", "JOE'S WIFE"),
#  ('JOEL', 'JOEL'),
#  ('JOEY', 'JOEY'),
#  ('JOHN', 'JOHN'),
#  ('JOHN (V.O.)', 'JOHN'),
#  ('JOHN TYLER', 'JOHN TYLER'),
#  ('JOHNNY', 'JOHNNY'),
#  ('JOY MAYO', 'JOY MAYO'),
#  ('JOYCE', 'JOYCE'),
#  ('JUDGE', 'JUDGE'),
#  ('JUDGE (banging his gavel)', 'JUDGE'),
#  ('JUDY', 'JUDY'),
#  ('JULIANNA', 'JULIANNA'),
#  ('JULIANNA (releasing her child)', 'JULIANNA'),
#  ('JULIANNA (visibly uncomfortable)', 'JULIANNA'),
#  ('JULIE', 'JULIE'),
#  ('JULIO', 'JULIO'),
#  ('James', 'James'),
#  ('Jerry and GEORGE', 'Jerry and GEORGE'),
#  ("Jerry's stand-up", "Jerry's stand-up"),
#  ('KAREN', 'KAREN'),
#  ('KARL', 'KARL'),
#  ('KATE', 'KATE'),
#  ('KATHY LEE', 'KATHY LEE'),
#  ('KATIE', 'KATIE'),
#  ('KATY', 'KATY'),
#  ('KATYA', 'KATYA'),
#  ('KEITH', 'KEITH'),
#  ('KELLY', 'KELLY'),
#  ('KEN', 'KEN'),
#  ('KEN (O.C.)', 'KEN'),
#  ('KERI', 'KERI'),
#  ('KERNIS', 'KERNIS'),
#  ('KESSLER', 'KESSLER'),
#  ('KEVIN', 'KEVIN'),
#  ('KID', 'KID'),
#  ('KID #2', 'KID #2'),
#  ('KIDS & KRAMER', 'KIDS & KRAMER'),
#  ('KIM', 'KIM'),
#  ('KIMBROUGH', 'KIMBROUGH'),
#  ('KLEIN', 'KLEIN'),
#  ('KOREN (O.C.)', 'KOREN'),
#  ('KRAMER', 'KRAMER'),
#  ('KRAMER ', 'KRAMER '),
#  ('KRAMER & GEORGE', 'KRAMER & GEORGE'),
#  ('KRAMER & JERRY', 'KRAMER & JERRY'),
#  ('KRAMER & JOEY', 'KRAMER & JOEY'),
#  ('KRAMER & MICKEY', 'KRAMER & MICKEY'),
#  ('KRAMER (O.C.)', 'KRAMER'),
#  ('KRAMER (a la Ratso Rizzo in Midnight Cowboy)', 'KRAMER'),
#  ('KRAMER (angrily, to Jerry)', 'KRAMER'),
#  ('KRAMER (approvingly)', 'KRAMER'),
#  ('KRAMER (breaking into tears)', 'KRAMER'),
#  ('KRAMER (comes back inside with his finger pointed at Jerry)', 'KRAMER'),
#  ('KRAMER (excited)', 'KRAMER'),
#  ('KRAMER (frantic)', 'KRAMER'),
#  ('KRAMER (from bathroom)', 'KRAMER'),
#  ('KRAMER (from hallway)', 'KRAMER'),
#  ('KRAMER (from his doorway)', 'KRAMER'),
#  ('KRAMER (getting up)', 'KRAMER'),
#  ('KRAMER (goes out on the terrace to look, and slips in the water)',
#   'KRAMER'),
#  ('KRAMER (happily)', 'KRAMER'),
#  ('KRAMER (holds up his hand)', 'KRAMER'),
#  ('KRAMER (impressed)', 'KRAMER'),
#  ("KRAMER (in a chef's hat and apron)", 'KRAMER'),
#  ('KRAMER (in a perfectly normal tone of voice)', 'KRAMER'),
#  ('KRAMER (in disgust)', 'KRAMER'),
#  ('KRAMER (in hallway)', 'KRAMER'),
#  ('KRAMER (into phone)', 'KRAMER'),
#  ('KRAMER (lunging for Little Jerry)', 'KRAMER'),
#  ('KRAMER (mouths the words)', 'KRAMER'),
#  ('KRAMER (moves over and sits next to George)', 'KRAMER'),
#  ('KRAMER (moving back to the othe side of the booth)', 'KRAMER'),
#  ('KRAMER (nervously)', 'KRAMER'),
#  ('KRAMER (nods)', 'KRAMER'),
#  ('KRAMER (panting)', 'KRAMER'),
#  ('KRAMER (picking up the wrapper)', 'KRAMER'),
#  ("KRAMER (points at Elaine's feet)", 'KRAMER'),
#  ("KRAMER (points at Jerry like he's found him out)", 'KRAMER'),
#  ('KRAMER (points to his head)', 'KRAMER'),
#  ('KRAMER (puts the dough on the counter)', 'KRAMER'),
#  ('KRAMER (realizing)', 'KRAMER'),
#  ('KRAMER (scanning a menu)', 'KRAMER'),
#  ("KRAMER (shouting over the cycle's engine)", 'KRAMER'),
#  ('KRAMER (shows Jerry his outfit)', 'KRAMER'),
#  ('KRAMER (shows Jerry his winnings)', 'KRAMER'),
#  ('KRAMER (singing)', 'KRAMER'),
#  ('KRAMER (sternly)', 'KRAMER'),
#  ('KRAMER (stuffing tissue up his nose)', 'KRAMER'),
#  ('KRAMER (talks rapidly in an attempt to keep up with Newman)', 'KRAMER'),
#  ('KRAMER (to Elaine)', 'KRAMER'),
#  ('KRAMER (to Jerry)', 'KRAMER'),
#  ('KRAMER (to Karen)', 'KRAMER'),
#  ('KRAMER (to Poppie)', 'KRAMER'),
#  ('KRAMER (to organizer at desk)', 'KRAMER'),
#  ('KRAMER (wipes chocolate off his face)', 'KRAMER'),
#  ('KRAMER + JERRY', 'KRAMER + JERRY'),
#  ('KRAMER and JERRY (together)', 'KRAMER and JERRY'),
#  ('KRAMER/NEWMAN', 'KRAMER/NEWMAN'),
#  ('KRAMER/Turkey', 'KRAMER/Turkey'),
#  ('KRISTIN', 'KRISTIN'),
#  ('KRMAER', 'KRMAER'),
#  ('KRUGER', 'KRUGER'),
#  ('KURT', 'KURT'),
#  ('KURT (from the bedroom)', 'KURT'),
#  ('KURT (laughs)', 'KURT'),
#  ('KURT (to Elaine)', 'KURT'),
#  ('LAB TECHNICIAN', 'LAB TECHNICIAN'),
#  ('LADY', 'LADY'),
#  ('LADY 1', 'LADY 1'),
#  ('LADY 2', 'LADY 2'),
#  ('LAMAR', 'LAMAR'),
#  ('LANDIS', 'LANDIS'),
#  ("LANDIS'S INTERCOM", "LANDIS'S INTERCOM"),
#  ('LANDLORD', 'LANDLORD'),
#  ('LANETTE', 'LANETTE'),
#  ('LARRY', 'LARRY'),
#  ('LASER GUY', 'LASER GUY'),
#  ('LAURA', 'LAURA'),
#  ('LAURA & JERRY', 'LAURA & JERRY'),
#  ('LEADER', 'LEADER'),
#  ("LEAPIN' LARRY", "LEAPIN' LARRY"),
#  ('LELAND', 'LELAND'),
#  ('LENA', 'LENA'),
#  ("LENA (smells Jerry's arm)", 'LENA'),
#  ('LENA (to waiter)', 'LENA'),
#  ('LEO', 'LEO'),
#  ('LEO (O.C.)', 'LEO'),
#  ('LESLIE', 'LESLIE'),
#  ('LETTERMAN', 'LETTERMAN'),
#  ('LEVITAN', 'LEVITAN'),
#  ('LEW', 'LEW'),
#  ('LIBRARIAN', 'LIBRARIAN'),
#  ('LINDSAY', 'LINDSAY'),
#  ('LIPPMAN', 'LIPPMAN'),
#  ('LISA', 'LISA'),
#  ('LISI', 'LISI'),
#  ('LIZ', 'LIZ'),
#  ('LLOYD', 'LLOYD'),
#  ('LOIS', 'LOIS'),
#  ('LORETTA', 'LORETTA'),
#  ('LORRAINE', 'LORRAINE'),
#  ('LORRAINE (shaking her hand)', 'LORRAINE'),
#  ('LOTUS', 'LOTUS'),
#  ('LOU', 'LOU'),
#  ('LOUISE', 'LOUISE'),
#  ('LOW-TALKER', 'LOW-TALKER'),
#  ('LT. COLEMAN', 'LT. COLEMAN'),
#  ('LT. MARTEL', 'LT. MARTEL'),
#  ('LUBECK', 'LUBECK'),
#  ('LUPE', 'LUPE'),
#  ('LYLE', 'LYLE'),
#  ('MABEL', 'MABEL'),
#  ('MACHINE', 'MACHINE'),
#  ('MACHINE (KRAMER)', 'MACHINE'),
#  ('MACKENZIE', 'MACKENZIE'),
#  ('MAESTRO', 'MAESTRO'),
#  ('MAESTRO AND ELAINE (Simultaneously)', 'MAESTRO AND ELAINE'),
#  ('MAHJONG LADY', 'MAHJONG LADY'),
#  ('MAID', 'MAID'),
#  ('MAILMAN', 'MAILMAN'),
#  ("MAITRE D'", "MAITRE D'"),
#  ('MALCOLM', 'MALCOLM'),
#  ('MALE WORKER', 'MALE WORKER'),
#  ('MAN', 'MAN'),
#  ('MAN #', 'MAN #'),
#  ('MAN #1', 'MAN #1'),
#  ('MAN #1 ', 'MAN #1 '),
#  ('MAN #2', 'MAN #2'),
#  ('MAN #2 ', 'MAN #2 '),
#  ('MAN #3', 'MAN #3'),
#  ('MAN #4', 'MAN #4'),
#  ('MAN 1', 'MAN 1'),
#  ('MAN 2', 'MAN 2'),
#  ('MAN 3', 'MAN 3'),
#  ('MAN 4', 'MAN 4'),
#  ('MAN AT THE COUNTER', 'MAN AT THE COUNTER'),
#  ('MAN BEHIND THE DOOR', 'MAN BEHIND THE DOOR'),
#  ('MAN IN AUDIENCE', 'MAN IN AUDIENCE'),
#  ('MAN IN CAR', 'MAN IN CAR'),
#  ('MAN IN NEIGHBORING BED', 'MAN IN NEIGHBORING BED'),
#  ('MAN IN SHOWER', 'MAN IN SHOWER'),
#  ('MAN IN THE CROWD', 'MAN IN THE CROWD'),
#  ('MAN ON RAFT', 'MAN ON RAFT'),
#  ('MAN ON THE STREET', 'MAN ON THE STREET'),
#  ('MAN#1', 'MAN#1'),
#  ('MAN#2', 'MAN#2'),
#  ('MAN#3', 'MAN#3'),
#  ('MAN1', 'MAN1'),
#  ('MAN2', 'MAN2'),
#  ('MAN3', 'MAN3'),
#  ('MAN4', 'MAN4'),
#  ('MANAGER', 'MANAGER'),
#  ('MANDEL', 'MANDEL'),
#  ('MANNY', 'MANNY'),
#  ('MANYA', 'MANYA'),
#  ('MANYA ', 'MANYA '),
#  ('MAR', 'MAR'),
#  ('MARCELINO', 'MARCELINO'),
#  ('MARCELINO (impressed)', 'MARCELINO'),
#  ('MARCELINO (leaving)', 'MARCELINO'),
#  ('MARCELINO (tosses the gum on the counter)', 'MARCELINO'),
#  ('MARCELLINO', 'MARCELLINO'),
#  ('MARCY', 'MARCY'),
#  ('MARGARET', 'MARGARET'),
#  ('MARIAN', 'MARIAN'),
#  ('MARIAN (turning, surprised)', 'MARIAN'),
#  ('MARIE', 'MARIE'),
#  ('MARIE (describing Holly Go-Lightly in "Breakfast At Tiffany\'s")', 'MARIE'),
#  ('MARIO', 'MARIO'),
#  ('MARION', 'MARION'),
#  ('MARISA', 'MARISA'),
#  ('MARK', 'MARK'),
#  ('MARLA', 'MARLA'),
#  ('MARLENE', 'MARLENE'),
#  ('MARRY', 'MARRY'),
#  ('MARTIN', 'MARTIN'),
#  ('MARTY', 'MARTY'),
#  ('MARTY (looking at the locket)', 'MARTY'),
#  ('MARTY (to Jerry)', 'MARTY'),
#  ('MARTY (to Meryl)', 'MARTY'),
#  ('MARY', 'MARY'),
#  ('MARY ANNE', 'MARY ANNE'),
#  ('MARYEDITH', 'MARYEDITH'),
#  ('MATTHEW', 'MATTHEW'),
#  ('MAURA', 'MAURA'),
#  ('MAXWELL', 'MAXWELL'),
#  ('MCADAM', 'MCADAM'),
#  ('MECHANIC', 'MECHANIC'),
#  ('MEL', 'MEL'),
#  ('MELANIE', 'MELANIE'),
#  ('MELISSA', 'MELISSA'),
#  ('MEMBER 1', 'MEMBER 1'),
#  ('MEMBER 2', 'MEMBER 2'),
#  ('MERYL', 'MERYL'),
#  ("MERYL (feels Jerry's material)", 'MERYL'),
#  ('MERYL (getting up)', 'MERYL'),
#  ('MERYL (looking for the can opener)', 'MERYL'),
#  ('MERYL (looking in the drawer)', 'MERYL'),
#  ('MERYL (not finding the opener)', 'MERYL'),
#  ("MERYL (throws Paula's clothes at Jerry)", 'MERYL'),
#  ('MICHAEL', 'MICHAEL'),
#  ('MICKEY', 'MICKEY'),
#  ('MIKE', 'MIKE'),
#  ('MILOS', 'MILOS'),
#  ('MINKLER', 'MINKLER'),
#  ('MIRANDA', 'MIRANDA'),
#  ('MISHA', 'MISHA'),
#  ('MISS RHODE ISLAND', 'MISS RHODE ISLAND'),
#  ('MODEL #1', 'MODEL #1'),
#  ('MODEL #2', 'MODEL #2'),
#  ('MODEL #3', 'MODEL #3'),
#  ('MODEL #4', 'MODEL #4'),
#  ('MOHEL', 'MOHEL'),
#  ('MOLLIKA', 'MOLLIKA'),
#  ('MOLLY', 'MOLLY'),
#  ...]

# %%
# Let's update the character column
df9 = df8.copy()
df9['character'] = [paren_removal(char) for char in df8.character]

char_list3 = df9.character.sort_values().unique()
print(len(char_list3))
list(char_list3)
# Out:
# 1121
# ['AARON',
#  'AARON & HELEN',
#  'ABBY',
#  'ADA',
#  'ADAM',
#  'ADE',
#  'AENT',
#  'AGENCY REP',
#  'AGENT',
#  'AL',
#  'AL ROKER',
#  'ALAN',
#  'ALEC',
#  'ALEX',
#  'ALEX TREBEK',
#  'ALICIA',
#  'ALISON',
#  'ALL',
#  'ALL FOUR MEN',
#  'ALL THREE',
#  'ALLBRIGHT',
#  'ALLISON',
#  'ALLSION',
#  'ALTON',
#  'AMANDA',
#  'AMY',
#  'ANGELA',
#  'ANGRY MAN',
#  'ANNA',
#  'ANNOUNCEMENT',
#  'ANNOUNCER',
#  'ANNOUNCER #1',
#  'ANNOUNCER #2',
#  'ANNOUNCER ON P.A. SYSTEM',
#  'ANNOUNCER ON TV',
#  'ANSWERING MACHINE',
#  'ANTONIO',
#  'APPLICANT',
#  'ARNIE',
#  'ARONSON',
#  'ARTIE',
#  'ASSISTANT',
#  'ASSISTANT DRESSER',
#  'ATTENDANT',
#  'ATTENDANT #1',
#  'ATTENDANT #2',
#  'AUCTIONEER',
#  'AUDIENCE',
#  'AUDREY',
#  'AUNT MAY',
#  'AVA',
#  'Announcer',
#  'Another man',
#  'BABS',
#  'BABU',
#  "BABU'S BROTHER",
#  "BABU'S FRIEND",
#  'BAILIFF',
#  'BANIA',
#  'BANK EMPLOYEE',
#  'BARBARA',
#  "BARNEY'S SALES ASSOCIATE",
#  'BARRY',
#  'BARTENDER',
#  'BECK',
#  'BECKY',
#  'BEN',
#  'BENES',
#  'BETH',
#  'BETSY',
#  'BETTE',
#  'BIKER',
#  'BILL',
#  'BILLY',
#  'BLAINE',
#  'BLIND MAN',
#  'BLIND VIOLIN PLAYER',
#  'BOB',
#  'BOBBY',
#  'BOMB COP',
#  'BONNIE',
#  'BOOKIE',
#  'BOOKMAN',
#  'BOSS',
#  "BOSS' WIFE",
#  'BOTH',
#  'BOUNCER',
#  'BOY',
#  'BOYFRIEND',
#  'BRADY',
#  'BRETT',
#  'BRIDGET',
#  'BRODY',
#  'BRUCE',
#  'BRYANT',
#  'BUBBLE BOY',
#  'BUCKLES',
#  'BUDDY',
#  'BUILDING A',
#  'BUILDING B',
#  'BUILDING C',
#  'BUSINESS MAN',
#  'BUSINESSMAN',
#  'BUXOM WOMAN',
#  'BUZZER',
#  'BYSTANDER #1',
#  'BYSTANDER #2',
#  'Babu Bhatt',
#  'Banker',
#  'Beginnings',
#  'Boysenberry',
#  'Bruce',
#  'C.K.',
#  'CAB DRIVER',
#  'CABBIE',
#  'CABBY',
#  'CALVIN KLEIN',
#  'CANDICE BERGEN',
#  'CAPTAIN',
#  'CAR SALESMAN',
#  'CAR THIEF',
#  'CAR WASHER',
#  'CARL',
#  'CAROL',
#  'CARRERAS',
#  'CARRIE',
#  'CASHIER',
#  'CASTING DIRECTOR',
#  'CASTRO',
#  'CEDRIC',
#  'CELIA',
#  'CHAIRMAN',
#  'CHARLES',
#  'CHARLIE',
#  'CHARMAINE',
#  'CHAUFFEUR',
#  'CHELSEA',
#  'CHERYL',
#  'CHILES',
#  'CHIROPRACTOR',
#  'CHOATE',
#  'CHRISTIE',
#  'CINDY',
#  'CLAIE',
#  'CLAIRE',
#  'CLARE',
#  'CLAYTON',
#  'CLEANING WOMAN',
#  'CLERK',
#  'CLERK 2',
#  'CLERK\x92S VOICE',
#  'CLICKY',
#  'CLOTWORTHY',
#  'CLUB ANNOUNCER',
#  'CLYDE',
#  'CO-WORKER',
#  'CO-WORKER #1',
#  'CO-WORKER #2',
#  'COCO',
#  'COMPUTER VOICE',
#  'CONNIE',
#  'CONRAD',
#  'CONTEST WINNER',
#  'COP',
#  'COP #1',
#  'COP #2',
#  'COP 2',
#  'COPS',
#  'CORBIN BERNSEN',
#  'CORINNE',
#  'COUNTER WOMAN',
#  'COUNTERPERSON',
#  'COWORKER',
#  'CRAIG',
#  'CRESPI',
#  'CREW LEADER',
#  'CROWD',
#  'CUSTOMER',
#  'CYNTHIA',
#  'Check #1246, dated Dec. 15 \x9196, Made out to',
#  'Claims to Fame',
#  'DAN',
#  'DANA',
#  'DANIELLE',
#  'DANNY TARTABULL',
#  'DAPHNE',
#  'DARREN',
#  'DARRYL',
#  'DAVID',
#  'DAVOLA',
#  'DEAN JONES',
#  'DEBBY',
#  'DEENA',
#  'DEENSFREI',
#  'DELIVERY BOY',
#  'DELIVERY GUY',
#  'DELIVERY MAN',
#  'DENIM VEST',
#  'DENISE',
#  'DENNIS',
#  'DENTIST',
#  'DEPUTY',
#  'DETECTIVE',
#  'DETECTIVE #1',
#  'DETECTIVE #2',
#  'DEVOLA',
#  'DIANE',
#  'DICK',
#  'DIRECTOR',
#  'DISPATCHER',
#  'DJ ON RADIO',
#  'DOCTER',
#  'DOCTOR',
#  'DOG OWNER',
#  'DOLL',
#  'DOLORES',
#  'DONALD',
#  'DONNA',
#  'DONNA ',
#  'DOORMAN',
#  'DOORMAN 2',
#  'DORIS',
#  'DR. ALLENWOOD',
#  'DR. BAKERSOLL',
#  'DR. COOPERMAN',
#  'DR. DEMBROW',
#  'DR. RESTON',
#  'DR. WEXLER',
#  'DRIVER',
#  'DRY CLEANE',
#  'DRY CLEANER',
#  'DUGAN',
#  'DUNCAN',
#  'DUNCAN & JERRY',
#  'DUSTIN',
#  'DUSTIN - Locker room Attendant #2',
#  'DWAYNE',
#  'Dedication',
#  'Driver',
#  'Dugan',
#  'Dx',
#  'EALINE',
#  'EARL',
#  'ECHO',
#  'ED',
#  'EDDIE',
#  'EDDIT',
#  'EGO',
#  'ELAIEN',
#  'ELAINE',
#  'ELAINE ',
#  'ELAINE & GEORGE',
#  'ELAINE & JERRY',
#  'ELAINE & PUDDY',
#  'ELAINE & RAY',
#  'ELAINE AND JERRY',
#  'ELAINE AND PUDDY',
#  'ELAINE and KRAMER',
#  "ELAINE'S VOICE",
#  "ELAINE's brain",
#  'ELAINE/DAVOLA',
#  'ELAINE/JERRY',
#  'ELAINE/WENDY',
#  'ELANE',
#  'ELDRIDGE',
#  'ELECTRICIAN',
#  'ELIANE',
#  'ELLEN',
#  'EMILY',
#  'EMPLOYEE',
#  'ENZO',
#  'ERIC',
#  'ESTELLE',
#  'ETHAN',
#  'EULOGIST',
#  'EVA',
#  'EVELYN',
#  'EVERYBODY',
#  'EVERYONE',
#  'EXECUTIVE 1',
#  'EXECUTIVE 2',
#  'ElainELAINE',
#  'Elaine',
#  'Elaine + JERRY',
#  'Elaine thinking',
#  'Elaine, becoming board',
#  'Ex',
#  'FAN',
#  'FAN #1',
#  'FARKUS',
#  'FARMER',
#  'FATHER',
#  'FATHER CURTIS',
#  'FATHER HERNANDEZ',
#  'FATHER JESSUP',
#  'FATHER-PRIEST',
#  'FATHER-PRIEST 2',
#  'FDR',
#  'FELDMAN',
#  'FEMALE CUSTOMER',
#  'FEMALE WORKER',
#  'FIREMAN',
#  'FLIGHT ATTENDANT',
#  'FLORIST',
#  'FOREMAN',
#  'FOWLER',
#  'FRANK',
#  'FRANKIE',
#  'FRED',
#  'FRED SAVAGE',
#  'FRIEND',
#  'FRIEND 1',
#  'FULTON',
#  'FURNITURE GUY',
#  'Frank',
#  'Frank Costanza',
#  'Frank and ESTELLE',
#  'GAIL',
#  'GARDNER',
#  'GARY',
#  'GAS STATION ATTENDANT',
#  'GAURD',
#  'GAVIN',
#  'GENE',
#  'GENNICE',
#  'GEOGE',
#  'GEORGE',
#  'GEORGE ',
#  'GEORGE & ELAINE',
#  'GEORGE & JERRY',
#  'GEORGE & KRAMER',
#  'GEORGE AND JERRY',
#  'GEORGE WENDT',
#  "GEORGE'S VOICE",
#  'GEORGE, ELAINE, KRAMER, JERRY, & STAN',
#  'GEORGE/JERRY/ELAINE/WENDY',
#  'GEORGE/SUSAN',
#  'GEPETTO',
#  'GERMAN WOMAN',
#  'GEROGE',
#  'GIGGIO',
#  'GILLIAN',
#  'GINA',
#  'GINO',
#  'GIRL',
#  'GIRLFRIEND',
#  'GIULIANI',
#  'GLADYS',
#  'GLENDA',
#  'GLENN',
#  'GOERGE',
#  'GRANDPA',
#  'GREENY',
#  'GREG',
#  'GROSSBARD',
#  'GROUP',
#  'GUAD',
#  'GUARD',
#  'GUESTS, JERRY & ELAINE',
#  'GUILLERMO',
#  'GUY',
#  'GUY ON PHONE',
#  'GWEN',
#  'GX',
#  'Genderson',
#  'Guy1',
#  'HAARWOOD',
#  'HAFFLER',
#  'HAIRDRESSER',
#  'HAL',
#  'HALLIE',
#  'HANKE',
#  'HAROLD',
#  'HEAD',
#  'HEALTH INSPECTOR',
#  'HELEN',
#  'HELEN & AARON',
#  'HELEN & MORTY',
#  'HELENA',
#  'HENRY',
#  'HERB',
#  'HEYMAN',
#  'HIGH PITCHED VOICE',
#  'HILDE',
#  'HIPPIE #1',
#  'HIPPIE #2',
#  'HOLE DIGGER',
#  'HOLE DIGGER #2',
#  'HOLLY',
#  'HOMELESS MAN',
#  'HOMELESS MAN 2',
#  'HOOKER',
#  'HORST',
#  'HOSPITAL VOICEOVER',
#  'HOSTESS',
#  'HOT DOG VENDOR',
#  'HOTEL CLERK',
#  'HOUSEKEEPER',
#  'HOYT',
#  'HUSBAND',
#  'Huckleberry',
#  'Hx',
#  'I always feel bad for the silver medal winner in the Olympics. How do you live with that the rest of your life? People are gonna keep asking',
#  "I always get confused in the movie theater by the, by the plot. It's embarrassing. It's an embarrassment to have to admit, but I'm the one that you see in the parking lot after the movie talking with his friends, going",
#  'I am not gay. I am, however, thin, single and neat. Sometimes when someone is thin, single and neat people assume they are gay because that is a stereotype. They normally don\'t think of gay people as fat, sloppy and married. Although I\'m sure there are, I don\'t want to perpetuate the stereotype. I\'m sure they are the minority though within the gay community. They\'re probably discriminated against because of that, people say to them "Y\'know Joe, I enjoy being gay with you but I think think it\'s about time, y\'know that you got in shape, tucked the shirt in and lost the wife". But if people are even going to assume that people that are neat are gay, maybe instead of doin\' this',
#  'I think the thing I admire most about the Chinese is that they\'re hanging in there with the chopsticks. Because, if you think about it, you know, they\'ve seen the fork... by now. I\'m sure they\'ve seen the spoon, they\'re going, "Yeah, yeah, they\'re OK... We\'re going to stay with the sticks." I mean, I don\'t know how they\'ve missed it',
#  'IAN',
#  'ICE CREAM VENDER #1',
#  'ICE CREAM VENDER #2',
#  'ILENE',
#  'ISAAC',
#  'ISABEL',
#  'IZZY',
#  'IZZY & IZZY JR.',
#  'IZZY IZZY SR..',
#  'IZZY JR.',
#  'IZZY SR.',
#  'IZZY/IZZY JR/IZZY IZZY SR.',
#  'Inside Kew Gardens Reprinted from an article in the October 1982 issue of Metropolis Magazine. http',
#  'J. PETERMAN',
#  'JACK',
#  'JACKIE',
#  'JACKIE ',
#  'JAKE',
#  'JAMES',
#  'JANE',
#  'JANET',
#  'JANICE',
#  'JAY',
#  'JAY LENO',
#  'JEAN-PAUL',
#  'JEANINE',
#  'JEANNIE',
#  'JEFF',
#  'JENNA',
#  'JENNY',
#  'JERR',
#  'JERRY',
#  'JERRY ',
#  'JERRY & COP',
#  'JERRY & ELAINE',
#  'JERRY & GEORGE',
#  'JERRY & George',
#  'JERRY & JEANNIE',
#  'JERRY & KRAMER',
#  'JERRY & TIA',
#  'JERRY AND ELAINE',
#  'JERRY AND GEORGE',
#  'JERRY AND JOEL',
#  'JERRY AND KRAMER',
#  'JERRY AND NEWMAN',
#  'JERRY and ELAINE',
#  'JERRY and ELAINE, together',
#  'JERRY and GEORGE',
#  'JERRY and KRAMER',
#  'JERRY and NEWMAN',
#  'JERRY&ELAINE',
#  "JERRY'S ANSWERING MACHINE",
#  "JERRY'S BRAIN",
#  "JERRY'S MACHINE",
#  "JERRY'S PENIS",
#  "JERRY'S brain",
#  "JERRY's brain",
#  'JERRY, GEORGE & ELAINE',
#  'JERRY, GEORGE & KRAMER',
#  'JERRY, GEORGE, & KRAMER',
#  'JERRY, GEORGE, ELAINE',
#  'JERRY, KRAMER & NEWMAN',
#  'JERRY, MORTY AND HELEN',
#  'JERRY\x92S MESSAGE',
#  'JERRY\x92S OUTGOING MESSAGE',
#  'JERY',
#  'JESSIE',
#  'JETER',
#  'JIM',
#  'JIMMY',
#  'JOAN',
#  'JOANNE',
#  'JODI',
#  'JOE',
#  'JOE DEVOLA',
#  'JOE DIVOLA',
#  "JOE'S WIFE",
#  'JOEL',
#  'JOEY',
#  'JOHN',
#  'JOHN TYLER',
#  'JOHNNY',
#  'JOY MAYO',
#  'JOYCE',
#  'JUDGE',
#  'JUDY',
#  'JULIANNA',
#  'JULIE',
#  'JULIO',
#  'James',
#  'Jerry and GEORGE',
#  "Jerry's stand-up",
#  'KAREN',
#  'KARL',
#  'KATE',
#  'KATHY LEE',
#  'KATIE',
#  'KATY',
#  'KATYA',
#  'KEITH',
#  'KELLY',
#  'KEN',
#  'KERI',
#  'KERNIS',
#  'KESSLER',
#  'KEVIN',
#  'KID',
#  'KID #2',
#  'KIDS & KRAMER',
#  'KIM',
#  'KIMBROUGH',
#  'KLEIN',
#  'KOREN',
#  'KRAMER',
#  'KRAMER ',
#  'KRAMER & GEORGE',
#  'KRAMER & JERRY',
#  'KRAMER & JOEY',
#  'KRAMER & MICKEY',
#  'KRAMER + JERRY',
#  'KRAMER and JERRY',
#  'KRAMER/NEWMAN',
#  'KRAMER/Turkey',
#  'KRISTIN',
#  'KRMAER',
#  'KRUGER',
#  'KURT',
#  'LAB TECHNICIAN',
#  'LADY',
#  'LADY 1',
#  'LADY 2',
#  'LAMAR',
#  'LANDIS',
#  "LANDIS'S INTERCOM",
#  'LANDLORD',
#  'LANETTE',
#  'LARRY',
#  'LASER GUY',
#  'LAURA',
#  'LAURA & JERRY',
#  'LEADER',
#  "LEAPIN' LARRY",
#  'LELAND',
#  'LENA',
#  'LEO',
#  'LESLIE',
#  'LETTERMAN',
#  'LEVITAN',
#  'LEW',
#  'LIBRARIAN',
#  'LINDSAY',
#  'LIPPMAN',
#  'LISA',
#  'LISI',
#  'LIZ',
#  'LLOYD',
#  'LOIS',
#  'LORETTA',
#  'LORRAINE',
#  'LOTUS',
#  'LOU',
#  'LOUISE',
#  'LOW-TALKER',
#  'LT. COLEMAN',
#  'LT. MARTEL',
#  'LUBECK',
#  'LUPE',
#  'LYLE',
#  'MABEL',
#  'MACHINE',
#  'MACKENZIE',
#  'MAESTRO',
#  'MAESTRO AND ELAINE',
#  'MAHJONG LADY',
#  'MAID',
#  'MAILMAN',
#  "MAITRE D'",
#  'MALCOLM',
#  'MALE WORKER',
#  'MAN',
#  'MAN #',
#  'MAN #1',
#  'MAN #1 ',
#  'MAN #2',
#  'MAN #2 ',
#  'MAN #3',
#  'MAN #4',
#  'MAN 1',
#  'MAN 2',
#  'MAN 3',
#  'MAN 4',
#  'MAN AT THE COUNTER',
#  'MAN BEHIND THE DOOR',
#  'MAN IN AUDIENCE',
#  'MAN IN CAR',
#  'MAN IN NEIGHBORING BED',
#  'MAN IN SHOWER',
#  'MAN IN THE CROWD',
#  'MAN ON RAFT',
#  'MAN ON THE STREET',
#  'MAN#1',
#  'MAN#2',
#  'MAN#3',
#  'MAN1',
#  'MAN2',
#  'MAN3',
#  'MAN4',
#  'MANAGER',
#  'MANDEL',
#  'MANNY',
#  'MANYA',
#  'MANYA ',
#  'MAR',
#  'MARCELINO',
#  'MARCELLINO',
#  'MARCY',
#  'MARGARET',
#  'MARIAN',
#  'MARIE',
#  'MARIO',
#  'MARION',
#  'MARISA',
#  'MARK',
#  'MARLA',
#  'MARLENE',
#  'MARRY',
#  'MARTIN',
#  'MARTY',
#  'MARY',
#  'MARY ANNE',
#  'MARYEDITH',
#  'MATTHEW',
#  'MAURA',
#  'MAXWELL',
#  'MCADAM',
#  'MECHANIC',
#  'MEL',
#  'MELANIE',
#  'MELISSA',
#  'MEMBER 1',
#  'MEMBER 2',
#  'MERYL',
#  'MICHAEL',
#  'MICKEY',
#  'MIKE',
#  'MILOS',
#  'MINKLER',
#  'MIRANDA',
#  'MISHA',
#  'MISS RHODE ISLAND',
#  'MODEL #1',
#  'MODEL #2',
#  'MODEL #3',
#  'MODEL #4',
#  'MOHEL',
#  'MOLLIKA',
#  'MOLLY',
#  'MOM',
#  'MONA',
#  'MONICA',
#  "MONK'S MANAGER",
#  'MOONEY',
#  'MORGAN',
#  'MORGANEWMAN',
#  'MORTY',
#  'MORTY/HELEN/JERRY',
#  'MOTHER',
#  'MOVIE PATRON',
#  'MOVIE PHONE GUY',
#  'MR BURNS',
#  'MR OH',
#  'MR REICHMAN',
#  'MR ROSS',
#  'MR STAR',
#  'MR TANAKA',
#  'MR YAMAGUCHI',
#  'MR. ABBOTT',
#  'MR. ARM',
#  'MR. BEVILACQUA',
#  'MR. COHEN',
#  'MR. CROSS',
#  'MR. CUSHMAN',
#  'MR. ELINOFF',
#  'MR. GOLDSTEIN',
#  'MR. GRAHAM',
#  'MR. GREEN',
#  'MR. LIPPMAN',
#  'MR. MORGAN',
#  'MR. PETERMAN',
#  'MR. PITT',
#  'MR. PLESS',
#  'MR. ROSS',
#  'MR. S',
#  'MR. SANGER',
#  'MR. STEINBRENNER',
#  'MR. THOMASSOULO',
#  'MR. TUTTLE',
#  'MR.THOMASSOULO',
#  'MRS ALLISTER',
#  'MRS HAMILTON',
#  'MRS REICHMAN',
#  'MRS WILHELM',
#  'MRS. ANVINO',
#  'MRS. C',
#  'MRS. CHOATE',
#  'MRS. COSTANZA',
#  'MRS. ENRIGHT',
#  'MRS. O',
#  'MRS. PAYTON',
#  'MRS. PETERMAN',
#  'MRS. ROSS',
#  'MRS. S',
#  'MRS. SANGER',
#  'MRS. SOKOL',
#  'MRS. SWEEDLER',
#  'MRS. ZANFINO',
#  'MRS.ARM',
#  'MS. BAINES',
#  'MS. DE GRANMONT',
#  'MS. JORDAN',
#  'MUSIC GUY',
#  'MYRA',
#  'Man',
#  "Micheal, Sandi, and Tom, and finally Jerry, and the four of them make a toast while it's written",
#  'Mr. VISAKI',
#  'Mrs. SANGER',
#  'Mrs. SWEEDLER',
#  'NAKED MAN',
#  'NANA',
#  'NANCY',
#  'NAOMI',
#  'NARRATOR',
#  'NED',
#  'NEIGHBOR',
#  'NEIL',
#  'NEMWAN',
#  'NEPHEW',
#  'NEWMAN',
#  'NEWMAN & KRAMER',
#  'NEWMAN AND KRAMER',
#  'NEWMAN and KRAMER',
#  'NEWMAN/KRAMER',
#  'NEWMANEWMAN',
#  'NEWS',
#  'NEWSSTAND OWNER',
#  'NICK',
#  'NIKKI',
#  'NINA',
#  'NOEL',
#  'NOREEN',
#  'NOTE',
#  'NUN',
#  'NURSE',
#  'NURSE 1',
#  'Nana',
#  'Newman',
#  'Newscaster',
#  'Notes',
#  'Notice',
#  "O'NEILL",
#  'OFFICER',
#  'OLD GUY',
#  'OLD MAN',
#  'OLD MAN #2',
#  'OLD MAN #3',
#  'OLD WOMAN',
#  'OLDER MAN',
#  'OLDER WOMAN',
#  'OLIVE',
#  'ORDERLY',
#  'ORGANIZER',
#  'OTHER CO-WORKERS IN HALLWAY',
#  'OTHER GUY',
#  'OTHER SECURITY GUARD',
#  'OTHER-WALTER',
#  'OWNER',
#  'Off stage',
#  'Opening Monolog',
#  'Opening scene',
#  'PAM',
#  'PAMELA',
#  'PARAMEDIC',
#  'PARK GUY#1',
#  'PARK GUY#2',
#  'PARRY',
#  'PARTY GUEST',
#  'PASSENGER',
#  'PASSENGER #1',
#  'PASSENGER #2',
#  'PASSENGER #3',
#  'PASSENGER 2',
#  'PASSERBY',
#  'PAT',
#  'PAT HAZELL',
#  'PATIENT',
#  'PATRICE',
#  'PATTI',
#  'PATTY',
#  'PAUL',
#  'PAUL - Locker room Attendant #1',
#  'PAULA',
#  'PEGGY',
#  'PENNY',
#  'PENSKY',
#  'PEOPLE AT TABLE',
#  'PETE',
#  'PETER',
#  'PETERMAN',
#  'PHARMACIST',
#  'PHIL',
#  'PHILBIN',
#  'PHONE',
#  'PHONE MAN',
#  'PHONE TAPE',
#  'PHOTOGRAPHER',
#  'PING',
#  'PINTER',
#  'PITT',
#  'PLAYER',
#  'POKER PLAYER #1',
#  'POKER PLAYER #2',
#  'POKER PLAYER #3',
#  'POKER PLAYER #4',
#  'POLICE',
#  'POLICE OFFICER',
#  'POLICE RADIO',
#  'POLICEMAN',
#  'POP',
#  'POPPIE',
#  'POSTAL EMPLOYEE',
#  'POSTMAN',
#  'POSTMASTER GENERAL',
#  'PREGNANT WOMAN',
#  'PRIEST',
#  'PRISONER',
#  'PRISONER 1',
#  'PRISONER 2',
#  'PRISONER 3',
#  'PROSTITUTE',
#  'PUDDY',
#  'PUERTO RICAN MAN',
#  'Performed by',
#  'Phil',
#  'Police officer',
#  'Published',
#  'RABBI',
#  'RACHEL',
#  'RADIO',
#  'RADIO ANNOUNCER',
#  'RALPH',
#  'RAMON',
#  'RAQUEL',
#  'RAVA',
#  'RAY',
#  'RAYMOND',
#  'READER',
#  'REBECCA',
#  'RECEPTIONIST',
#  'REFEREE',
#  'REGIS',
#  'REILLY',
#  'REMY',
#  'RENE',
#  'RENTAL CAR AGENT',
#  'REPAIRMAN',
#  'REPORTER',
#  'REPORTERS',
#  'RESIDENT',
#  'RESTAURANT MANAGER',
#  'RESTAURATEUR',
#  'RESTON',
#  'RHISA',
#  'RICARDI',
#  'RICHIE',
#  'RICK',
#  'RICKEY',
#  'RICKY',
#  "RICKY'S BOSS",
#  'RITA',
#  'RIVERA',
#  'ROBBER',
#  'ROBERT',
#  'ROBERTA',
#  'ROBIN',
#  "ROBIN'S MOTHER",
#  'ROCHELLE',
#  'ROGER',
#  'RON',
#  'RONNIE',
#  'ROXANNE',
#  'ROY',
#  'RUBY',
#  'RUDY',
#  'RULA',
#  'RUSSEL',
#  'RUSSELL',
#  'RUSTY',
#  'RUTHIE',
#  'Readers',
#  'Receptionist',
#  'SAILOR',
#  'SAL BASS',
#  'SALES WOMAN',
#  'SALESMAN',
#  'SALESWOMAN',
#  'SALLY',
#  'SAM',
#  "SAM'S VOICE",
#  'SANDI',
#  'SANDOS BROTHER 1',
#  'SANDOS BROTHER 2',
#  'SANDRA',
#  'SANDY',
#  'SANSEI',
#  'SARA',
#  'SASHA',
#  'SCOTT',
#  'SECRETARY',
#  'SECURITY GUARD',
#  'SHARON',
#  'SHEILA',
#  'SHELLBACH',
#  'SHELLY',
#  'SHERRY',
#  'SHLOMO',
#  'SHOWALTER',
#  'SID',
#  'SIDRA',
#  'SIENA',
#  'SILVIO',
#  'SIMON',
#  'SISTER ROBERTA',
#  'SKYCAP',
#  'SLIPPERT PETE',
#  'SLIPPERY PETE',
#  'SOME GUY',
#  'SON',
#  'SOPHIE',
#  'SOUP NAZI',
#  'SPEAKER',
#  'SPIKE',
#  'SPONSER',
#  'SPONSOR',
#  'STACEY',
#  'STAGE HAND',
#  'STAGEHAND',
#  'STAN',
#  'STATIONER',
#  'STEFANIE',
#  'STEIN',
#  'STEINBRENNER',
#  'STELLA',
#  'STEVE',
#  'STEVEN',
#  'STEWARDESS',
#  'STOCK BOY',
#  'STORE MANAGER',
#  'STRANGER',
#  'STREET TOUGH',
#  'STU',
#  'STUDENT #1',
#  'STUDENT #2',
#  'STUDENT 1',
#  'STUDENT 2',
#  'STUDENT 3',
#  'STUDIO GUARD',
#  'SUBWAY ANNOUNCEMENT',
#  'SUE ELLEN',
#  'SUNNY',
#  'SUPER',
#  'SUPERVISOR',
#  'SUSAN',
#  'SUSAN AND ALLSION',
#  'SUSIE',
#  'SYLVIA',
#  'Sari / Saree',
#  'Scene',
#  'SeConrad',
#  'Song over the end credits',
#  'Sponer',
#  'Stu',
#  'Sung by',
#  'TABACHNICK',
#  'TALL GIRL',
#  'TAMMY',
#  'TAN',
#  'TANNOY',
#  'TAPE PLAYER',
#  'TAPE RECORDER',
#  'TARA',
#  'TARTABULL',
#  'TARTBULL',
#  'TAWNI',
#  'TAXI DRIVER',
#  ...]

# %%
weird_char_list = [
    "Micheal, Sandi, and Tom, and finally Jerry, and the four of them make a toast while it's written",
    "Inside Kew Gardens Reprinted from an article in the October 1982 issue of Metropolis Magazine. http",
    "GEORGE, ELAINE, KRAMER, JERRY, & STAN",
    "DUSTIN - Locker room Attendant #2",
    "Check #1246, dated Dec. 15 \x9196, Made out to"]

print([len(weirdo) for weirdo in weird_char_list])
# Out:
# [96, 99, 37, 33, 43]

# %%
mask = list(map(lambda x: len(x) > 40, df9.character))
df9[mask]

# standup bits without JERRY there: 54-6-1, 57-15-1, 65-16-1
# description with a colon somewhere in there: 64-8-1
# Let's delete all of these rows
# Out:
#      ep_num  scene_num  line_num  \
# 635      54          6         1
# 535      57         15         1
# 434      64          8         1
# 860      65         16         1
# 31       90          2         1
# 826      90         20         9
# 33      115          2         1
# 974     122         26        14
# 139     145          4         1
#
#                                              character  \
# 635  I always get confused in the movie theater by ...
# 535  I am not gay. I am, however, thin, single and ...
# 434  Micheal, Sandi, and Tom, and finally Jerry, an...
# 860  The female orgasm is kinda like the bat cave, ...
# 31   I think the thing I admire most about the Chin...
# 826  Inside Kew Gardens Reprinted from an article i...
# 33   I always feel bad for the silver medal winner ...
# 974  This is the guy who traded Jay Buhner for Ken ...
# 139        Check #1246, dated Dec. 15 96, Made out to
#
#                                                   line
# 635  ``Oh, you mean that was the same guy from the ...
# 535  "Y'know I think Joe might be a little... [wave...
# 434   "Created by Jerry Seinfeld and George Costanza".
# 860  the real and the fake. And uh I'll tell you ri...
# 31   thousands of years ago, Chinese farmer gets up...
# 826                           //www.metropolismag.com/
# 33   - How much did you lose by? - I don't even kno...
# 974  "How could you trade Jay Buhner?!" "My people ...
# 139                           Columbus Deli for $40.00

# %%
df10 = df9[[not x for x in mask]]

char_list4 = df10.character.sort_values().unique()
print(len(char_list4))
pprint(list(char_list4))
# Out:
# 1112
# ['AARON',
#  'AARON & HELEN',
#  'ABBY',
#  'ADA',
#  'ADAM',
#  'ADE',
#  'AENT',
#  'AGENCY REP',
#  'AGENT',
#  'AL',
#  'AL ROKER',
#  'ALAN',
#  'ALEC',
#  'ALEX',
#  'ALEX TREBEK',
#  'ALICIA',
#  'ALISON',
#  'ALL',
#  'ALL FOUR MEN',
#  'ALL THREE',
#  'ALLBRIGHT',
#  'ALLISON',
#  'ALLSION',
#  'ALTON',
#  'AMANDA',
#  'AMY',
#  'ANGELA',
#  'ANGRY MAN',
#  'ANNA',
#  'ANNOUNCEMENT',
#  'ANNOUNCER',
#  'ANNOUNCER #1',
#  'ANNOUNCER #2',
#  'ANNOUNCER ON P.A. SYSTEM',
#  'ANNOUNCER ON TV',
#  'ANSWERING MACHINE',
#  'ANTONIO',
#  'APPLICANT',
#  'ARNIE',
#  'ARONSON',
#  'ARTIE',
#  'ASSISTANT',
#  'ASSISTANT DRESSER',
#  'ATTENDANT',
#  'ATTENDANT #1',
#  'ATTENDANT #2',
#  'AUCTIONEER',
#  'AUDIENCE',
#  'AUDREY',
#  'AUNT MAY',
#  'AVA',
#  'Announcer',
#  'Another man',
#  'BABS',
#  'BABU',
#  "BABU'S BROTHER",
#  "BABU'S FRIEND",
#  'BAILIFF',
#  'BANIA',
#  'BANK EMPLOYEE',
#  'BARBARA',
#  "BARNEY'S SALES ASSOCIATE",
#  'BARRY',
#  'BARTENDER',
#  'BECK',
#  'BECKY',
#  'BEN',
#  'BENES',
#  'BETH',
#  'BETSY',
#  'BETTE',
#  'BIKER',
#  'BILL',
#  'BILLY',
#  'BLAINE',
#  'BLIND MAN',
#  'BLIND VIOLIN PLAYER',
#  'BOB',
#  'BOBBY',
#  'BOMB COP',
#  'BONNIE',
#  'BOOKIE',
#  'BOOKMAN',
#  'BOSS',
#  "BOSS' WIFE",
#  'BOTH',
#  'BOUNCER',
#  'BOY',
#  'BOYFRIEND',
#  'BRADY',
#  'BRETT',
#  'BRIDGET',
#  'BRODY',
#  'BRUCE',
#  'BRYANT',
#  'BUBBLE BOY',
#  'BUCKLES',
#  'BUDDY',
#  'BUILDING A',
#  'BUILDING B',
#  'BUILDING C',
#  'BUSINESS MAN',
#  'BUSINESSMAN',
#  'BUXOM WOMAN',
#  'BUZZER',
#  'BYSTANDER #1',
#  'BYSTANDER #2',
#  'Babu Bhatt',
#  'Banker',
#  'Beginnings',
#  'Boysenberry',
#  'Bruce',
#  'C.K.',
#  'CAB DRIVER',
#  'CABBIE',
#  'CABBY',
#  'CALVIN KLEIN',
#  'CANDICE BERGEN',
#  'CAPTAIN',
#  'CAR SALESMAN',
#  'CAR THIEF',
#  'CAR WASHER',
#  'CARL',
#  'CAROL',
#  'CARRERAS',
#  'CARRIE',
#  'CASHIER',
#  'CASTING DIRECTOR',
#  'CASTRO',
#  'CEDRIC',
#  'CELIA',
#  'CHAIRMAN',
#  'CHARLES',
#  'CHARLIE',
#  'CHARMAINE',
#  'CHAUFFEUR',
#  'CHELSEA',
#  'CHERYL',
#  'CHILES',
#  'CHIROPRACTOR',
#  'CHOATE',
#  'CHRISTIE',
#  'CINDY',
#  'CLAIE',
#  'CLAIRE',
#  'CLARE',
#  'CLAYTON',
#  'CLEANING WOMAN',
#  'CLERK',
#  'CLERK 2',
#  'CLERK\x92S VOICE',
#  'CLICKY',
#  'CLOTWORTHY',
#  'CLUB ANNOUNCER',
#  'CLYDE',
#  'CO-WORKER',
#  'CO-WORKER #1',
#  'CO-WORKER #2',
#  'COCO',
#  'COMPUTER VOICE',
#  'CONNIE',
#  'CONRAD',
#  'CONTEST WINNER',
#  'COP',
#  'COP #1',
#  'COP #2',
#  'COP 2',
#  'COPS',
#  'CORBIN BERNSEN',
#  'CORINNE',
#  'COUNTER WOMAN',
#  'COUNTERPERSON',
#  'COWORKER',
#  'CRAIG',
#  'CRESPI',
#  'CREW LEADER',
#  'CROWD',
#  'CUSTOMER',
#  'CYNTHIA',
#  'Claims to Fame',
#  'DAN',
#  'DANA',
#  'DANIELLE',
#  'DANNY TARTABULL',
#  'DAPHNE',
#  'DARREN',
#  'DARRYL',
#  'DAVID',
#  'DAVOLA',
#  'DEAN JONES',
#  'DEBBY',
#  'DEENA',
#  'DEENSFREI',
#  'DELIVERY BOY',
#  'DELIVERY GUY',
#  'DELIVERY MAN',
#  'DENIM VEST',
#  'DENISE',
#  'DENNIS',
#  'DENTIST',
#  'DEPUTY',
#  'DETECTIVE',
#  'DETECTIVE #1',
#  'DETECTIVE #2',
#  'DEVOLA',
#  'DIANE',
#  'DICK',
#  'DIRECTOR',
#  'DISPATCHER',
#  'DJ ON RADIO',
#  'DOCTER',
#  'DOCTOR',
#  'DOG OWNER',
#  'DOLL',
#  'DOLORES',
#  'DONALD',
#  'DONNA',
#  'DONNA ',
#  'DOORMAN',
#  'DOORMAN 2',
#  'DORIS',
#  'DR. ALLENWOOD',
#  'DR. BAKERSOLL',
#  'DR. COOPERMAN',
#  'DR. DEMBROW',
#  'DR. RESTON',
#  'DR. WEXLER',
#  'DRIVER',
#  'DRY CLEANE',
#  'DRY CLEANER',
#  'DUGAN',
#  'DUNCAN',
#  'DUNCAN & JERRY',
#  'DUSTIN',
#  'DUSTIN - Locker room Attendant #2',
#  'DWAYNE',
#  'Dedication',
#  'Driver',
#  'Dugan',
#  'Dx',
#  'EALINE',
#  'EARL',
#  'ECHO',
#  'ED',
#  'EDDIE',
#  'EDDIT',
#  'EGO',
#  'ELAIEN',
#  'ELAINE',
#  'ELAINE ',
#  'ELAINE & GEORGE',
#  'ELAINE & JERRY',
#  'ELAINE & PUDDY',
#  'ELAINE & RAY',
#  'ELAINE AND JERRY',
#  'ELAINE AND PUDDY',
#  'ELAINE and KRAMER',
#  "ELAINE'S VOICE",
#  "ELAINE's brain",
#  'ELAINE/DAVOLA',
#  'ELAINE/JERRY',
#  'ELAINE/WENDY',
#  'ELANE',
#  'ELDRIDGE',
#  'ELECTRICIAN',
#  'ELIANE',
#  'ELLEN',
#  'EMILY',
#  'EMPLOYEE',
#  'ENZO',
#  'ERIC',
#  'ESTELLE',
#  'ETHAN',
#  'EULOGIST',
#  'EVA',
#  'EVELYN',
#  'EVERYBODY',
#  'EVERYONE',
#  'EXECUTIVE 1',
#  'EXECUTIVE 2',
#  'ElainELAINE',
#  'Elaine',
#  'Elaine + JERRY',
#  'Elaine thinking',
#  'Elaine, becoming board',
#  'Ex',
#  'FAN',
#  'FAN #1',
#  'FARKUS',
#  'FARMER',
#  'FATHER',
#  'FATHER CURTIS',
#  'FATHER HERNANDEZ',
#  'FATHER JESSUP',
#  'FATHER-PRIEST',
#  'FATHER-PRIEST 2',
#  'FDR',
#  'FELDMAN',
#  'FEMALE CUSTOMER',
#  'FEMALE WORKER',
#  'FIREMAN',
#  'FLIGHT ATTENDANT',
#  'FLORIST',
#  'FOREMAN',
#  'FOWLER',
#  'FRANK',
#  'FRANKIE',
#  'FRED',
#  'FRED SAVAGE',
#  'FRIEND',
#  'FRIEND 1',
#  'FULTON',
#  'FURNITURE GUY',
#  'Frank',
#  'Frank Costanza',
#  'Frank and ESTELLE',
#  'GAIL',
#  'GARDNER',
#  'GARY',
#  'GAS STATION ATTENDANT',
#  'GAURD',
#  'GAVIN',
#  'GENE',
#  'GENNICE',
#  'GEOGE',
#  'GEORGE',
#  'GEORGE ',
#  'GEORGE & ELAINE',
#  'GEORGE & JERRY',
#  'GEORGE & KRAMER',
#  'GEORGE AND JERRY',
#  'GEORGE WENDT',
#  "GEORGE'S VOICE",
#  'GEORGE, ELAINE, KRAMER, JERRY, & STAN',
#  'GEORGE/JERRY/ELAINE/WENDY',
#  'GEORGE/SUSAN',
#  'GEPETTO',
#  'GERMAN WOMAN',
#  'GEROGE',
#  'GIGGIO',
#  'GILLIAN',
#  'GINA',
#  'GINO',
#  'GIRL',
#  'GIRLFRIEND',
#  'GIULIANI',
#  'GLADYS',
#  'GLENDA',
#  'GLENN',
#  'GOERGE',
#  'GRANDPA',
#  'GREENY',
#  'GREG',
#  'GROSSBARD',
#  'GROUP',
#  'GUAD',
#  'GUARD',
#  'GUESTS, JERRY & ELAINE',
#  'GUILLERMO',
#  'GUY',
#  'GUY ON PHONE',
#  'GWEN',
#  'GX',
#  'Genderson',
#  'Guy1',
#  'HAARWOOD',
#  'HAFFLER',
#  'HAIRDRESSER',
#  'HAL',
#  'HALLIE',
#  'HANKE',
#  'HAROLD',
#  'HEAD',
#  'HEALTH INSPECTOR',
#  'HELEN',
#  'HELEN & AARON',
#  'HELEN & MORTY',
#  'HELENA',
#  'HENRY',
#  'HERB',
#  'HEYMAN',
#  'HIGH PITCHED VOICE',
#  'HILDE',
#  'HIPPIE #1',
#  'HIPPIE #2',
#  'HOLE DIGGER',
#  'HOLE DIGGER #2',
#  'HOLLY',
#  'HOMELESS MAN',
#  'HOMELESS MAN 2',
#  'HOOKER',
#  'HORST',
#  'HOSPITAL VOICEOVER',
#  'HOSTESS',
#  'HOT DOG VENDOR',
#  'HOTEL CLERK',
#  'HOUSEKEEPER',
#  'HOYT',
#  'HUSBAND',
#  'Huckleberry',
#  'Hx',
#  'IAN',
#  'ICE CREAM VENDER #1',
#  'ICE CREAM VENDER #2',
#  'ILENE',
#  'ISAAC',
#  'ISABEL',
#  'IZZY',
#  'IZZY & IZZY JR.',
#  'IZZY IZZY SR..',
#  'IZZY JR.',
#  'IZZY SR.',
#  'IZZY/IZZY JR/IZZY IZZY SR.',
#  'J. PETERMAN',
#  'JACK',
#  'JACKIE',
#  'JACKIE ',
#  'JAKE',
#  'JAMES',
#  'JANE',
#  'JANET',
#  'JANICE',
#  'JAY',
#  'JAY LENO',
#  'JEAN-PAUL',
#  'JEANINE',
#  'JEANNIE',
#  'JEFF',
#  'JENNA',
#  'JENNY',
#  'JERR',
#  'JERRY',
#  'JERRY ',
#  'JERRY & COP',
#  'JERRY & ELAINE',
#  'JERRY & GEORGE',
#  'JERRY & George',
#  'JERRY & JEANNIE',
#  'JERRY & KRAMER',
#  'JERRY & TIA',
#  'JERRY AND ELAINE',
#  'JERRY AND GEORGE',
#  'JERRY AND JOEL',
#  'JERRY AND KRAMER',
#  'JERRY AND NEWMAN',
#  'JERRY and ELAINE',
#  'JERRY and ELAINE, together',
#  'JERRY and GEORGE',
#  'JERRY and KRAMER',
#  'JERRY and NEWMAN',
#  'JERRY&ELAINE',
#  "JERRY'S ANSWERING MACHINE",
#  "JERRY'S BRAIN",
#  "JERRY'S MACHINE",
#  "JERRY'S PENIS",
#  "JERRY'S brain",
#  "JERRY's brain",
#  'JERRY, GEORGE & ELAINE',
#  'JERRY, GEORGE & KRAMER',
#  'JERRY, GEORGE, & KRAMER',
#  'JERRY, GEORGE, ELAINE',
#  'JERRY, KRAMER & NEWMAN',
#  'JERRY, MORTY AND HELEN',
#  'JERRY\x92S MESSAGE',
#  'JERRY\x92S OUTGOING MESSAGE',
#  'JERY',
#  'JESSIE',
#  'JETER',
#  'JIM',
#  'JIMMY',
#  'JOAN',
#  'JOANNE',
#  'JODI',
#  'JOE',
#  'JOE DEVOLA',
#  'JOE DIVOLA',
#  "JOE'S WIFE",
#  'JOEL',
#  'JOEY',
#  'JOHN',
#  'JOHN TYLER',
#  'JOHNNY',
#  'JOY MAYO',
#  'JOYCE',
#  'JUDGE',
#  'JUDY',
#  'JULIANNA',
#  'JULIE',
#  'JULIO',
#  'James',
#  'Jerry and GEORGE',
#  "Jerry's stand-up",
#  'KAREN',
#  'KARL',
#  'KATE',
#  'KATHY LEE',
#  'KATIE',
#  'KATY',
#  'KATYA',
#  'KEITH',
#  'KELLY',
#  'KEN',
#  'KERI',
#  'KERNIS',
#  'KESSLER',
#  'KEVIN',
#  'KID',
#  'KID #2',
#  'KIDS & KRAMER',
#  'KIM',
#  'KIMBROUGH',
#  'KLEIN',
#  'KOREN',
#  'KRAMER',
#  'KRAMER ',
#  'KRAMER & GEORGE',
#  'KRAMER & JERRY',
#  'KRAMER & JOEY',
#  'KRAMER & MICKEY',
#  'KRAMER + JERRY',
#  'KRAMER and JERRY',
#  'KRAMER/NEWMAN',
#  'KRAMER/Turkey',
#  'KRISTIN',
#  'KRMAER',
#  'KRUGER',
#  'KURT',
#  'LAB TECHNICIAN',
#  'LADY',
#  'LADY 1',
#  'LADY 2',
#  'LAMAR',
#  'LANDIS',
#  "LANDIS'S INTERCOM",
#  'LANDLORD',
#  'LANETTE',
#  'LARRY',
#  'LASER GUY',
#  'LAURA',
#  'LAURA & JERRY',
#  'LEADER',
#  "LEAPIN' LARRY",
#  'LELAND',
#  'LENA',
#  'LEO',
#  'LESLIE',
#  'LETTERMAN',
#  'LEVITAN',
#  'LEW',
#  'LIBRARIAN',
#  'LINDSAY',
#  'LIPPMAN',
#  'LISA',
#  'LISI',
#  'LIZ',
#  'LLOYD',
#  'LOIS',
#  'LORETTA',
#  'LORRAINE',
#  'LOTUS',
#  'LOU',
#  'LOUISE',
#  'LOW-TALKER',
#  'LT. COLEMAN',
#  'LT. MARTEL',
#  'LUBECK',
#  'LUPE',
#  'LYLE',
#  'MABEL',
#  'MACHINE',
#  'MACKENZIE',
#  'MAESTRO',
#  'MAESTRO AND ELAINE',
#  'MAHJONG LADY',
#  'MAID',
#  'MAILMAN',
#  "MAITRE D'",
#  'MALCOLM',
#  'MALE WORKER',
#  'MAN',
#  'MAN #',
#  'MAN #1',
#  'MAN #1 ',
#  'MAN #2',
#  'MAN #2 ',
#  'MAN #3',
#  'MAN #4',
#  'MAN 1',
#  'MAN 2',
#  'MAN 3',
#  'MAN 4',
#  'MAN AT THE COUNTER',
#  'MAN BEHIND THE DOOR',
#  'MAN IN AUDIENCE',
#  'MAN IN CAR',
#  'MAN IN NEIGHBORING BED',
#  'MAN IN SHOWER',
#  'MAN IN THE CROWD',
#  'MAN ON RAFT',
#  'MAN ON THE STREET',
#  'MAN#1',
#  'MAN#2',
#  'MAN#3',
#  'MAN1',
#  'MAN2',
#  'MAN3',
#  'MAN4',
#  'MANAGER',
#  'MANDEL',
#  'MANNY',
#  'MANYA',
#  'MANYA ',
#  'MAR',
#  'MARCELINO',
#  'MARCELLINO',
#  'MARCY',
#  'MARGARET',
#  'MARIAN',
#  'MARIE',
#  'MARIO',
#  'MARION',
#  'MARISA',
#  'MARK',
#  'MARLA',
#  'MARLENE',
#  'MARRY',
#  'MARTIN',
#  'MARTY',
#  'MARY',
#  'MARY ANNE',
#  'MARYEDITH',
#  'MATTHEW',
#  'MAURA',
#  'MAXWELL',
#  'MCADAM',
#  'MECHANIC',
#  'MEL',
#  'MELANIE',
#  'MELISSA',
#  'MEMBER 1',
#  'MEMBER 2',
#  'MERYL',
#  'MICHAEL',
#  'MICKEY',
#  'MIKE',
#  'MILOS',
#  'MINKLER',
#  'MIRANDA',
#  'MISHA',
#  'MISS RHODE ISLAND',
#  'MODEL #1',
#  'MODEL #2',
#  'MODEL #3',
#  'MODEL #4',
#  'MOHEL',
#  'MOLLIKA',
#  'MOLLY',
#  'MOM',
#  'MONA',
#  'MONICA',
#  "MONK'S MANAGER",
#  'MOONEY',
#  'MORGAN',
#  'MORGANEWMAN',
#  'MORTY',
#  'MORTY/HELEN/JERRY',
#  'MOTHER',
#  'MOVIE PATRON',
#  'MOVIE PHONE GUY',
#  'MR BURNS',
#  'MR OH',
#  'MR REICHMAN',
#  'MR ROSS',
#  'MR STAR',
#  'MR TANAKA',
#  'MR YAMAGUCHI',
#  'MR. ABBOTT',
#  'MR. ARM',
#  'MR. BEVILACQUA',
#  'MR. COHEN',
#  'MR. CROSS',
#  'MR. CUSHMAN',
#  'MR. ELINOFF',
#  'MR. GOLDSTEIN',
#  'MR. GRAHAM',
#  'MR. GREEN',
#  'MR. LIPPMAN',
#  'MR. MORGAN',
#  'MR. PETERMAN',
#  'MR. PITT',
#  'MR. PLESS',
#  'MR. ROSS',
#  'MR. S',
#  'MR. SANGER',
#  'MR. STEINBRENNER',
#  'MR. THOMASSOULO',
#  'MR. TUTTLE',
#  'MR.THOMASSOULO',
#  'MRS ALLISTER',
#  'MRS HAMILTON',
#  'MRS REICHMAN',
#  'MRS WILHELM',
#  'MRS. ANVINO',
#  'MRS. C',
#  'MRS. CHOATE',
#  'MRS. COSTANZA',
#  'MRS. ENRIGHT',
#  'MRS. O',
#  'MRS. PAYTON',
#  'MRS. PETERMAN',
#  'MRS. ROSS',
#  'MRS. S',
#  'MRS. SANGER',
#  'MRS. SOKOL',
#  'MRS. SWEEDLER',
#  'MRS. ZANFINO',
#  'MRS.ARM',
#  'MS. BAINES',
#  'MS. DE GRANMONT',
#  'MS. JORDAN',
#  'MUSIC GUY',
#  'MYRA',
#  'Man',
#  'Mr. VISAKI',
#  'Mrs. SANGER',
#  'Mrs. SWEEDLER',
#  'NAKED MAN',
#  'NANA',
#  'NANCY',
#  'NAOMI',
#  'NARRATOR',
#  'NED',
#  'NEIGHBOR',
#  'NEIL',
#  'NEMWAN',
#  'NEPHEW',
#  'NEWMAN',
#  'NEWMAN & KRAMER',
#  'NEWMAN AND KRAMER',
#  'NEWMAN and KRAMER',
#  'NEWMAN/KRAMER',
#  'NEWMANEWMAN',
#  'NEWS',
#  'NEWSSTAND OWNER',
#  'NICK',
#  'NIKKI',
#  'NINA',
#  'NOEL',
#  'NOREEN',
#  'NOTE',
#  'NUN',
#  'NURSE',
#  'NURSE 1',
#  'Nana',
#  'Newman',
#  'Newscaster',
#  'Notes',
#  'Notice',
#  "O'NEILL",
#  'OFFICER',
#  'OLD GUY',
#  'OLD MAN',
#  'OLD MAN #2',
#  'OLD MAN #3',
#  'OLD WOMAN',
#  'OLDER MAN',
#  'OLDER WOMAN',
#  'OLIVE',
#  'ORDERLY',
#  'ORGANIZER',
#  'OTHER CO-WORKERS IN HALLWAY',
#  'OTHER GUY',
#  'OTHER SECURITY GUARD',
#  'OTHER-WALTER',
#  'OWNER',
#  'Off stage',
#  'Opening Monolog',
#  'Opening scene',
#  'PAM',
#  'PAMELA',
#  'PARAMEDIC',
#  'PARK GUY#1',
#  'PARK GUY#2',
#  'PARRY',
#  'PARTY GUEST',
#  'PASSENGER',
#  'PASSENGER #1',
#  'PASSENGER #2',
#  'PASSENGER #3',
#  'PASSENGER 2',
#  'PASSERBY',
#  'PAT',
#  'PAT HAZELL',
#  'PATIENT',
#  'PATRICE',
#  'PATTI',
#  'PATTY',
#  'PAUL',
#  'PAUL - Locker room Attendant #1',
#  'PAULA',
#  'PEGGY',
#  'PENNY',
#  'PENSKY',
#  'PEOPLE AT TABLE',
#  'PETE',
#  'PETER',
#  'PETERMAN',
#  'PHARMACIST',
#  'PHIL',
#  'PHILBIN',
#  'PHONE',
#  'PHONE MAN',
#  'PHONE TAPE',
#  'PHOTOGRAPHER',
#  'PING',
#  'PINTER',
#  'PITT',
#  'PLAYER',
#  'POKER PLAYER #1',
#  'POKER PLAYER #2',
#  'POKER PLAYER #3',
#  'POKER PLAYER #4',
#  'POLICE',
#  'POLICE OFFICER',
#  'POLICE RADIO',
#  'POLICEMAN',
#  'POP',
#  'POPPIE',
#  'POSTAL EMPLOYEE',
#  'POSTMAN',
#  'POSTMASTER GENERAL',
#  'PREGNANT WOMAN',
#  'PRIEST',
#  'PRISONER',
#  'PRISONER 1',
#  'PRISONER 2',
#  'PRISONER 3',
#  'PROSTITUTE',
#  'PUDDY',
#  'PUERTO RICAN MAN',
#  'Performed by',
#  'Phil',
#  'Police officer',
#  'Published',
#  'RABBI',
#  'RACHEL',
#  'RADIO',
#  'RADIO ANNOUNCER',
#  'RALPH',
#  'RAMON',
#  'RAQUEL',
#  'RAVA',
#  'RAY',
#  'RAYMOND',
#  'READER',
#  'REBECCA',
#  'RECEPTIONIST',
#  'REFEREE',
#  'REGIS',
#  'REILLY',
#  'REMY',
#  'RENE',
#  'RENTAL CAR AGENT',
#  'REPAIRMAN',
#  'REPORTER',
#  'REPORTERS',
#  'RESIDENT',
#  'RESTAURANT MANAGER',
#  'RESTAURATEUR',
#  'RESTON',
#  'RHISA',
#  'RICARDI',
#  'RICHIE',
#  'RICK',
#  'RICKEY',
#  'RICKY',
#  "RICKY'S BOSS",
#  'RITA',
#  'RIVERA',
#  'ROBBER',
#  'ROBERT',
#  'ROBERTA',
#  'ROBIN',
#  "ROBIN'S MOTHER",
#  'ROCHELLE',
#  'ROGER',
#  'RON',
#  'RONNIE',
#  'ROXANNE',
#  'ROY',
#  'RUBY',
#  'RUDY',
#  'RULA',
#  'RUSSEL',
#  'RUSSELL',
#  'RUSTY',
#  'RUTHIE',
#  'Readers',
#  'Receptionist',
#  'SAILOR',
#  'SAL BASS',
#  'SALES WOMAN',
#  'SALESMAN',
#  'SALESWOMAN',
#  'SALLY',
#  'SAM',
#  "SAM'S VOICE",
#  'SANDI',
#  'SANDOS BROTHER 1',
#  'SANDOS BROTHER 2',
#  'SANDRA',
#  'SANDY',
#  'SANSEI',
#  'SARA',
#  'SASHA',
#  'SCOTT',
#  'SECRETARY',
#  'SECURITY GUARD',
#  'SHARON',
#  'SHEILA',
#  'SHELLBACH',
#  'SHELLY',
#  'SHERRY',
#  'SHLOMO',
#  'SHOWALTER',
#  'SID',
#  'SIDRA',
#  'SIENA',
#  'SILVIO',
#  'SIMON',
#  'SISTER ROBERTA',
#  'SKYCAP',
#  'SLIPPERT PETE',
#  'SLIPPERY PETE',
#  'SOME GUY',
#  'SON',
#  'SOPHIE',
#  'SOUP NAZI',
#  'SPEAKER',
#  'SPIKE',
#  'SPONSER',
#  'SPONSOR',
#  'STACEY',
#  'STAGE HAND',
#  'STAGEHAND',
#  'STAN',
#  'STATIONER',
#  'STEFANIE',
#  'STEIN',
#  'STEINBRENNER',
#  'STELLA',
#  'STEVE',
#  'STEVEN',
#  'STEWARDESS',
#  'STOCK BOY',
#  'STORE MANAGER',
#  'STRANGER',
#  'STREET TOUGH',
#  'STU',
#  'STUDENT #1',
#  'STUDENT #2',
#  'STUDENT 1',
#  'STUDENT 2',
#  'STUDENT 3',
#  'STUDIO GUARD',
#  'SUBWAY ANNOUNCEMENT',
#  'SUE ELLEN',
#  'SUNNY',
#  'SUPER',
#  'SUPERVISOR',
#  'SUSAN',
#  'SUSAN AND ALLSION',
#  'SUSIE',
#  'SYLVIA',
#  'Sari / Saree',
#  'Scene',
#  'SeConrad',
#  'Song over the end credits',
#  'Sponer',
#  'Stu',
#  'Sung by',
#  'TABACHNICK',
#  'TALL GIRL',
#  'TAMMY',
#  'TAN',
#  'TANNOY',
#  'TAPE PLAYER',
#  'TAPE RECORDER',
#  'TARA',
#  'TARTABULL',
#  'TARTBULL',
#  'TAWNI',
#  'TAXI DRIVER',
#  'TEACHER',
#  'TEDDY',
#  'TEL',
#  'TELLER',
#  'TENANT 1',
#  'TENANT 2',
#  'TESTIKOV',
#  'THE DRAKE',
#  'THE FREAK',
#  'THE GIRLS',
#  'THEATER MANAGER',
#  'THERAPIST',
#  'THOMASSOULO',
#  'THUG',
#  'TIA',
#  'TICKET LADY',
#  'TICKET MAN',
#  'TIERNEY',
#  'TIM',
#  'TIMMY',
#  'TINA',
#  'TOBY',
#  'TODD',
#  'TOM',
#  'TONY',
#  'TOR',
#  'TOUGH GUY',
#  'TRUCK DRIVER',
#  'TUTTLE',
#  'TV',
#  'TV ANNOUNCER',
#  'TV ELAINE',
#  'TV JERRY',
#  'TV NEWSCASTER',
#  'TV VOICE',
#  'TVVOICE',
#  'Tina',
#  'Turning Point',
#  'UKRAINIAN',
#  'UMPIRE',
#  'UNCLE LEO',
#  'UNCLE MAC',
#  'USHA',
#  'USHER',
#  'VALERIE',
#  'VANDELAY',
#  'VANESSA',
#  'VARGUS',
#  'VEGETABLE LASAGNA',
#  'VENDER',
#  'VET',
#  'VIC',
#  'VICTORIA',
#  'VINCENT',
#  'VIOLIN PLAYER',
#  'VIVIAN',
#  'VOGEL',
#  'VOICE',
#  'VOICE 1',
#  'VOICE 2',
#  'VOICE FROM POKER GAME',
#  'VOICE ON INTERCOM',
#  'VOICE ON SPEAKER',
#  'VOICE ON THE PHONE',
#  'VOIGHT',
#  'Voice',
#  'WAITER',
#  'WAITRESS',
#  'WAITRESS ',
#  'WAITRESS #1',
#  'WAITRESS #2',
#  'WALKER #1',
#  'WALKER #2',
#  'WALKER #3',
#  'WALTER',
#  'WATKINS',
#  'WELLS',
#  'WENDY',
#  'WEST',
#  'WHATLEY',
#  'WIFE',
#  'WILCOX',
#  'WILHELM',
#  'WILKIE',
#  'WILLIAMS',
#  'WILLIE',
#  'WILLIE SR',
#  'WILTON',
#  'WINONA',
#  'WOMAN',
#  'WOMAN #1',
#  'WOMAN #2',
#  'WOMAN 1',
#  'WOMAN 2',
#  'WOMAN AT ANOTHER TABLE',
#  'WOMAN AT BEACH',
#  'WOMAN AT NEXT TABLE',
#  'WOMAN AT PHONE',
#  'WOMAN AT YET ANOTHER TABLE',
#  'WOMAN IN THE CROWD',
#  "WOMAN'S VOICE ON THE PHONE",
#  'WOMANEWMAN',
#  'WORKER',
#  'WORKERS',
#  'WYCK',
#  "We gotta go! It's 8",
#  'Where to Find More',
#  'Woman Behind ELAINE',
#  'Women',
#  'Written by',
#  'Wx',
#  'YELLING GUY',
#  'YOUNG COP',
#  'ZACH',
#  'ZEKE',
#  'ZUBIN',
#  'http',
#  'rc',
#  'so far']

# %%
# Found some more 'characters' to remove by manually looking at the character list above
# (Also, The character 'SeConrad' should be 'SECRETARY', but that's fine)
more_chars_to_remove = ['Beginnings', "Jerry's stand-up", 'Opening Monolog', 'Opening scene', 'Performed by', 
    'Published', 'Song over the end credits', 'Sung by',' Turning Point',# "We gotta go! It's 8",
    'Where to Find More', 'Written by', 'http', 'rc', 'so far']

df11 = df10[[char not in more_chars_to_remove for char in df10.character]]

# %%
# About 20 lines can't be processed by get_paren_depth
paren_test_line = [get_paren_depth(line) for line in df11.line]
paren_test_line2 = [test != 0 for test in paren_test_line]

df_bad_lines = df11[paren_test_line2]
df_bad_lines
# Out:
#      ep_num  scene_num  line_num character  \
# 416      12         11         3       VIC
# 128      25          2        47    KRAMER
# 477      26         10         8     JERRY
# 140      27          3         3    GEORGE
# 180      27          3        20     JERRY
# 339      82          5        90    ELAINE
# 814      95         19        19    ELAINE
# 92      105          2        29    GEORGE
# 264     105          5        53     JERRY
# 750     105         18        14     STEIN
# 123     106          3        39    GEORGE
# 633     110         22         1   GENNICE
# 351     125          7         1     JERRY
# 150     133          4        17    KRAMER
# 142     137          5        11     JERRY
# 334     137         10        27    KRAMER
# 107     144          4         4    GEORGE
# 37      149          2         5    KRAMER
# 178     159          3        58     PATTY
# 556     164         17         6    ELAINE
# 477     171         11        12     JERRY
#
#                                                   line
# 416  Hey, you see that sign right there? (Points to...
# 128  All right Come on....again attempts to pull he...
# 477  (to himself: Uh oh. My organs are playing ches...
# 140                                     (waving:  Eva.
# 180                (Patting his head:  I'm a comedian.
# 339              (under her breath) Ya that'll happen)
# 814  (Tilts her head down, looking over her glasses...
# 92   "Aahhrgh...it wouldn't take...... long pause, ...
# 264                                      "Kom Pau(sp?"
# 750  "Yes it is. Well lets see what I have today. D...
# 123  Yeah.( reaches for the purse and finds a piece...
# 633  (singing and dancing) "It's a long journey fro...
# 351                                   Gimme that rye!)
# 150  Now, what are you thinkin'? (Getting upset) Yo...
# 142  I mean all that stuff is so small.. ((ELAINE i...
# 334  Yeah. Well, count me out. I'm swimmin'. Old ma...
# 107  Oh, right! (Shakes her hand) Right! Hey, hey.....
# 37   Uh. Well, I'm sick o' waiting. (pulls out his ...
# 178                             Sarcastically) Uh huh.
# 556  Spite Never sleeps (doing a little dance as sh...
# 477       (overhearing the other two: Elaine, Elaine--

# %%
# Copy and paste
for line in df_bad_lines.line:
    print('"' + line + '",')
# Out:
# "Hey, you see that sign right there? (Points to a sign saying "Not Responsible for Valuables"",
# "All right Come on....again attempts to pull headphones off)",
# "(to himself: Uh oh. My organs are playing chess again.",
# "(waving:  Eva.",
# "(Patting his head:  I'm a comedian.",
# "(under her breath) Ya that'll happen)",
# "(Tilts her head down, looking over her glasses in amazement of",
# ""Aahhrgh...it wouldn't take...... long pause, audience laughter) ten minutes from now, I'll be sweating all over again ,I can feel it. I'm a human heat pump!"",
# ""Kom Pau(sp?"",
# ""Yes it is. Well lets see what I have today. Darn it It's ham & Cheese again and she forgot the fancy mustard. I told her I like that fancy mustard. You could put that fancy mustard on a shoe and it would taste pretty good to me. oh! she made it up with a cupcake though. Hey look at this. you know I got a new system for eating these things. `I used to peel off the chocolate now I turn them upside down , I eat the cake first and save the frosting for the end. (George stops listening and It's almost like its own dessert.............",
# "Yeah.( reaches for the purse and finds a piece of paper . he looks annoyed.",
# "(singing and dancing) "It's a long journey from Milan to Minsk" (Shoe lace comes undone (even LOOKS like figure skates) wait wait. Hold it stop, (sob) I'm sorry, I have to start it over, my shoelace. (sob) I can't do it like this. Please let me start over. (sob) Please. (sob) Please. . . .",
# "Gimme that rye!)",
# "Now, what are you thinkin'? (Getting upset) You think that I'm not able to wear jeans anymore? Is that what you're sayin'? Because if that's what you're sayin', Jerry, I'll go and I'll buy some jeans. (Jerry shrugs. Kramer raises his voice to a menacing tone) I swear to God I will! (Jerry's showing off a skeptical face.",
# "I mean all that stuff is so small.. ((ELAINE is wryly assessing him)) stupid..",
# "Yeah. Well, count me out. I'm swimmin'. Old man Leland is bustin' my hump over these reports. If I don't get 'em done by nine, I'm toast.. ((takes a swig and reacts))",
# "Oh, right! (Shakes her hand) Right! Hey, hey.. I love the floors in here. It's like a gymnasium in here! Try and guard me! (Dribbles an imaginary ball",
# "Uh. Well, I'm sick o' waiting. (pulls out his pocket-watch (it has a chain, too)) I am springin' ahead riiight now.",
# "Sarcastically) Uh huh.",
# "Spite Never sleeps (doing a little dance as she says it",
# "(overhearing the other two: Elaine, Elaine--",

# %%
good_lines = [
    "Hey, you see that sign right there?",
    "All right Come on...",
    "Uh oh. My organs are playing chess again.",
    "Eva.",
    "I'm a comedian.",
    "Ya that'll happen",
    "", #hmmm
    "Aahhrgh...it wouldn't take...... ten minutes from now, I'll be sweating all over again, I can feel it. I'm a human heat pump!",
    "Kom Pau",
    "Yes it is. Well lets see what I have today. Darn it It's ham & Cheese again and she forgot the fancy mustard. I told her I like that fancy mustard. You could put that fancy mustard on a shoe and it would taste pretty good to me. oh! she made it up with a cupcake though. Hey look at this. you know I got a new system for eating these things. I used to peel off the chocolate now I turn them upside down , I eat the cake first and save the frosting for the end.",
    "Yeah.",
    "It's a long journey from Milan to Minsk. wait wait. Hold it stop, (sob) I'm sorry, I have to start it over, my shoelace. (sob) I can't do it like this. Please let me start over. (sob) Please. (sob) Please. . . .",
    "Gimme that rye!",
    "Now, what are you thinkin'? You think that I'm not able to wear jeans anymore? Is that what you're sayin'? Because if that's what you're sayin', Jerry, I'll go and I'll buy some jeans. I swear to God I will!",
    "I mean all that stuff is so small. stupid.",
    "Yeah. Well, count me out. I'm swimmin'. Old man Leland is bustin' my hump over these reports. If I don't get 'em done by nine, I'm toast.",
    "Oh, right! Right! Hey, hey.. I love the floors in here. It's like a gymnasium in here! Try and guard me!",
    "Uh. Well, I'm sick o' waiting. I am springin' ahead riiight now.",
    "Uh huh.",
    "Spite Never sleeps",
    "Elaine, Elaine"]

# %%
# Needed to use assign method to make the code in this cell work for reasons unknown
test_zip = zip(good_lines, df_bad_lines.iterrows())
df12 = df11.copy(deep = True)

for good, (ind, val) in test_zip:
    mask = (df11.ep_num == val.ep_num) & (df11.scene_num == val.scene_num) & (df11.line_num == val.line_num)
#     print(df11[mask].line)
#     df12[mask]['line'] = good
#     df12[mask].loc[:, 'line'] = good
    df12[mask] = df12[mask].assign(line = good)
#     print(df11[mask].line)
    print(good)
    print(df12[mask]['line'])
# Out:
# Hey, you see that sign right there?
# 416    Hey, you see that sign right there?
# Name: line, dtype: object
# All right Come on...
# 128    All right Come on...
# Name: line, dtype: object
# Uh oh. My organs are playing chess again.
# 477    Uh oh. My organs are playing chess again.
# Name: line, dtype: object
# Eva.
# 140    Eva.
# Name: line, dtype: object
# I'm a comedian.
# 180    I'm a comedian.
# Name: line, dtype: object
# Ya that'll happen
# 339    Ya that'll happen
# Name: line, dtype: object
#
# 814
# Name: line, dtype: object
# Aahhrgh...it wouldn't take...... ten minutes from now, I'll be sweating all over again, I can feel it. I'm a human heat pump!
# 92    Aahhrgh...it wouldn't take...... ten minutes f...
# Name: line, dtype: object
# Kom Pau
# 264    Kom Pau
# Name: line, dtype: object
# Yes it is. Well lets see what I have today. Darn it It's ham & Cheese again and she forgot the fancy mustard. I told her I like that fancy mustard. You could put that fancy mustard on a shoe and it would taste pretty good to me. oh! she made it up with a cupcake though. Hey look at this. you know I got a new system for eating these things. I used to peel off the chocolate now I turn them upside down , I eat the cake first and save the frosting for the end.
# 750    Yes it is. Well lets see what I have today. Da...
# Name: line, dtype: object
# Yeah.
# 123    Yeah.
# Name: line, dtype: object
# It's a long journey from Milan to Minsk. wait wait. Hold it stop, (sob) I'm sorry, I have to start it over, my shoelace. (sob) I can't do it like this. Please let me start over. (sob) Please. (sob) Please. . . .
# 633    It's a long journey from Milan to Minsk. wait ...
# Name: line, dtype: object
# Gimme that rye!
# 351    Gimme that rye!
# Name: line, dtype: object
# Now, what are you thinkin'? You think that I'm not able to wear jeans anymore? Is that what you're sayin'? Because if that's what you're sayin', Jerry, I'll go and I'll buy some jeans. I swear to God I will!
# 150    Now, what are you thinkin'? You think that I'm...
# Name: line, dtype: object
# I mean all that stuff is so small. stupid.
# 142    I mean all that stuff is so small. stupid.
# Name: line, dtype: object
# Yeah. Well, count me out. I'm swimmin'. Old man Leland is bustin' my hump over these reports. If I don't get 'em done by nine, I'm toast.
# 334    Yeah. Well, count me out. I'm swimmin'. Old ma...
# Name: line, dtype: object
# Oh, right! Right! Hey, hey.. I love the floors in here. It's like a gymnasium in here! Try and guard me!
# 107    Oh, right! Right! Hey, hey.. I love the floors...
# Name: line, dtype: object
# Uh. Well, I'm sick o' waiting. I am springin' ahead riiight now.
# 37    Uh. Well, I'm sick o' waiting. I am springin' ...
# Name: line, dtype: object
# Uh huh.
# 178    Uh huh.
# Name: line, dtype: object
# Spite Never sleeps
# 556    Spite Never sleeps
# Name: line, dtype: object
# Elaine, Elaine
# 477    Elaine, Elaine
# Name: line, dtype: object

# %%
# Look's good!
paren_test_line = [get_paren_depth(line) for line in df12.line]
print(max(paren_test_line))
print(min(paren_test_line))
# Out:
# 0
# 0

# %%
# Let's update the line column
df13 = df12.copy()
i = 0

while True:
    # Update line column
    df13['line'] = [paren_removal(line) for line in df13.line]
    
    # Update counter
    i += 1
    
    # Tests
    paren_test_line = [get_paren_depth(line) for line in df13.line]
    too_many_begs = max(paren_test_line)
    too_many_ends = min(paren_test_line)
    num_opens = ['(' in line for line in df13.line]
    num_closes = [')' in line for line in df13.line]
    no_closes = [')' not in line for line in df13.line]
#     df_look_at = df13[num_opens and no_closes]
    
    print(i, ' ', too_many_begs, ' ', too_many_ends, ' ', sum(num_opens), ' ', sum(num_closes))
    
    if (sum(num_opens) == 0) & (sum(num_closes) == 0):
        break
# Out:
# 1   0   0   1107   1107
# 2   0   0   203   203
# 3   0   0   64   64
# 4   0   0   21   21
# 5   0   0   12   12
# 6   0   0   6   6
# 7   0   0   4   4
# 8   0   0   3   3
# 9   0   0   1   1
# 10   0   0   0   0

# %%
df13.head()
# Out:
#     ep_num  scene_num  line_num character  \
# 28       1          1         1     JERRY
# 36       1          2         1     JERRY
# 38       1          2         2    GEORGE
# 40       1          2         3     JERRY
# 42       1          2         4    GEORGE
#
#                                                  line
# 28  Do you know what this is all about? Do you kno...
# 36  See, to me, that button is in the worst possib...
# 38                                   Are you through?
# 40             You do of course try on, when you buy?
# 42  Yes, it was purple, I liked it, I dont actual...

# %%
! pwd
# Out:
# /Users/warren/Data_Science/Metis/github/project-kojak

# %% [markdown]
# ### Pickle the file

# %%
df13.to_pickle('seinfeld_scripts_clean.pkl')

# %% [markdown]
# ### Further processing

# %%
# Do more standard preproc now!
# Remove the x\'s
# Remove "AUDIENCE" lines

# nltk ipynb stuff?: normalization, punc removal, tokenization (pretty sure yes)

# %%
char_x = ['\\x' in char for char in df13.character]
line_x = ['\\x' in line for line in df13.line]

# %%
# I'm skeptical but let's move on I suppose
print(sum(char_x))
print(sum(line_x))
# Out:
# 0
# 0

# %%
rename = ['CLERK' in char and 'VOICE' in char for char in df13.character]
df13[rename].character
# Out:
# 659    CLERKS VOICE
# Name: character, dtype: object

# %%
rename = ['JERRY' in char and 'MESSAGE' in char for char in df13.character]
df13[rename].character
# Out:
# 414             JERRYS MESSAGE
# 711    JERRYS OUTGOING MESSAGE
# Name: character, dtype: object

# %%
# Only want to remove the first two of these
rename = ['AUDIENCE' in char for char in df13.character]
df13.reset_index().drop('index', axis = 1)[rename]
# Out:
#        ep_num  scene_num  line_num        character            line
# 212         2          2         2         AUDIENCE         Cheque.
# 7884       29         10         3         AUDIENCE         Oooooh.
# 46809     157         22         5  MAN IN AUDIENCE  I have cancer!
# 49494     165         29         2         AUDIENCE      Hi, Jason.

# %%
df14 = (df13
        .reset_index()
        .drop('index', axis = 1)
        .drop([212, 7884]))

# %%
# Only want to remove the first two of these
rename = ['AUDIENCE' in char for char in df14.character]
df14[rename]
# Out:
#        ep_num  scene_num  line_num        character            line
# 46809     157         22         5  MAN IN AUDIENCE  I have cancer!
# 49494     165         29         2         AUDIENCE      Hi, Jason.

# %%
# Let's remove scenes with only one character in them
# These are presumably most Jerry's stand-up scenes
multi_char_scenes = (df14
          .groupby(['ep_num', 'scene_num'])
          .character
          .nunique()
          .reset_index()
          .rename(index = str, columns = {'character' : 'num_chars'})
          .query('num_chars != 1'))
multi_char_scenes.head()
# Out:
#    ep_num  scene_num  num_chars
# 1       1          2          4
# 2       1          3          2
# 4       1          5          2
# 5       1          6          4
# 7       1          8          5

# %%
df15 = pd.merge(df14, multi_char_scenes[['ep_num', 'scene_num']], how = 'inner', on = ['ep_num', 'scene_num'])
df15.head()
# Out:
#    ep_num  scene_num  line_num character  \
# 0       1          2         1     JERRY
# 1       1          2         2    GEORGE
# 2       1          2         3     JERRY
# 3       1          2         4    GEORGE
# 4       1          2         5     JERRY
#
#                                                 line
# 0  See, to me, that button is in the worst possib...
# 1                                   Are you through?
# 2             You do of course try on, when you buy?
# 3  Yes, it was purple, I liked it, I dont actual...
# 4                              Oh, you dont recall?

# %%
for line in df15.head(10).line:
    print(line)
# Out:
# See, to me, that button is in the worst possible spot. The second button literally makes or breaks the shirt, look at it. Its too high! Its in no-mans-land. You look like you live with your mother.
# Are you through?
# You do of course try on, when you buy?
# Yes, it was purple, I liked it, I dont actually recall considering the buttons.
# Oh, you dont recall?
# Uh, no, not at this time.
# Well, senator, Id just like to know, what you knew and when you knew it.
# Mr. Seinfeld. Mr. Costanza.
# Are, are you sure this is decaf? Wheres the orange indicator?
# Its missing, I have to do it in my head: decaf left, regular right, decaf left, regular right...its very challenging work.

# %%
# Filter out empty lines
nonempty_lines = [len(line) != 0 for line in df15.line]
df16 = df15[nonempty_lines]

print(df15.shape)
print(df16.shape)
# Out:
# (53373, 5)
# (53327, 5)

# %%
# One issue is when a character is quoting someone else

# %%
line_end_chars = {line[-1] for line in df16.line}
len(line_end_chars)
# Out:
# 53

# %%
df17 = df16.assign(line = df16.line.str.strip())

# %%
line_end_chars = {line[-1] for line in df17.line}
len(line_end_chars)
# Out:
# 53

# %%
mask = [line[-1] not in ['.', '?', '!'] for line in df16.line]
for line in df16[mask].head().line:
    print(line, ' ', line.strip()[-1])
# Out:
# If you know what happened in the Met game, dont say anything, I taped it, hello. Yeah, no, Im sorry, you have the wrong number. Yeah, no   o
# If my father was moving this hed had to have a cigarette in his mouth the whole way. 'Have you got your end?...Your ends got to come down first, easy now, drop it down...drop it down, your ends got to come down.'   '
# Maybe they came back for Chinese food. Yknow Maureen Stapleton, if she gets a craving, shes probably screamin at those aliens, I gotta have a lo mein!   
# So, uh, whats your son doing now, Dr. Stevens? Oh, hes a public fornicator. Yes, hes a fine boy...   
# Hi   i

# %%
mask = [line[-1] not in ['.', '?', '!'] for line in df17.line]
for line in df17[mask].head().line:
    print(line, ' ', '?' + line.strip()[-1] + '?')
# Out:
# If you know what happened in the Met game, dont say anything, I taped it, hello. Yeah, no, Im sorry, you have the wrong number. Yeah, no   ?o?
# If my father was moving this hed had to have a cigarette in his mouth the whole way. 'Have you got your end?...Your ends got to come down first, easy now, drop it down...drop it down, your ends got to come down.'   ?'?
# Maybe they came back for Chinese food. Yknow Maureen Stapleton, if she gets a craving, shes probably screamin at those aliens, I gotta have a lo mein!   ??
# So, uh, whats your son doing now, Dr. Stevens? Oh, hes a public fornicator. Yes, hes a fine boy...   ??
# Hi   ?i?

# %%
mask = [line[-1] in ['*', '/'] for line in df17.line] # ',', '-',
for line in df17[mask].head().line:
    print(line)
    pprint(line)
# replace dashes with spaces but then strip
# nix commas
#
# Out:
# Huh. Well this is a little awkward, isn't it/
# "Huh. Well this is a little awkward, isn't it/"
# Hello. How are you/
# 'Hello. How are you/'
# Seven... Eight... Nine... Ten. *ding*
# 'Seven... Eight... Nine... Ten. *ding*'
# Oh no-no, it's okay. *comment from transcriber: yeah, she doesn't want to be paid, didn't she send the bill?*
# ("Oh no-no, it's okay. *comment from transcriber: yeah, she doesn't want to be "
#  "paid, didn't she send the bill?*")
# They give you that *Fish.*
# 'They give you that *Fish.*'

# %%
# These \x things gotta go...
for ind, val in df16.iterrows():
    if 'Maybe they came back for Chinese food.' in val.line:
        print(ind, val)
        look_at_this = val.line
        print(val.line)
# Out:
# 208 ep_num                                                       2
# scene_num                                                    3
# line_num                                                     3
# character                                                JERRY
# line         Maybe they came back for Chinese food. Yknow ...
# Name: 208, dtype: object
# Maybe they came back for Chinese food. Yknow Maureen Stapleton, if she gets a craving, shes probably screamin at those aliens, I gotta have a lo mein!

# %%
look_at_this
# Out:
# 'Maybe they came back for Chinese food. Y\x92know Maureen Stapleton, if she gets a craving, she\x92s probably screamin\x92 at those aliens, \x93I gotta have a lo mein!\x94'

# %%
look_at_this.find('\x93')
# Out:
# 130

# %%
'\x93' in look_at_this
# Out:
# True

# %%
# Not getting regex to work...
i = 0
for ind, val in df16.iterrows():
    if ('\x92' in val.line) | ('\x93' in val.line) | ('\x94' in val.line):
        i += 1

i
# Out:
# 2146
